# %% [markdown]
# ## テキストマイニング
#
# 出現頻度を取得

# %%
# text-mining.py
 
# python解析器janomeをインポート - 1
from janome.tokenizer import Tokenizer
 
# 形態素解析用オブジェクトの生成 - 2
text = Tokenizer()
 
# txtファイルからデータの読み込み - 3
text_file = open("pg2.txt")
bindata = text_file.read()
txt = bindata
 
# txtから読み込んだデータを形態素解析 - 4
lines = txt.split("\r\n")
for i in lines:
    print(i)
    print("\n")
    text_c = text.tokenize(i)
    for j in text_c:
      print(j)
 
print("\n")
 
# テキストを一行ごとに処理 - 5
word_dic = {}
lines_1 = txt.split("\r\n")
print(lines_1)
print("\n")
for line in lines_1:
    malist = text.tokenize(line)
    for w in malist:
	    word = w.surface
	    ps = w.part_of_speech # 品詞 - 6
	    if ps.find("名詞") < 0: continue # 名詞だけをカウント - 7
	    if not word in word_dic:
		    word_dic[word] = 0
	    word_dic[word] += 1
 
# よく使われる単語を表示 - 8
keys = sorted(word_dic.items(), key=lambda x:x[1], reverse=True)
for word, cnt in keys[:50]:
    print("{0}({1}) ".format(word,cnt), end="")
# Out:
#     プログラミング独学者でも効率的に学べる超絶お勧めの5つの勉強法をまとめてみた
# 		  		全取材あり！ | エンジニアになれるプログラミングスクールおすすめ5社まとめ
#                   プログラミング独学者でも効率的に学べる超絶お勧めの5つの勉強法をまとめてみた
#                           プログラミング初心者,プログラミング学習法
#                       ≪DAINOTE編集部推薦のDAIが実際に取材、体験してみて、特にオススメのプログラミングスクール一覧≫
# 【第1位】ポテパンキャンプ：サーバーサイドエンジニアに未経験から転職して年収700万円代を目指したい人向け！ | レビュー記事
# 【第2位】CodeCamp: 未経験から副業でWeb制作し、副業で月10万円ほどを目指したい人向け！業界最安値！ | レビュー記事
# 【第3位】TechAcademy:未経験から副業でWeb制作し、副業で月10万円ほどを目指したい人向け！ | レビュー記事
# 【第4位】デジタルハリウッドスタジオbyLIG：未経験からWebデザイナーとして転職した人向け！教室で学びたい人向け！ | レビュー記事
# 【第5位】Aidemy：Python・AIに特化したプログラミングスクール。 | レビュー記事
#
#
#
#
# 					転職で全額キャッシュバッグ。エンジニア転職したいなら絶対にココ
#
#
#
# 						ポテパンキャンプ：未経験からの就職実績がNo1のRuby特化スクール
#
#
#
#
#
# 						ポテパンキャンプの公式HPを確認する
#
#
#
#
#
#
#
#
#
# 					【副業特化 Web制作をするならココ！】
#
#
#
# 						CodeCamp: Web制作に特化したプログラミングスクール
#
#
#
#
#
# 						CodeCampで無料カウンセリングを受けてみる
#
#
#
#
#
#
#
#
#
# 					業界最安のプログラミングスクール
#
#
#
# 						TechAcademy:完全オフラインで学べる最も有名なプログラミングスクール
#
#
#
#
#
# 						TechAcademy Webデザインコースで無料体験してみる
#
#
#
#
#
#
#
#
#
# 					専門学校のコースが受けられる！
#
#
#
# 						デジタルハリウッドStudio by LIG
#
#
#
#
#
# 						デジタルハリウッドStudio by LIGを見てみる
#
#
#
#
#
#
#
#
#
# 					大学法人・東証一部上場企業も導入
#
#
#
# 						Aidemy: AI教育No1の実績。本気でAIを学びたいならココ！
#
#
#
#
#
# 						Aidemyで無料カウンセリングを受けてみる
#
#
#
#
#
# こんにちは！DAINOTE編集部のDAIです。
# 突然ですがプログラミングを学び始めの時って死ぬほど大変じゃないですか？プログラミングの学習って初心者だったときマジで非効率だったのを思い出しました。
# ここ最近はクラウドソーシングで案件取ったり、データ分析などをPythonでできるようになってきたのですが、最初の勉強方法とだいぶ変わってきたなぁと感じています。
#
# そこで、最近ツイッターで初心者の視点からよい学習方法を発信しているのですが、ツイートの中で反響が大きかったものをまとめました。プログラミングを独学でやっている人に、おすすめの学習方法についてです。
# 目次勉強法①. 作業ログをGithubのIssueに残す勉強法②. 2週間で基礎は終わらせる勉強法③. プロダクトベースのチュートリアルをやるRails チュートリアルTutorials PointsUdemyQiitaYoutube勉強法④. メンターに聞きながらトライアンドエラーをする仕事として通用するプログラミング力を得るためにはプログラミング独学で躓くポイントオススメのプログラミングスクール勉強法5. 自分のプロダクトを決めて作りはじめるその他 プログラミングを独学するうえでよくいただく質問「プログラミングを独学するなら、本の方がいいですか？Webの方がいいですか？」「プログラミングで独学するうえで、おすすめの言語を教えてください」まとめプログラミングスクールを選ぶなら
# 勉強法①. 作業ログをGithubのIssueに残す
# Githubはソースコード管理を行えるソフトウェアですが、その中でIssueという掲示板みたいなものがあります。そこに、どういう処理を行っていて、何がうまくいっていないのかを作業ログとして残しておくのがおすすめです。
#
# プログラミング初心者はGithubで作業ログ残してツイッターに連携して作業すると、優しいお兄さんたちがコメントしてくれるのですごくおすすめ。作業も可視化されるし、質問しなくても何しようとしているのか見てわかればこたえてくれやすくなる。
# &mdash; DAI (@never_be_a_pm) April 14, 2018
#
# GithubのIssueとは、簡単いいうと掲示板みたいなもので、そこで開発についてやりとりができるんですよね。それがソースコード管理システムである、Githubに標準機能としておいてあります。例がないとわかりにくいと思うので、こちらが僕がツイッターの自動化アプリを作っているときのイシューです。 こんな感じで、自分が作業をしているときのログを適宜張り付けています。
#
# これをやるのには2つメリットがあります。
# 一つは、プログラミングの作業ログを残せるので、自分が今どのような処理をしているのか言語化しながら確認することで、状況の理解がしやすくなるという点です。独学しているときの形跡が残せるので、後で見直すときにも使えます。
# もう一つが、ツイッター上で自分のプログラムをGithubのイシューを公開しておくと、だれか優しい人がぱっと見てヒントを出してくれたりするからです。
# ツイッター上だと、140文字しかないので、すべてを説明するには文字数が足りませんし、いきなり「ちょっと教えて」と見ず知らずの人に教えるのは正直ハードルが高いと思います。（しかも実際いいよ～なんて言ってくれる人も少ないと思います。）
# 勉強法②. 2週間で基礎は終わらせる
#
# プログラミング基礎は、Progateで十分です！これだけで十分独学可能です。
# ≫ https://prog-8.com
# 何カ月も基礎の本をず～とやっている人がいますが、Progateで学びたい言語をある程度勉強したら、さっさとプロダクトを創りましょう。基礎だけやってても球拾いだけやってるだけで、実際に野球ができるかって言われたら、実践詰まないとできないですよね。
# 本は、それを利用して学習を進めていくよりも、困った時のリファレンスとして使う側面が大きいです。普通にプログラミング学習の基礎を学びたいのであれば、実際に書きながら基礎を学べるProgateやAidemyなどのサイトを利用して、独学でやってみるのが一番早いです。
# たまにず～とProgateでレベル上げしている人がいるのですが、これはポケモンで言うとひたすらマサラタウンでてひたすらコラッタを倒し続けているような状態なので、早く外に出たほうがいいです。
# 勉強法③. プロダクトベースのチュートリアルをやる
# お勧めは、「～を作ろう！」系のチュートリアルをひたすらこなすのがよいです。
# 写経でもよいので、どういうアプリがどういう構造で作られていて、どういう風に作ることができるのか、ひたすら型を学んでいくのが一番効率的です。
# チュートリアルをある程度こなせるようになると、ある程度この機能を実装したい！と思ったときに、過去の経験から実装することができるようになります。
#
# プログラミングやって気づいたけど、作りたいものまず決めて、そこからそれに近いチュートリアルを訳わからないながら進め、細かいところ埋めて行くのが一番コスパよく学習できる気がする。スキル的にもモチベーション的にも。
# &mdash; DAI (@never_be_a_pm) November 7, 2017
#
# Rails チュートリアル
#
# ちなみに僕自身は最初にツイッターのクローンを作るRails チュートリアルをやりました。Railsチュートリアルは、
#
# Ruby on Railsでツイッターと同機能を持つ、クローンアプリを開発する
# 基本的なログイン機能、ツイート機能、いいね機能などを実装する
#
# など、Web アプリケーションを作成するうえで、必要なスキルをみにつけることができます。
# Tutorials Points
# その後海外のTutorial Pointsというサイトでいろいろなアプリのチュートリアルを何度もやりました。そうすると、だいたいこの機能を付けるためにはこれが必要だよね！ってことがわかってくるので、自然とどういう風に設計すればよいのかイメージができるようになります。ただし全部英語ですので、英語力に自信がある人はぜひ！
# ≫https://www.tutorialspoint.com/
# Udemy
#
# 英語じゃきつい！って人へ。日本語化されているコンテンツでいうと、Udemyもけっこういいです。Udemyは動画で0からプロダクトを創れるチュートリアルを公開していますね！Udemyの動画はかなり質が高いので、お勧めです。あとYoutubeとかでも動画でチュートリアルがあがってたりしますのでおすすめですね。ネットにはなかなか落ちていないような情報が、包括的にまとまっているのでお勧めですね！
# Udemyでプロダクトを創る過程を通勤中に見て、土日に実際に写経しながらっ進めるってやり方を一時期やってましたが、かなり効率がよかったです。ちなみに、これ以外で日本語化されているコンテンツは日本には圧倒的に少ないので、注意が必要です。
# あと、個人的には動画だと理解しきれずに話が進んでしまうので、あまり動画は好きではないです。僕は基本的にはテキストでじっくりコードを理解したい派です。なので、初心者でも圧倒的にわかりやすくプロダクトが作れるチュートリアルシリーズを何個か書いています。いろいろ用意していますが、Pythonでクラウドソーシングで案件が取れるようなチュートリアルもあるので、もしよかったら読んでみてください！
# Qiita
#
# Qiitaは、エンジニア向けの技術発信プラットフォームです。ここで検索機能がありまして、「〇〇　チュートリアル」と検索すると、たまに包括的にわかりやすいチュートリアルが出てくることがあります。
# チュートリアルとして使う以外にも、プログラミングの学習ログとして使うヒトもいらっしゃいます。エンジニアであれ、独学の学習者であれ、みんなが使えますね。
# Youtube
# Youtubeは実は知られていないのですが、チュートリアルがたくさんあります。いくつか参考を。
#
# Python Django Web Framework &#8211; Full Course for Beginners
# 0から手を動かして作るRailsチャットアプリ【チュートリアル】
# Flaskチュートリアル ①Pythonでツイッターの分析ツールを作ってディプロイしよう！
#
# 勉強法④. メンターに聞きながらトライアンドエラーをする
# チュートリアルをやっていると、Progateなどで学習するときと違って詰むようになります。
# よくわからないエラーが出てきたり、チュートリアル通りにやってもうまくいかなかったときに、独学だとしんどいな！と思うときがあると思うんですよね。そういう場合は、特に最初はプログラミングのメンターが必要かと思います。
#
# プログラミング最初本当に訳わからなかったけど、やっとわかるようになった時の学習方法は
# ・何を作りたいのか決める・何を学べばできるのかメンターに聞く・そこから学習ルート決めてもらって、ひたすらコード書く・つまづいたらメンターに聞く
# でした。これでだいぶ変わります。
# &mdash; DAI (@never_be_a_pm) April 10, 2018
#
# で、プログラミングのメンターをどうやって見つけらえるかというと、大きく分けて3つくらい選択肢があると思います。ちなみに学生の場合は
# 1. 自分の友達でプログラミングをできる人にお願いする
# 2. プログラミングを学べるインターンに行く
# 3. 有料のプログラミング学習スクールに行く
# が鉄板です。1の場合はめっちゃラッキーなので、土下座して頼みましょう。
# 2の場合は、ある程度自分でプロダクトを創れるなら、プログラミングで実際に何かを作れた証拠をもって、インターン受けにいくのがおすすめです。
# 1, 2の選択肢が取れない場合は、有料のプログラミングスクールに行くのがおすすめです。有料のプログラミングスクールであれば、メンターと教材がそろっているので、非常に効率的に学ぶことができます。
# 仕事として通用するプログラミング力を得るためには
# 仕事としてプログラミングで稼ぐなら、以下のことができるようになる必要があります。
#
# 顧客から信頼を勝ち取って、営業するスキル
# 顧客の要件を定義してあげて、相手が本当に欲しいものをヒアリングする能力
# 実際に成果物を作成する能力
#
# また、実際にエンジニアとして就職を考えるのであれば、実際に面接ではオリジナルアプリを作ったことがあるか間違いなく問われますので、必ずオリジナルアプリの一つはできるようにしておきましょう。
# プログラミング独学で躓くポイント
# プログラミングの独学で躓くポイントとしては、以下の通りです。
#
# 次に何を学べばいいかがわからなくなる
# エラーが起きたときにどう解決すればいいかわからなくなる
# 仕事を獲得するためにどういう風に営業したらいいかわからなくなる
# エンジニア採用の就職活動でエンジニアがどういうことを期待しているのか理解できない
#
# これらの問題がもし起こっているなら、プログラミングスクールに行ってみるのもひとつかと思います（私自身もプログラミングスクール経営者のサポートがあってから、2倍のペースで学習が進むようになりました。）
# オススメのプログラミングスクール
# おすすめのプログラミングスクールは、以下3スクールとなります。
#
# Tech Academy: 大学生や、忙しい社会人にお勧め。完全オンラインで学べる、プログラミングスクール。
# CodeCamp: Web制作に特化しているプログラミングスクール。こちらも完全オンラインで学べます。現役プログラマーの指導つき。
# ポテパンキャンプ：ガチでエンジニアに転職・就職したい人におすすめ。安いけどしっかりコミットしないと離脱します。
#
#
#
#
#
# 					業界最安のプログラミングスクール
#
#
#
# 						TechAcademy:完全オフラインで学べる最も有名なプログラミングスクール
#
#
#
#
#
# 						TechAcademy Webデザインコースで無料体験してみる
#
#
#
#
#
#
#
#
#
# 					【副業特化 Web制作をするならココ！】
#
#
#
# 						CodeCamp: Web制作に特化したプログラミングスクール
#
#
#
#
#
# 						CodeCampで無料カウンセリングを受けてみる
#
#
#
#
#
#
#
#
#
# 					転職で全額キャッシュバッグ。エンジニア転職したいなら絶対にココ
#
#
#
# 						ポテパンキャンプ：未経験からの就職実績がNo1のRuby特化スクール
#
#
#
#
#
# 						ポテパンキャンプの公式HPを確認する
#
#
#
#
#
# それぞれ、実際の利用者の人にインタビューした記事があります。
#
# 【Tech Academyの評判は？】Tech Academyを受講して、エンジニアに転職された卒業生にインタビューしてみた【PR】
# CodeCamp(コードキャンプ)の評判・レビュー・口コミは？実際に受講して確かめてみた！【PR】
# 【ポテパン・キャンプの評判は？】ポテパン・キャンプを受講して、エンジニアに転職された卒業生にインタビューしてみた【PR】
#
# 僕も学生の時にもっと早くプログラミングはじめてたら、Tech Academyに行ってたかな。業界最安値ですね。
# TechAcademy Webデザインコースで無料体験してみる
# 副業でWeb制作してみようかなぁ～って感じなら、CodeCampが非常によいと思います。実際にWordPressコースなど、Web制作に特化したコースがたくさんあるのでおすすめですね。
# CodeCampで無料カウンセリングを受けてみる
# 学生ではなく、社会人でガチでエンジニア転職一本で考えているのであれば、絶対にポテパンです。ポテパンはメンターがついて、ECサイトをゼロから作るというチュートリアルを持っています。
# ポテパンの何がすごいかというと、まずプログラミングの基礎を学んでいない人はとらないということ、そして授業である程度コースを完了すると、それが認定証となり、転職にそのままつながるところです。
# そして、転職がみごと完了すると、普通に授業料がキャッシュバックされるということですね。この仕組みをやっているのは、エンジニア教育企業初なので、非常によくできていると思います。まだ面接とかはやっているので、気になる人はぜひ連絡してみるのがいいと思います。社会人ならポテパン一択だと思います。
# ポテパンキャンプの公式HPを確認する
# 勉強法5. 自分のプロダクトを決めて作りはじめる
# 先に作りたいもの決めて勧めたほうがよいです。モチベーション的に。
# 僕はもう、最初のRailsチュートリアル終わった後に、出会い系サイト作りたいというのを明確に決めていたので、出会い系サイトを作るためには、ログイン、メッセージ機能、フレンド申請機能等が必要だな～なんて思ったので、それができるチュートリアルを探して、すべての機能がイメージが付いたら、実装に取り掛かってました。
# 今でも新しいことを試すときには使っている方法ですね。例えば、VRも最近アプリを作ったのですが、空を飛びたかったので Youtubeで「VR FLY」と調べて出てきたチュートリアルで学び始めて、実際C#とか書いたことなかったけど、それで一つアプリを作ることができるようになりました。
# その他 プログラミングを独学するうえでよくいただく質問
# プログラミングを独学して身に付けるうえで、よくいただく質問についてご回答します。
# 「プログラミングを独学するなら、本の方がいいですか？Webの方がいいですか？」
# 目的によるのですが、初学者がプログラミングを独学するなら、圧倒的にWebの方がよいです。理由は3点。
#
# 本の内容が古く、今では通用しない可能性があるが、プログラミング初心者だとそれを見抜くのが難しい
# 書籍代金が非常に高いので、費用対効果が悪い。特に入門書はどれも変わらない。
# テキストを開きながら、コードを写経するのが難しい
#
# 上記の理由から、本で独学するよりは、ProgateやUdemyなどで学んだほうがお得かと思います。
# 「プログラミングで独学するうえで、おすすめの言語を教えてください」
# こちらも目的によって大きく変わるのですが、
#
# Web制作：HTML, CSS, JavaScript, PHP, WordPress
# Webアプリ開発：HTML, CSS, JavaScript, Ruby, Ruby on Rails
#
# あたりがおすすめです。
# まとめ
# ということで、プログラミングを独学で勉強するときにお勧めな方法は
# 1. 作業ログをGithubのIssueに残す
# 2. 2週間で基礎は終わらせる
# 3. チュートリアルをやる
# 4. メンターに聞きながらトライアンドエラーをする
# 5. 自分のプロダクトを決めて作りはじめる
# でした！
# 副業や、就職活動まで含めて、考えていて、「独学だとちょっときついなぁ」とう方は、実際にプログラミングスクールに行ってみるといいと思います。
# Web制作をしたいなら、TechAcademyとCodeCamp、エンジニア転職までがっつりと考えているのであれば、ポテパンキャンプがよいと思います。
#
# Tech Academy: 大学生や、忙しい社会人にお勧め。完全オンラインで学べる、プログラミングスクール。
# CodeCamp: Web制作に特化しているプログラミングスクール。こちらも完全オンラインで学べます。現役プログラマーの指導つき。
# ポテパンキャンプ：ガチでエンジニアに転職・就職したい人におすすめ。安いけどしっかりコミットしないと離脱します。
#
# プログラミングスクールを選ぶなら
# 正直、プログラミングスクールを選ぶと、アフィリエイト記事の評判ばかりなので本当に受講した人の声が聞けないです。
# そこで、実際に私自身がスクールを実際に体験したり、プログラミングスクールの卒業生に独占インタビューした内容を記事にまとめました。
# その中で、特に評価が高く、値段も比較的にお手頃なスクールを厳選して紹介した記事があるので、興味があるひとはみてください！
# &nbsp;
#
# &nbsp;
#
#
#
#
#
#
#
#
#
#
#         こちらもおすすめ
#
#
#
#
#
#                               【体験談まとめ】プログラミングスクールで受講者がおすすめした厳選5社を一挙解説【全インタビュー付き】
#
#
#                             2019/01/31
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                               【保存版】Python・機械学習・人工知能（AI）を仕事にできるプログラミングスクール3選
#
#
#                             2018/09/01
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                               【副業したいプログラマーへ！】未経験から在宅副業プログラミングで月10万円稼ぐ方法をまとめてみた　【どのくらいの収入がもらえるかもデータにしてみたよ！】
#
#
#                             2018/07/26
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 PR記事【取材あり】
#
#
#
#
#
#
#                         2019/06/06
#                         デジタルハリウッドSTUDIO by LIGを受講して感じたこと一挙まとめてみた！
#
#
#
#
#
#
#
#
#                         2019/01/26
#                         【体験談】Aidemyの口コミ・評判は？受講し転職した卒業生に直撃インタビューしてみた【PR】
#
#
#
#
#
#
#
#
#                         2019/01/23
#                         【体験談】Tech Boostの口コミ・評判は？受講してエンジニアに転職した卒業生にインタビューしてみた【PR】
#
#
#
#
#
#
#
#
#                         2019/01/21
#                         【体験談】TechAcademyの評判を確かめにエンジニアに転職された卒業生にインタビュー【PR】
#
#
#
#
#
#
#
# 						DAI
#
#
#
#
#
# 					プログラミングとかデータアナリティクスとかマーケティングとかコンテンツマーケとかSNSとか好きなフリーランス。KADOKAWAさんから著書『独学プログラマーのためのAIアプリ開発がわかる本』が出ました。 ICU卒
#
# 						プロフィールを見る
#
# 					カテゴリ
# 				AI
#
# 	GoogleAppsScript
#
# 	IT副業
#
# 	Other
#
# 	Python
#
# 	R
#
# 	redash
#
# 	Ruby
#
# 	Webデザイン
#
# 	WordPress
#
# 	アフィリエイト
#
# 	キャリア
#
# 	クラウドソーシング
#
# 	フリーランス
#
# 	プログラミング 独学
#
# 	プログラミングスクール
#
# 	プログラミング初心者
#
# 	プログラミング学習法
#
# 	マーケティング
#
#
# 							最近の投稿
#
# 					IT系のフリーランスの職種と案件の獲得方法についてまとめてみた
#
#
# 					Webライターが副業するならおすすめという話と、仕事の取り方についてまとめてみた
#
#
# 					Webディレクターへの転職におすすめしたい転職エージェントは？ディレクター職の仕事の選び方をまとめてみた
#
#
# 					Webディレクターの副業は？仕事の取り方からオススメのエージェントまでまとめてみた
#
#
# 					エンジニア転職を始める前に！知っておきたい業界知識を、採用担当と開発会社CEOにインタビューしてみた
#
#
# 					【保存版】統計学のおすすめ書籍8選 | 文系からでも基礎を理解するのに役立つ書籍をピックアップ！
#
#
# 					フリーランスの案件は？職種別に仕事のとり方と案件紹介サイトをまとめてみた
#
#
# 					【保存版】WordPress初心者が独学でWebサイトを作るために必要な6つの学習ステップまとめ
#
#
# 					【体験談】プログラミングを学んでフリーランスになる方法をまとめてみた
#
#
# 					【体験談】第二新卒での転職で、未経験職でも成功するための3つの方法をまとめてみた
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# 独学	名詞,サ変接続,*,*,*,*,独学,ドクガク,ドクガク
# 者	名詞,接尾,一般,*,*,*,者,シャ,シャ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 効率	名詞,一般,*,*,*,*,効率,コウリツ,コーリツ
# 的	名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# 学べる	動詞,自立,*,*,一段,基本形,学べる,マナベル,マナベル
# 超絶	名詞,サ変接続,*,*,*,*,超絶,チョウゼツ,チョーゼツ
# お	接頭詞,名詞接続,*,*,*,*,お,オ,オ
# 勧め	名詞,一般,*,*,*,*,勧め,ススメ,ススメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 5	名詞,数,*,*,*,*,5,*,*
# つ	助動詞,*,*,*,下二・タ行,基本形,つ,ツ,ツ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 勉強	名詞,サ変接続,*,*,*,*,勉強,ベンキョウ,ベンキョー
# 法	名詞,接尾,一般,*,*,*,法,ホウ,ホー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# まとめ	動詞,自立,*,*,一段,連用形,まとめる,マトメ,マトメ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
#
# 		  			記号,空白,*,*,*,*,
# 		  		,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# 取材	名詞,サ変接続,*,*,*,*,取材,シュザイ,シュザイ
# あり	動詞,自立,*,*,ラ変,基本形,あり,アリ,アリ
# ！	記号,一般,*,*,*,*,！,！,！
#  	記号,空白,*,*,*,*, ,*,*
# |	名詞,サ変接続,*,*,*,*,|,*,*
#  	記号,空白,*,*,*,*, ,*,*
# エンジニア	名詞,一般,*,*,*,*,エンジニア,エンジニア,エンジニア
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なれる	動詞,自立,*,*,一段,基本形,なれる,ナレル,ナレル
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# スクール	名詞,一般,*,*,*,*,スクール,スクール,スクール
# おすすめ	名詞,サ変接続,*,*,*,*,おすすめ,オススメ,オススメ
# 5	名詞,数,*,*,*,*,5,*,*
# 社	名詞,接尾,助数詞,*,*,*,社,シャ,シャ
# まとめ	動詞,自立,*,*,一段,連用形,まとめる,マトメ,マトメ
#
#                   	記号,空白,*,*,*,*,
#                   ,*,*
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# 独学	名詞,サ変接続,*,*,*,*,独学,ドクガク,ドクガク
# 者	名詞,接尾,一般,*,*,*,者,シャ,シャ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 効率	名詞,一般,*,*,*,*,効率,コウリツ,コーリツ
# 的	名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# 学べる	動詞,自立,*,*,一段,基本形,学べる,マナベル,マナベル
# 超絶	名詞,サ変接続,*,*,*,*,超絶,チョウゼツ,チョーゼツ
# お	接頭詞,名詞接続,*,*,*,*,お,オ,オ
# 勧め	名詞,一般,*,*,*,*,勧め,ススメ,ススメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 5	名詞,数,*,*,*,*,5,*,*
# つ	助動詞,*,*,*,下二・タ行,基本形,つ,ツ,ツ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 勉強	名詞,サ変接続,*,*,*,*,勉強,ベンキョウ,ベンキョー
# 法	名詞,接尾,一般,*,*,*,法,ホウ,ホー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# まとめ	動詞,自立,*,*,一段,連用形,まとめる,マトメ,マトメ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
#
#                           	記号,空白,*,*,*,*,
#                           ,*,*
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# 初心者	名詞,一般,*,*,*,*,初心者,ショシンシャ,ショシンシャ
# ,	名詞,サ変接続,*,*,*,*,,,*,*
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# 学習	名詞,サ変接続,*,*,*,*,学習,ガクシュウ,ガクシュー
# 法	名詞,接尾,一般,*,*,*,法,ホウ,ホー
#
#                       	記号,空白,*,*,*,*,
#                       ,*,*
# ≪	名詞,サ変接続,*,*,*,*,≪,*,*
# DAINOTE	名詞,一般,*,*,*,*,DAINOTE,*,*
# 編集	名詞,サ変接続,*,*,*,*,編集,ヘンシュウ,ヘンシュー
# 部	名詞,接尾,一般,*,*,*,部,ブ,ブ
# 推薦	名詞,サ変接続,*,*,*,*,推薦,スイセン,スイセン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# DAI	名詞,一般,*,*,*,*,DAI,*,*
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 実際	副詞,助詞類接続,*,*,*,*,実際,ジッサイ,ジッサイ
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# 取材	名詞,サ変接続,*,*,*,*,取材,シュザイ,シュザイ
# 、	記号,読点,*,*,*,*,、,、,、
# 体験	名詞,サ変接続,*,*,*,*,体験,タイケン,タイケン
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 特に	副詞,一般,*,*,*,*,特に,トクニ,トクニ
# オススメ	名詞,サ変接続,*,*,*,*,オススメ,オススメ,オススメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# スクール	名詞,一般,*,*,*,*,スクール,スクール,スクール
# 一覧	名詞,サ変接続,*,*,*,*,一覧,イチラン,イチラン
# ≫	名詞,サ変接続,*,*,*,*,≫,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# 第	接頭詞,数接続,*,*,*,*,第,ダイ,ダイ
# 1	名詞,数,*,*,*,*,1,*,*
# 位	名詞,接尾,助数詞,*,*,*,位,イ,イ
# 】	記号,括弧閉,*,*,*,*,】,】,】
# ポテパンキャンプ	名詞,一般,*,*,*,*,ポテパンキャンプ,*,*
# ：	記号,一般,*,*,*,*,：,：,：
# サーバーサイドエンジニア	名詞,一般,*,*,*,*,サーバーサイドエンジニア,*,*
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 未	接頭詞,名詞接続,*,*,*,*,未,ミ,ミ
# 経験	名詞,サ変接続,*,*,*,*,経験,ケイケン,ケイケン
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# 転職	名詞,サ変接続,*,*,*,*,転職,テンショク,テンショク
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 年収	名詞,一般,*,*,*,*,年収,ネンシュウ,ネンシュー
# 700	名詞,数,*,*,*,*,700,*,*
# 万	名詞,数,*,*,*,*,万,マン,マン
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
# 代	名詞,接尾,一般,*,*,*,代,ダイ,ダイ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 目指し	動詞,自立,*,*,五段・サ行,連用形,目指す,メザシ,メザシ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# 向け	名詞,接尾,一般,*,*,*,向け,ムケ,ムケ
# ！	記号,一般,*,*,*,*,！,！,！
#  	記号,空白,*,*,*,*, ,*,*
# |	名詞,サ変接続,*,*,*,*,|,*,*
#  	記号,空白,*,*,*,*, ,*,*
# レビュー	名詞,サ変接続,*,*,*,*,レビュー,レビュー,レビュー
# 記事	名詞,一般,*,*,*,*,記事,キジ,キジ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# 第	接頭詞,数接続,*,*,*,*,第,ダイ,ダイ
# 2	名詞,数,*,*,*,*,2,*,*
# 位	名詞,接尾,助数詞,*,*,*,位,イ,イ
# 】	記号,括弧閉,*,*,*,*,】,】,】
# CodeCamp	名詞,固有名詞,組織,*,*,*,CodeCamp,*,*
# :	名詞,サ変接続,*,*,*,*,:,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 未	接頭詞,名詞接続,*,*,*,*,未,ミ,ミ
# 経験	名詞,サ変接続,*,*,*,*,経験,ケイケン,ケイケン
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# 副業	名詞,一般,*,*,*,*,副業,フクギョウ,フクギョー
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# Web	名詞,一般,*,*,*,*,Web,*,*
# 制作	名詞,サ変接続,*,*,*,*,制作,セイサク,セイサク
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# 、	記号,読点,*,*,*,*,、,、,、
# 副業	名詞,一般,*,*,*,*,副業,フクギョウ,フクギョー
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 月	名詞,一般,*,*,*,*,月,ツキ,ツキ
# 10	名詞,数,*,*,*,*,10,*,*
# 万	名詞,数,*,*,*,*,万,マン,マン
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
# ほど	助詞,副助詞,*,*,*,*,ほど,ホド,ホド
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 目指し	動詞,自立,*,*,五段・サ行,連用形,目指す,メザシ,メザシ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# 向け	名詞,接尾,一般,*,*,*,向け,ムケ,ムケ
# ！	記号,一般,*,*,*,*,！,！,！
# 業界	名詞,一般,*,*,*,*,業界,ギョウカイ,ギョーカイ
# 最	接頭詞,名詞接続,*,*,*,*,最,サイ,サイ
# 安値	名詞,一般,*,*,*,*,安値,ヤスネ,ヤスネ
# ！	記号,一般,*,*,*,*,！,！,！
#  	記号,空白,*,*,*,*, ,*,*
# |	名詞,サ変接続,*,*,*,*,|,*,*
#  	記号,空白,*,*,*,*, ,*,*
# レビュー	名詞,サ変接続,*,*,*,*,レビュー,レビュー,レビュー
# 記事	名詞,一般,*,*,*,*,記事,キジ,キジ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# 第	接頭詞,数接続,*,*,*,*,第,ダイ,ダイ
# 3	名詞,数,*,*,*,*,3,*,*
# 位	名詞,接尾,助数詞,*,*,*,位,イ,イ
# 】	記号,括弧閉,*,*,*,*,】,】,】
# TechAcademy	名詞,固有名詞,組織,*,*,*,TechAcademy,*,*
# :	名詞,サ変接続,*,*,*,*,:,*,*
# 未	接頭詞,名詞接続,*,*,*,*,未,ミ,ミ
# 経験	名詞,サ変接続,*,*,*,*,経験,ケイケン,ケイケン
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# 副業	名詞,一般,*,*,*,*,副業,フクギョウ,フクギョー
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# Web	名詞,一般,*,*,*,*,Web,*,*
# 制作	名詞,サ変接続,*,*,*,*,制作,セイサク,セイサク
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# 、	記号,読点,*,*,*,*,、,、,、
# 副業	名詞,一般,*,*,*,*,副業,フクギョウ,フクギョー
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 月	名詞,一般,*,*,*,*,月,ツキ,ツキ
# 10	名詞,数,*,*,*,*,10,*,*
# 万	名詞,数,*,*,*,*,万,マン,マン
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
# ほど	助詞,副助詞,*,*,*,*,ほど,ホド,ホド
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 目指し	動詞,自立,*,*,五段・サ行,連用形,目指す,メザシ,メザシ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# 向け	名詞,接尾,一般,*,*,*,向け,ムケ,ムケ
# ！	記号,一般,*,*,*,*,！,！,！
#  	記号,空白,*,*,*,*, ,*,*
# |	名詞,サ変接続,*,*,*,*,|,*,*
#  	記号,空白,*,*,*,*, ,*,*
# レビュー	名詞,サ変接続,*,*,*,*,レビュー,レビュー,レビュー
# 記事	名詞,一般,*,*,*,*,記事,キジ,キジ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# 第	接頭詞,数接続,*,*,*,*,第,ダイ,ダイ
# 4	名詞,数,*,*,*,*,4,*,*
# 位	名詞,接尾,助数詞,*,*,*,位,イ,イ
# 】	記号,括弧閉,*,*,*,*,】,】,】
# デジタルハリウッドスタジオ	名詞,固有名詞,一般,*,*,*,デジタルハリウッドスタジオ,*,*
# byLIG	名詞,一般,*,*,*,*,byLIG,*,*
# ：	記号,一般,*,*,*,*,：,：,：
# 未	接頭詞,名詞接続,*,*,*,*,未,ミ,ミ
# 経験	名詞,サ変接続,*,*,*,*,経験,ケイケン,ケイケン
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# Web	名詞,固有名詞,組織,*,*,*,Web,*,*
# デザイナー	名詞,一般,*,*,*,*,デザイナー,デザイナー,デザイナー
# として	助詞,格助詞,連語,*,*,*,として,トシテ,トシテ
# 転職	名詞,サ変接続,*,*,*,*,転職,テンショク,テンショク
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# 向け	名詞,接尾,一般,*,*,*,向け,ムケ,ムケ
# ！	記号,一般,*,*,*,*,！,！,！
# 教室	名詞,一般,*,*,*,*,教室,キョウシツ,キョーシツ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 学び	動詞,自立,*,*,五段・バ行,連用形,学ぶ,マナビ,マナビ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# 向け	名詞,接尾,一般,*,*,*,向け,ムケ,ムケ
# ！	記号,一般,*,*,*,*,！,！,！
#  	記号,空白,*,*,*,*, ,*,*
# |	名詞,サ変接続,*,*,*,*,|,*,*
#  	記号,空白,*,*,*,*, ,*,*
# レビュー	名詞,サ変接続,*,*,*,*,レビュー,レビュー,レビュー
# 記事	名詞,一般,*,*,*,*,記事,キジ,キジ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# 第	接頭詞,数接続,*,*,*,*,第,ダイ,ダイ
# 5	名詞,数,*,*,*,*,5,*,*
# 位	名詞,接尾,助数詞,*,*,*,位,イ,イ
# 】	記号,括弧閉,*,*,*,*,】,】,】
# Aidemy	名詞,固有名詞,組織,*,*,*,Aidemy,*,*
# ：	記号,一般,*,*,*,*,：,：,：
# Python	名詞,固有名詞,組織,*,*,*,Python,*,*
# ・	記号,一般,*,*,*,*,・,・,・
# AI	名詞,固有名詞,組織,*,*,*,AI,*,*
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 特	名詞,一般,*,*,*,*,特,トク,トク
# 化	名詞,接尾,サ変接続,*,*,*,化,カ,カ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# スクール	名詞,一般,*,*,*,*,スクール,スクール,スクール
# 。	記号,句点,*,*,*,*,。,。,。
#  	記号,空白,*,*,*,*, ,*,*
# |	名詞,サ変接続,*,*,*,*,|,*,*
#  	記号,空白,*,*,*,*, ,*,*
# レビュー	名詞,サ変接続,*,*,*,*,レビュー,レビュー,レビュー
# 記事	名詞,一般,*,*,*,*,記事,キジ,キジ
#
#
#
#
#
# 						記号,空白,*,*,*,*,
#
#
#
#
# 					,*,*
# 転職	名詞,サ変接続,*,*,*,*,転職,テンショク,テンショク
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 全額	名詞,一般,*,*,*,*,全額,ゼンガク,ゼンガク
# キャッシュ	名詞,一般,*,*,*,*,キャッシュ,キャッシュ,キャッシュ
# バッグ	名詞,一般,*,*,*,*,バッグ,バッグ,バッグ
# 。	記号,句点,*,*,*,*,。,。,。
# エンジニア	名詞,一般,*,*,*,*,エンジニア,エンジニア,エンジニア
# 転職	名詞,サ変接続,*,*,*,*,転職,テンショク,テンショク
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# なら	助動詞,*,*,*,特殊・ダ,仮定形,だ,ナラ,ナラ
# 絶対	名詞,副詞可能,*,*,*,*,絶対,ゼッタイ,ゼッタイ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# ココ	名詞,一般,*,*,*,*,ココ,*,*
#
#
#
#
# 							記号,空白,*,*,*,*,
#
#
#
# 						,*,*
# ポテパンキャンプ	名詞,一般,*,*,*,*,ポテパンキャンプ,*,*
# ：	記号,一般,*,*,*,*,：,：,：
# 未	接頭詞,名詞接続,*,*,*,*,未,ミ,ミ
# 経験	名詞,サ変接続,*,*,*,*,経験,ケイケン,ケイケン
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 就職	名詞,サ変接続,*,*,*,*,就職,シュウショク,シューショク
# 実績	名詞,一般,*,*,*,*,実績,ジッセキ,ジッセキ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# No	名詞,一般,*,*,*,*,No,*,*
# 1	名詞,数,*,*,*,*,1,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# Ruby	名詞,一般,*,*,*,*,Ruby,*,*
# 特	名詞,一般,*,*,*,*,特,トク,トク
# 化	名詞,接尾,サ変接続,*,*,*,化,カ,カ
# スクール	名詞,一般,*,*,*,*,スクール,スクール,スクール
#
#
#
#
#
#
# 							記号,空白,*,*,*,*,
#
#
#
#
#
# 						,*,*
# ポテパンキャンプ	名詞,一般,*,*,*,*,ポテパンキャンプ,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 公式	名詞,形容動詞語幹,*,*,*,*,公式,コウシキ,コーシキ
# HP	名詞,一般,*,*,*,*,HP,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 確認	名詞,サ変接続,*,*,*,*,確認,カクニン,カクニン
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
#
#
#
#
#
#
#
#
#
#
# 						記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
#
# 					,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# 副業	名詞,一般,*,*,*,*,副業,フクギョウ,フクギョー
# 特	名詞,一般,*,*,*,*,特,トク,トク
# 化	名詞,接尾,サ変接続,*,*,*,化,カ,カ
#  	記号,空白,*,*,*,*, ,*,*
# Web	名詞,固有名詞,組織,*,*,*,Web,*,*
# 制作	名詞,サ変接続,*,*,*,*,制作,セイサク,セイサク
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# なら	助動詞,*,*,*,特殊・ダ,仮定形,だ,ナラ,ナラ
# ココ	名詞,一般,*,*,*,*,ココ,*,*
# ！	記号,一般,*,*,*,*,！,！,！
# 】	記号,括弧閉,*,*,*,*,】,】,】
#
#
#
#
# 							記号,空白,*,*,*,*,
#
#
#
# 						,*,*
# CodeCamp	名詞,固有名詞,組織,*,*,*,CodeCamp,*,*
# :	名詞,サ変接続,*,*,*,*,:,*,*
#  	記号,空白,*,*,*,*, ,*,*
# Web	名詞,固有名詞,組織,*,*,*,Web,*,*
# 制作	名詞,サ変接続,*,*,*,*,制作,セイサク,セイサク
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 特	名詞,一般,*,*,*,*,特,トク,トク
# 化	名詞,接尾,サ変接続,*,*,*,化,カ,カ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# スクール	名詞,一般,*,*,*,*,スクール,スクール,スクール
#
#
#
#
#
#
# 							記号,空白,*,*,*,*,
#
#
#
#
#
# 						,*,*
# CodeCamp	名詞,一般,*,*,*,*,CodeCamp,*,*
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 無料	名詞,一般,*,*,*,*,無料,ムリョウ,ムリョー
# カウンセリング	名詞,一般,*,*,*,*,カウンセリング,カウンセリング,カウンセリング
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 受け	動詞,自立,*,*,一段,連用形,受ける,ウケ,ウケ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# みる	動詞,非自立,*,*,一段,基本形,みる,ミル,ミル
#
#
#
#
#
#
#
#
#
#
# 						記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
#
# 					,*,*
# 業界	名詞,一般,*,*,*,*,業界,ギョウカイ,ギョーカイ
# 最	接頭詞,名詞接続,*,*,*,*,最,サイ,サイ
# 安	名詞,一般,*,*,*,*,安,ヤス,ヤス
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# スクール	名詞,一般,*,*,*,*,スクール,スクール,スクール
#
#
#
#
# 							記号,空白,*,*,*,*,
#
#
#
# 						,*,*
# TechAcademy	名詞,固有名詞,組織,*,*,*,TechAcademy,*,*
# :	名詞,サ変接続,*,*,*,*,:,*,*
# 完全	名詞,形容動詞語幹,*,*,*,*,完全,カンゼン,カンゼン
# オフライン	名詞,一般,*,*,*,*,オフライン,オフライン,オフライン
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 学べる	動詞,自立,*,*,一段,基本形,学べる,マナベル,マナベル
# 最も	副詞,一般,*,*,*,*,最も,モットモ,モットモ
# 有名	名詞,形容動詞語幹,*,*,*,*,有名,ユウメイ,ユーメイ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# スクール	名詞,一般,*,*,*,*,スクール,スクール,スクール
#
#
#
#
#
#
# 							記号,空白,*,*,*,*,
#
#
#
#
#
# 						,*,*
# TechAcademy	名詞,固有名詞,組織,*,*,*,TechAcademy,*,*
#  	記号,空白,*,*,*,*, ,*,*
# Web	名詞,固有名詞,組織,*,*,*,Web,*,*
# デザイン	名詞,サ変接続,*,*,*,*,デザイン,デザイン,デザイン
# コース	名詞,一般,*,*,*,*,コース,コース,コース
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 無料	名詞,一般,*,*,*,*,無料,ムリョウ,ムリョー
# 体験	名詞,サ変接続,*,*,*,*,体験,タイケン,タイケン
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# みる	動詞,非自立,*,*,一段,基本形,みる,ミル,ミル
#
#
#
#
#
#
#
#
#
#
# 						記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
#
# 					,*,*
# 専門	名詞,一般,*,*,*,*,専門,センモン,センモン
# 学校	名詞,一般,*,*,*,*,学校,ガッコウ,ガッコー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# コース	名詞,一般,*,*,*,*,コース,コース,コース
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 受け	動詞,自立,*,*,一段,未然形,受ける,ウケ,ウケ
# られる	動詞,接尾,*,*,一段,基本形,られる,ラレル,ラレル
# ！	記号,一般,*,*,*,*,！,！,！
#
#
#
#
# 							記号,空白,*,*,*,*,
#
#
#
# 						,*,*
# デジタル	名詞,一般,*,*,*,*,デジタル,デジタル,デジタル
# ハリウッド	名詞,固有名詞,地域,一般,*,*,ハリウッド,ハリウッド,ハリウッド
# Studio	名詞,固有名詞,組織,*,*,*,Studio,*,*
#  	記号,空白,*,*,*,*, ,*,*
# by	名詞,固有名詞,組織,*,*,*,by,*,*
#  	記号,空白,*,*,*,*, ,*,*
# LIG	名詞,固有名詞,組織,*,*,*,LIG,*,*
#
#
#
#
#
#
# 							記号,空白,*,*,*,*,
#
#
#
#
#
# 						,*,*
# デジタル	名詞,一般,*,*,*,*,デジタル,デジタル,デジタル
# ハリウッド	名詞,固有名詞,地域,一般,*,*,ハリウッド,ハリウッド,ハリウッド
# Studio	名詞,固有名詞,組織,*,*,*,Studio,*,*
#  	記号,空白,*,*,*,*, ,*,*
# by	名詞,固有名詞,組織,*,*,*,by,*,*
#  	記号,空白,*,*,*,*, ,*,*
# LIG	名詞,一般,*,*,*,*,LIG,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# みる	動詞,非自立,*,*,一段,基本形,みる,ミル,ミル
#
#
#
#
#
#
#
#
#
#
# 						記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
#
# 					,*,*
# 大学	名詞,一般,*,*,*,*,大学,ダイガク,ダイガク
# 法人	名詞,一般,*,*,*,*,法人,ホウジン,ホージン
# ・	記号,一般,*,*,*,*,・,・,・
# 東証	名詞,固有名詞,組織,*,*,*,東証,トウショウ,トーショー
# 一部	名詞,副詞可能,*,*,*,*,一部,イチブ,イチブ
# 上場	名詞,サ変接続,*,*,*,*,上場,ジョウジョウ,ジョージョー
# 企業	名詞,一般,*,*,*,*,企業,キギョウ,キギョー
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 導入	名詞,サ変接続,*,*,*,*,導入,ドウニュウ,ドーニュー
#
#
#
#
# 							記号,空白,*,*,*,*,
#
#
#
# 						,*,*
# Aidemy	名詞,固有名詞,組織,*,*,*,Aidemy,*,*
# :	名詞,サ変接続,*,*,*,*,:,*,*
#  	記号,空白,*,*,*,*, ,*,*
# AI	名詞,固有名詞,組織,*,*,*,AI,*,*
# 教育	名詞,サ変接続,*,*,*,*,教育,キョウイク,キョーイク
# No	名詞,一般,*,*,*,*,No,*,*
# 1	名詞,数,*,*,*,*,1,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 実績	名詞,一般,*,*,*,*,実績,ジッセキ,ジッセキ
# 。	記号,句点,*,*,*,*,。,。,。
# 本気	名詞,一般,*,*,*,*,本気,ホンキ,ホンキ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# AI	名詞,一般,*,*,*,*,AI,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 学び	動詞,自立,*,*,五段・バ行,連用形,学ぶ,マナビ,マナビ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# なら	助動詞,*,*,*,特殊・ダ,仮定形,だ,ナラ,ナラ
# ココ	名詞,一般,*,*,*,*,ココ,*,*
# ！	記号,一般,*,*,*,*,！,！,！
#
#
#
#
#
#
# 							記号,空白,*,*,*,*,
#
#
#
#
#
# 						,*,*
# Aidemy	名詞,一般,*,*,*,*,Aidemy,*,*
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 無料	名詞,一般,*,*,*,*,無料,ムリョウ,ムリョー
# カウンセリング	名詞,一般,*,*,*,*,カウンセリング,カウンセリング,カウンセリング
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 受け	動詞,自立,*,*,一段,連用形,受ける,ウケ,ウケ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# みる	動詞,非自立,*,*,一段,基本形,みる,ミル,ミル
#
#
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
#
#
# ,*,*
# こんにちは	感動詞,*,*,*,*,*,こんにちは,コンニチハ,コンニチワ
# ！	記号,一般,*,*,*,*,！,！,！
# DAINOTE	名詞,固有名詞,組織,*,*,*,DAINOTE,*,*
# 編集	名詞,サ変接続,*,*,*,*,編集,ヘンシュウ,ヘンシュー
# 部	名詞,接尾,一般,*,*,*,部,ブ,ブ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# DAI	名詞,一般,*,*,*,*,DAI,*,*
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 突然	副詞,助詞類接続,*,*,*,*,突然,トツゼン,トツゼン
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 学び	動詞,自立,*,*,五段・バ行,連用形,学ぶ,マナビ,マナビ
# 始め	名詞,副詞可能,*,*,*,*,始め,ハジメ,ハジメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 時	名詞,非自立,副詞可能,*,*,*,時,トキ,トキ
# って	助詞,格助詞,連語,*,*,*,って,ッテ,ッテ
# 死ぬ	動詞,自立,*,*,五段・ナ行,基本形,死ぬ,シヌ,シヌ
# ほど	助詞,副助詞,*,*,*,*,ほど,ホド,ホド
# 大変	名詞,形容動詞語幹,*,*,*,*,大変,タイヘン,タイヘン
# じゃ	助詞,副助詞,*,*,*,*,じゃ,ジャ,ジャ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# ？	記号,一般,*,*,*,*,？,？,？
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 学習	名詞,サ変接続,*,*,*,*,学習,ガクシュウ,ガクシュー
# って	助詞,格助詞,連語,*,*,*,って,ッテ,ッテ
# 初心者	名詞,一般,*,*,*,*,初心者,ショシンシャ,ショシンシャ
# だっ	助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# とき	名詞,非自立,副詞可能,*,*,*,とき,トキ,トキ
# マジ	名詞,形容動詞語幹,*,*,*,*,マジ,マジ,マジ
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# 非	接頭詞,名詞接続,*,*,*,*,非,ヒ,ヒ
# 効率	名詞,一般,*,*,*,*,効率,コウリツ,コーリツ
# だっ	助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 思い出し	動詞,自立,*,*,五段・サ行,連用形,思い出す,オモイダシ,オモイダシ
# まし	助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ここ	名詞,代名詞,一般,*,*,*,ここ,ココ,ココ
# 最近	名詞,副詞可能,*,*,*,*,最近,サイキン,サイキン
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# クラウドソーシング	名詞,一般,*,*,*,*,クラウドソーシング,*,*
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 案件	名詞,一般,*,*,*,*,案件,アンケン,アンケン
# 取っ	動詞,自立,*,*,五段・ラ行,連用タ接続,取る,トッ,トッ
# たり	助詞,並立助詞,*,*,*,*,たり,タリ,タリ
# 、	記号,読点,*,*,*,*,、,、,、
# データ	名詞,一般,*,*,*,*,データ,データ,データ
# 分析	名詞,サ変接続,*,*,*,*,分析,ブンセキ,ブンセキ
# など	助詞,副助詞,*,*,*,*,など,ナド,ナド
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# Python	名詞,一般,*,*,*,*,Python,*,*
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# できる	動詞,自立,*,*,一段,基本形,できる,デキル,デキル
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# き	動詞,非自立,*,*,カ変・クル,連用形,くる,キ,キ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# 最初	名詞,一般,*,*,*,*,最初,サイショ,サイショ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 勉強	名詞,サ変接続,*,*,*,*,勉強,ベンキョウ,ベンキョー
# 方法	名詞,一般,*,*,*,*,方法,ホウホウ,ホーホー
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# だいぶ	副詞,一般,*,*,*,*,だいぶ,ダイブ,ダイブ
# 変わっ	動詞,自立,*,*,五段・ラ行,連用タ接続,変わる,カワッ,カワッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# き	動詞,非自立,*,*,カ変・クル,連用形,くる,キ,キ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# なぁ	助詞,終助詞,*,*,*,*,なぁ,ナァ,ナー
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 感じ	動詞,自立,*,*,一段,連用形,感じる,カンジ,カンジ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# い	動詞,非自立,*,*,一段,連用形,いる,イ,イ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# そこで	接続詞,*,*,*,*,*,そこで,ソコデ,ソコデ
# 、	記号,読点,*,*,*,*,、,、,、
# 最近	名詞,副詞可能,*,*,*,*,最近,サイキン,サイキン
# ツイッター	名詞,一般,*,*,*,*,ツイッター,*,*
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 初心者	名詞,一般,*,*,*,*,初心者,ショシンシャ,ショシンシャ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 視点	名詞,一般,*,*,*,*,視点,シテン,シテン
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# よい	形容詞,自立,*,*,形容詞・アウオ段,基本形,よい,ヨイ,ヨイ
# 学習	名詞,サ変接続,*,*,*,*,学習,ガクシュウ,ガクシュー
# 方法	名詞,一般,*,*,*,*,方法,ホウホウ,ホーホー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 発信	名詞,サ変接続,*,*,*,*,発信,ハッシン,ハッシン
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# ツイート	名詞,一般,*,*,*,*,ツイート,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 中	名詞,非自立,副詞可能,*,*,*,中,ナカ,ナカ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 反響	名詞,サ変接続,*,*,*,*,反響,ハンキョウ,ハンキョー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 大きかっ	形容詞,自立,*,*,形容詞・イ段,連用タ接続,大きい,オオキカッ,オーキカッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# もの	名詞,非自立,一般,*,*,*,もの,モノ,モノ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# まとめ	動詞,自立,*,*,一段,連用形,まとめる,マトメ,マトメ
# まし	助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 独学	名詞,サ変接続,*,*,*,*,独学,ドクガク,ドクガク
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# やっ	動詞,自立,*,*,五段・ラ行,連用タ接続,やる,ヤッ,ヤッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 、	記号,読点,*,*,*,*,、,、,、
# おすすめ	名詞,サ変接続,*,*,*,*,おすすめ,オススメ,オススメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 学習	名詞,サ変接続,*,*,*,*,学習,ガクシュウ,ガクシュー
# 方法	名詞,一般,*,*,*,*,方法,ホウホウ,ホーホー
# について	助詞,格助詞,連語,*,*,*,について,ニツイテ,ニツイテ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 目次	名詞,一般,*,*,*,*,目次,モクジ,モクジ
# 勉強	名詞,サ変接続,*,*,*,*,勉強,ベンキョウ,ベンキョー
# 法	名詞,接尾,一般,*,*,*,法,ホウ,ホー
# ①.	名詞,サ変接続,*,*,*,*,①.,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 作業	名詞,サ変接続,*,*,*,*,作業,サギョウ,サギョー
# ログ	名詞,サ変接続,*,*,*,*,ログ,ログ,ログ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# Github	名詞,固有名詞,組織,*,*,*,Github,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# Issue	名詞,一般,*,*,*,*,Issue,*,*
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 残す	動詞,自立,*,*,五段・サ行,基本形,残す,ノコス,ノコス
# 勉強	名詞,サ変接続,*,*,*,*,勉強,ベンキョウ,ベンキョー
# 法	名詞,接尾,一般,*,*,*,法,ホウ,ホー
# ②.	名詞,サ変接続,*,*,*,*,②.,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 2	名詞,数,*,*,*,*,2,*,*
# 週間	名詞,接尾,助数詞,*,*,*,週間,シュウカン,シューカン
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 基礎	名詞,一般,*,*,*,*,基礎,キソ,キソ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 終わら	動詞,自立,*,*,五段・ラ行,未然形,終わる,オワラ,オワラ
# せる	動詞,接尾,*,*,一段,基本形,せる,セル,セル
# 勉強	名詞,サ変接続,*,*,*,*,勉強,ベンキョウ,ベンキョー
# 法	名詞,接尾,一般,*,*,*,法,ホウ,ホー
# ③.	名詞,サ変接続,*,*,*,*,③.,*,*
#  	記号,空白,*,*,*,*, ,*,*
# プロダクト	名詞,一般,*,*,*,*,プロダクト,プロダクト,プロダクト
# ベース	名詞,一般,*,*,*,*,ベース,ベース,ベース
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# チュートリアル	名詞,一般,*,*,*,*,チュートリアル,チュートリアル,チュートリアル
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# やる	動詞,自立,*,*,五段・ラ行,基本形,やる,ヤル,ヤル
# Rails	名詞,固有名詞,組織,*,*,*,Rails,*,*
#  	記号,空白,*,*,*,*, ,*,*
# チュートリアル	名詞,一般,*,*,*,*,チュートリアル,チュートリアル,チュートリアル
# Tutorials	名詞,一般,*,*,*,*,Tutorials,*,*
#  	記号,空白,*,*,*,*, ,*,*
# PointsUdemyQiitaYoutube	名詞,固有名詞,組織,*,*,*,PointsUdemyQiitaYoutube,*,*
# 勉強	名詞,サ変接続,*,*,*,*,勉強,ベンキョウ,ベンキョー
# 法	名詞,接尾,一般,*,*,*,法,ホウ,ホー
# ④.	名詞,サ変接続,*,*,*,*,④.,*,*
#  	記号,空白,*,*,*,*, ,*,*
# メンター	名詞,一般,*,*,*,*,メンター,*,*
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 聞き	動詞,自立,*,*,五段・カ行イ音便,連用形,聞く,キキ,キキ
# ながら	助詞,接続助詞,*,*,*,*,ながら,ナガラ,ナガラ
# トライアンドエラー	名詞,一般,*,*,*,*,トライアンドエラー,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# として	助詞,格助詞,連語,*,*,*,として,トシテ,トシテ
# 通用	名詞,サ変接続,*,*,*,*,通用,ツウヨウ,ツーヨー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# 力	名詞,接尾,一般,*,*,*,力,リョク,リョク
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 得る	動詞,自立,*,*,一段,基本形,得る,エル,エル
# ため	名詞,非自立,副詞可能,*,*,*,ため,タメ,タメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# 独学	名詞,サ変接続,*,*,*,*,独学,ドクガク,ドクガク
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 躓く	動詞,自立,*,*,五段・カ行イ音便,基本形,躓く,ツマズク,ツマズク
# ポイントオススメ	名詞,一般,*,*,*,*,ポイントオススメ,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# スクール	名詞,一般,*,*,*,*,スクール,スクール,スクール
# 勉強	名詞,サ変接続,*,*,*,*,勉強,ベンキョウ,ベンキョー
# 法	名詞,接尾,一般,*,*,*,法,ホウ,ホー
# 5	名詞,数,*,*,*,*,5,*,*
# .	名詞,サ変接続,*,*,*,*,.,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 自分	名詞,一般,*,*,*,*,自分,ジブン,ジブン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# プロダクト	名詞,一般,*,*,*,*,プロダクト,プロダクト,プロダクト
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 決め	動詞,自立,*,*,一段,連用形,決める,キメ,キメ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 作り	動詞,自立,*,*,五段・ラ行,連用形,作る,ツクリ,ツクリ
# はじめる	動詞,非自立,*,*,一段,基本形,はじめる,ハジメル,ハジメル
# その他	名詞,代名詞,一般,*,*,*,その他,ソノタ,ソノタ
#  	記号,空白,*,*,*,*, ,*,*
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 独学	名詞,サ変接続,*,*,*,*,独学,ドクガク,ドクガク
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# うえ	名詞,非自立,副詞可能,*,*,*,うえ,ウエ,ウエ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# よく	副詞,一般,*,*,*,*,よく,ヨク,ヨク
# いただく	動詞,自立,*,*,五段・カ行イ音便,基本形,いただく,イタダク,イタダク
# 質問	名詞,サ変接続,*,*,*,*,質問,シツモン,シツモン
# 「	記号,括弧開,*,*,*,*,「,「,「
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 独学	名詞,サ変接続,*,*,*,*,独学,ドクガク,ドクガク
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# なら	助動詞,*,*,*,特殊・ダ,仮定形,だ,ナラ,ナラ
# 、	記号,読点,*,*,*,*,、,、,、
# 本	名詞,一般,*,*,*,*,本,ホン,ホン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 方	名詞,非自立,一般,*,*,*,方,ホウ,ホー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# ？	記号,一般,*,*,*,*,？,？,？
# Web	名詞,固有名詞,組織,*,*,*,Web,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 方	名詞,非自立,一般,*,*,*,方,ホウ,ホー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# ？	記号,一般,*,*,*,*,？,？,？
# 」	記号,括弧閉,*,*,*,*,」,」,」
# 「	記号,括弧開,*,*,*,*,「,「,「
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 独学	名詞,サ変接続,*,*,*,*,独学,ドクガク,ドクガク
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# うえ	名詞,非自立,副詞可能,*,*,*,うえ,ウエ,ウエ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# おすすめ	名詞,サ変接続,*,*,*,*,おすすめ,オススメ,オススメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 教え	動詞,自立,*,*,一段,連用形,教える,オシエ,オシエ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ください	動詞,非自立,*,*,五段・ラ行特殊,命令ｉ,くださる,クダサイ,クダサイ
# 」	記号,括弧閉,*,*,*,*,」,」,」
# まとめ	名詞,一般,*,*,*,*,まとめ,マトメ,マトメ
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# スクール	名詞,一般,*,*,*,*,スクール,スクール,スクール
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 選ぶ	動詞,自立,*,*,五段・バ行,基本形,選ぶ,エラブ,エラブ
# なら	助動詞,*,*,*,特殊・ダ,仮定形,だ,ナラ,ナラ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 勉強	名詞,サ変接続,*,*,*,*,勉強,ベンキョウ,ベンキョー
# 法	名詞,接尾,一般,*,*,*,法,ホウ,ホー
# ①.	名詞,サ変接続,*,*,*,*,①.,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 作業	名詞,サ変接続,*,*,*,*,作業,サギョウ,サギョー
# ログ	名詞,サ変接続,*,*,*,*,ログ,ログ,ログ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# Github	名詞,固有名詞,組織,*,*,*,Github,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# Issue	名詞,一般,*,*,*,*,Issue,*,*
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 残す	動詞,自立,*,*,五段・サ行,基本形,残す,ノコス,ノコス
#
# 	記号,空白,*,*,*,*,
# ,*,*
# Github	名詞,固有名詞,組織,*,*,*,Github,*,*
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# ソース	名詞,一般,*,*,*,*,ソース,ソース,ソース
# コード	名詞,一般,*,*,*,*,コード,コード,コード
# 管理	名詞,サ変接続,*,*,*,*,管理,カンリ,カンリ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 行える	動詞,自立,*,*,一段,基本形,行える,オコナエル,オコナエル
# ソフトウェア	名詞,一般,*,*,*,*,ソフトウェア,ソフトウェア,ソフトウェア
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# その	連体詞,*,*,*,*,*,その,ソノ,ソノ
# 中	名詞,非自立,副詞可能,*,*,*,中,ナカ,ナカ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# Issue	名詞,固有名詞,組織,*,*,*,Issue,*,*
# という	助詞,格助詞,連語,*,*,*,という,トイウ,トユウ
# 掲示板	名詞,一般,*,*,*,*,掲示板,ケイジバン,ケイジバン
# みたい	名詞,非自立,形容動詞語幹,*,*,*,みたい,ミタイ,ミタイ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# もの	名詞,非自立,一般,*,*,*,もの,モノ,モノ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# あり	動詞,自立,*,*,五段・ラ行,連用形,ある,アリ,アリ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
# そこ	名詞,代名詞,一般,*,*,*,そこ,ソコ,ソコ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 、	記号,読点,*,*,*,*,、,、,、
# どういう	連体詞,*,*,*,*,*,どういう,ドウイウ,ドーユウ
# 処理	名詞,サ変接続,*,*,*,*,処理,ショリ,ショリ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 行っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,行う,オコナッ,オコナッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# い	動詞,非自立,*,*,一段,連用形,いる,イ,イ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 何	名詞,代名詞,一般,*,*,*,何,ナニ,ナニ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# うまく	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,うまい,ウマク,ウマク
# いっ	動詞,自立,*,*,五段・カ行促音便,連用タ接続,いく,イッ,イッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# い	動詞,非自立,*,*,一段,未然形,いる,イ,イ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 作業	名詞,サ変接続,*,*,*,*,作業,サギョウ,サギョー
# ログ	名詞,サ変接続,*,*,*,*,ログ,ログ,ログ
# として	助詞,格助詞,連語,*,*,*,として,トシテ,トシテ
# 残し	動詞,自立,*,*,五段・サ行,連用形,残す,ノコシ,ノコシ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# おく	動詞,非自立,*,*,五段・カ行イ音便,基本形,おく,オク,オク
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# おすすめ	名詞,サ変接続,*,*,*,*,おすすめ,オススメ,オススメ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# 初心者	名詞,一般,*,*,*,*,初心者,ショシンシャ,ショシンシャ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# Github	名詞,一般,*,*,*,*,Github,*,*
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 作業	名詞,サ変接続,*,*,*,*,作業,サギョウ,サギョー
# ログ	名詞,サ変接続,*,*,*,*,ログ,ログ,ログ
# 残し	動詞,自立,*,*,五段・サ行,連用形,残す,ノコシ,ノコシ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ツイッター	名詞,一般,*,*,*,*,ツイッター,*,*
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 連携	名詞,サ変接続,*,*,*,*,連携,レンケイ,レンケイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 作業	名詞,サ変接続,*,*,*,*,作業,サギョウ,サギョー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# 、	記号,読点,*,*,*,*,、,、,、
# 優しい	形容詞,自立,*,*,形容詞・イ段,基本形,優しい,ヤサシイ,ヤサシイ
# お	接頭詞,名詞接続,*,*,*,*,お,オ,オ
# 兄さん	名詞,一般,*,*,*,*,兄さん,ニイサン,ニーサン
# たち	名詞,接尾,一般,*,*,*,たち,タチ,タチ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# コメント	名詞,サ変接続,*,*,*,*,コメント,コメント,コメント
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# くれる	動詞,非自立,*,*,一段・クレル,基本形,くれる,クレル,クレル
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# すごく	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,すごい,スゴク,スゴク
# おすすめ	名詞,サ変接続,*,*,*,*,おすすめ,オススメ,オススメ
# 。	記号,句点,*,*,*,*,。,。,。
# 作業	名詞,サ変接続,*,*,*,*,作業,サギョウ,サギョー
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 可視	名詞,一般,*,*,*,*,可視,カシ,カシ
# 化	名詞,接尾,サ変接続,*,*,*,化,カ,カ
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れる	動詞,接尾,*,*,一段,基本形,れる,レル,レル
# し	助詞,接続助詞,*,*,*,*,し,シ,シ
# 、	記号,読点,*,*,*,*,、,、,、
# 質問	名詞,サ変接続,*,*,*,*,質問,シツモン,シツモン
# し	動詞,自立,*,*,サ変・スル,未然形,する,シ,シ
# なく	助動詞,*,*,*,特殊・ナイ,連用テ接続,ない,ナク,ナク
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 何	名詞,代名詞,一般,*,*,*,何,ナニ,ナニ
# しよ	動詞,自立,*,*,サ変・スル,未然ウ接続,する,シヨ,シヨ
# う	助動詞,*,*,*,不変化型,基本形,う,ウ,ウ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# わかれ	動詞,自立,*,*,五段・ラ行,仮定形,わかる,ワカレ,ワカレ
# ば	助詞,接続助詞,*,*,*,*,ば,バ,バ
# こたえ	動詞,自立,*,*,一段,連用形,こたえる,コタエ,コタエ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# くれ	動詞,非自立,*,*,一段・クレル,連用形,くれる,クレ,クレ
# やすく	形容詞,非自立,*,*,形容詞・アウオ段,連用テ接続,やすい,ヤスク,ヤスク
# なる	動詞,自立,*,*,五段・ラ行,基本形,なる,ナル,ナル
# 。	記号,句点,*,*,*,*,。,。,。
#
# 	記号,空白,*,*,*,*,
# ,*,*
# &	名詞,サ変接続,*,*,*,*,&,*,*
# mdash	名詞,一般,*,*,*,*,mdash,*,*
# ;	名詞,サ変接続,*,*,*,*,;,*,*
#  	記号,空白,*,*,*,*, ,*,*
# DAI	名詞,固有名詞,組織,*,*,*,DAI,*,*
#  	記号,空白,*,*,*,*, ,*,*
# (@	名詞,サ変接続,*,*,*,*,(@,*,*
# never	名詞,一般,*,*,*,*,never,*,*
# _	名詞,サ変接続,*,*,*,*,_,*,*
# be	名詞,一般,*,*,*,*,be,*,*
# _	名詞,サ変接続,*,*,*,*,_,*,*
# a	名詞,一般,*,*,*,*,a,*,*
# _	名詞,サ変接続,*,*,*,*,_,*,*
# pm	名詞,一般,*,*,*,*,pm,*,*
# )	名詞,サ変接続,*,*,*,*,),*,*
#  	記号,空白,*,*,*,*, ,*,*
# April	名詞,固有名詞,組織,*,*,*,April,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 14	名詞,数,*,*,*,*,14,*,*
# ,	名詞,サ変接続,*,*,*,*,,,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 2018	名詞,数,*,*,*,*,2018,*,*
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# Github	名詞,固有名詞,組織,*,*,*,Github,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# Issue	名詞,一般,*,*,*,*,Issue,*,*
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# 簡単	名詞,形容動詞語幹,*,*,*,*,簡単,カンタン,カンタン
# い	動詞,自立,*,*,一段,連用形,いる,イ,イ
# いう	動詞,自立,*,*,五段・ワ行促音便,基本形,いう,イウ,イウ
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# 掲示板	名詞,一般,*,*,*,*,掲示板,ケイジバン,ケイジバン
# みたい	名詞,非自立,形容動詞語幹,*,*,*,みたい,ミタイ,ミタイ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# もの	名詞,非自立,一般,*,*,*,もの,モノ,モノ
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# そこで	接続詞,*,*,*,*,*,そこで,ソコデ,ソコデ
# 開発	名詞,サ変接続,*,*,*,*,開発,カイハツ,カイハツ
# について	助詞,格助詞,連語,*,*,*,について,ニツイテ,ニツイテ
# やりとり	名詞,一般,*,*,*,*,やりとり,ヤリトリ,ヤリトリ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# できる	動詞,自立,*,*,一段,基本形,できる,デキル,デキル
# ん	名詞,非自立,一般,*,*,*,ん,ン,ン
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# よ	助詞,終助詞,*,*,*,*,よ,ヨ,ヨ
# ね	助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。	記号,句点,*,*,*,*,。,。,。
# それ	名詞,代名詞,一般,*,*,*,それ,ソレ,ソレ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# ソース	名詞,一般,*,*,*,*,ソース,ソース,ソース
# コード	名詞,一般,*,*,*,*,コード,コード,コード
# 管理	名詞,サ変接続,*,*,*,*,管理,カンリ,カンリ
# システム	名詞,一般,*,*,*,*,システム,システム,システム
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# ある	助動詞,*,*,*,五段・ラ行アル,基本形,ある,アル,アル
# 、	記号,読点,*,*,*,*,、,、,、
# Github	名詞,一般,*,*,*,*,Github,*,*
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 標準	名詞,一般,*,*,*,*,標準,ヒョウジュン,ヒョージュン
# 機能	名詞,サ変接続,*,*,*,*,機能,キノウ,キノー
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# おい	動詞,非自立,*,*,五段・カ行イ音便,連用タ接続,おく,オイ,オイ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# あり	動詞,非自立,*,*,五段・ラ行,連用形,ある,アリ,アリ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
# 例	名詞,一般,*,*,*,*,例,レイ,レイ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# わかり	動詞,自立,*,*,五段・ラ行,連用形,わかる,ワカリ,ワカリ
# にくい	形容詞,非自立,*,*,形容詞・アウオ段,基本形,にくい,ニクイ,ニクイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 思う	動詞,自立,*,*,五段・ワ行促音便,基本形,思う,オモウ,オモウ
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# 、	記号,読点,*,*,*,*,、,、,、
# こちら	名詞,代名詞,一般,*,*,*,こちら,コチラ,コチラ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 僕	名詞,代名詞,一般,*,*,*,僕,ボク,ボク
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# ツイッター	名詞,一般,*,*,*,*,ツイッター,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 自動	名詞,一般,*,*,*,*,自動,ジドウ,ジドー
# 化	名詞,接尾,サ変接続,*,*,*,化,カ,カ
# アプリ	名詞,一般,*,*,*,*,アプリ,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 作っ	動詞,自立,*,*,五段・ラ行,連用タ接続,作る,ツクッ,ツクッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# とき	名詞,非自立,副詞可能,*,*,*,とき,トキ,トキ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# イシュー	名詞,一般,*,*,*,*,イシュー,*,*
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
#  	記号,空白,*,*,*,*, ,*,*
# こんな	連体詞,*,*,*,*,*,こんな,コンナ,コンナ
# 感じ	名詞,一般,*,*,*,*,感じ,カンジ,カンジ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# 自分	名詞,一般,*,*,*,*,自分,ジブン,ジブン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 作業	名詞,サ変接続,*,*,*,*,作業,サギョウ,サギョー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# とき	名詞,非自立,副詞可能,*,*,*,とき,トキ,トキ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# ログ	名詞,サ変接続,*,*,*,*,ログ,ログ,ログ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 適宜	名詞,副詞可能,*,*,*,*,適宜,テキギ,テキギ
# 張り付け	動詞,自立,*,*,一段,連用形,張り付ける,ハリツケ,ハリツケ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# い	動詞,非自立,*,*,一段,連用形,いる,イ,イ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# これ	名詞,代名詞,一般,*,*,*,これ,コレ,コレ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# やる	動詞,自立,*,*,五段・ラ行,基本形,やる,ヤル,ヤル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 2	名詞,数,*,*,*,*,2,*,*
# つ	助動詞,*,*,*,下二・タ行,基本形,つ,ツ,ツ
# メリット	名詞,一般,*,*,*,*,メリット,メリット,メリット
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# あり	動詞,自立,*,*,五段・ラ行,連用形,ある,アリ,アリ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 一つ	名詞,一般,*,*,*,*,一つ,ヒトツ,ヒトツ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 作業	名詞,サ変接続,*,*,*,*,作業,サギョウ,サギョー
# ログ	名詞,サ変接続,*,*,*,*,ログ,ログ,ログ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 残せる	動詞,自立,*,*,一段,基本形,残せる,ノコセル,ノコセル
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# 、	記号,読点,*,*,*,*,、,、,、
# 自分	名詞,一般,*,*,*,*,自分,ジブン,ジブン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 今	名詞,副詞可能,*,*,*,*,今,イマ,イマ
# どの	連体詞,*,*,*,*,*,どの,ドノ,ドノ
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 処理	名詞,サ変接続,*,*,*,*,処理,ショリ,ショリ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# 化	名詞,接尾,サ変接続,*,*,*,化,カ,カ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# ながら	助詞,接続助詞,*,*,*,*,ながら,ナガラ,ナガラ
# 確認	名詞,サ変接続,*,*,*,*,確認,カクニン,カクニン
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# 状況	名詞,一般,*,*,*,*,状況,ジョウキョウ,ジョーキョー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 理解	名詞,サ変接続,*,*,*,*,理解,リカイ,リカイ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# やすく	形容詞,非自立,*,*,形容詞・アウオ段,連用テ接続,やすい,ヤスク,ヤスク
# なる	動詞,自立,*,*,五段・ラ行,基本形,なる,ナル,ナル
# という	助詞,格助詞,連語,*,*,*,という,トイウ,トユウ
# 点	名詞,非自立,一般,*,*,*,点,テン,テン
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
# 独学	名詞,サ変接続,*,*,*,*,独学,ドクガク,ドクガク
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# とき	名詞,非自立,副詞可能,*,*,*,とき,トキ,トキ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 形跡	名詞,一般,*,*,*,*,形跡,ケイセキ,ケイセキ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 残せる	動詞,自立,*,*,一段,基本形,残せる,ノコセル,ノコセル
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# 、	記号,読点,*,*,*,*,、,、,、
# 後で	副詞,一般,*,*,*,*,後で,アトデ,アトデ
# 見直す	動詞,自立,*,*,五段・サ行,基本形,見直す,ミナオス,ミナオス
# とき	名詞,非自立,副詞可能,*,*,*,とき,トキ,トキ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 使え	動詞,自立,*,*,一段,連用形,使える,ツカエ,ツカエ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
#
# 	記号,空白,*,*,*,*,
# ,*,*
# もう	副詞,一般,*,*,*,*,もう,モウ,モー
# 一つ	名詞,一般,*,*,*,*,一つ,ヒトツ,ヒトツ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# ツイッター	名詞,一般,*,*,*,*,ツイッター,*,*
# 上	名詞,接尾,副詞可能,*,*,*,上,ジョウ,ジョー
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 自分	名詞,一般,*,*,*,*,自分,ジブン,ジブン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# プログラム	名詞,サ変接続,*,*,*,*,プログラム,プログラム,プログラム
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# Github	名詞,固有名詞,組織,*,*,*,Github,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# イシュー	名詞,一般,*,*,*,*,イシュー,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 公開	名詞,サ変接続,*,*,*,*,公開,コウカイ,コーカイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# おく	動詞,非自立,*,*,五段・カ行イ音便,基本形,おく,オク,オク
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# 、	記号,読点,*,*,*,*,、,、,、
# だれ	名詞,代名詞,一般,*,*,*,だれ,ダレ,ダレ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# 優しい	形容詞,自立,*,*,形容詞・イ段,基本形,優しい,ヤサシイ,ヤサシイ
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# ぱっと	副詞,一般,*,*,*,*,ぱっと,パット,パット
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ヒント	名詞,一般,*,*,*,*,ヒント,ヒント,ヒント
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 出し	動詞,自立,*,*,五段・サ行,連用形,出す,ダシ,ダシ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# くれ	動詞,非自立,*,*,一段・クレル,連用形,くれる,クレ,クレ
# たり	助詞,並立助詞,*,*,*,*,たり,タリ,タリ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# から	助詞,接続助詞,*,*,*,*,から,カラ,カラ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ツイッター	名詞,一般,*,*,*,*,ツイッター,*,*
# 上	名詞,接尾,副詞可能,*,*,*,上,ジョウ,ジョー
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# 、	記号,読点,*,*,*,*,、,、,、
# 140	名詞,数,*,*,*,*,140,*,*
# 文字	名詞,一般,*,*,*,*,文字,モジ,モジ
# しか	助詞,係助詞,*,*,*,*,しか,シカ,シカ
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# 、	記号,読点,*,*,*,*,、,、,、
# すべて	名詞,副詞可能,*,*,*,*,すべて,スベテ,スベテ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 説明	名詞,サ変接続,*,*,*,*,説明,セツメイ,セツメイ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 文字数	名詞,一般,*,*,*,*,文字数,モジスウ,モジスー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 足り	動詞,自立,*,*,五段・ラ行,連用形,足る,タリ,タリ
# ませ	助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ
# ん	助動詞,*,*,*,不変化型,基本形,ん,ン,ン
# し	助詞,接続助詞,*,*,*,*,し,シ,シ
# 、	記号,読点,*,*,*,*,、,、,、
# いきなり	副詞,助詞類接続,*,*,*,*,いきなり,イキナリ,イキナリ
# 「	記号,括弧開,*,*,*,*,「,「,「
# ちょっと	副詞,助詞類接続,*,*,*,*,ちょっと,チョット,チョット
# 教え	動詞,自立,*,*,一段,連用形,教える,オシエ,オシエ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 」	記号,括弧閉,*,*,*,*,」,」,」
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 見ず知らず	名詞,一般,*,*,*,*,見ず知らず,ミズシラズ,ミズシラズ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 教える	動詞,自立,*,*,一段,基本形,教える,オシエル,オシエル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 正直	名詞,形容動詞語幹,*,*,*,*,正直,ショウジキ,ショージキ
# ハードル	名詞,一般,*,*,*,*,ハードル,ハードル,ハードル
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 高い	形容詞,自立,*,*,形容詞・アウオ段,基本形,高い,タカイ,タカイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 思い	動詞,自立,*,*,五段・ワ行促音便,連用形,思う,オモイ,オモイ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
# （	記号,括弧開,*,*,*,*,（,（,（
# しかも	接続詞,*,*,*,*,*,しかも,シカモ,シカモ
# 実際	副詞,助詞類接続,*,*,*,*,実際,ジッサイ,ジッサイ
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# よ	助詞,終助詞,*,*,*,*,よ,ヨ,ヨ
# ～	名詞,サ変接続,*,*,*,*,～,*,*
# なんて	助詞,副助詞,*,*,*,*,なんて,ナンテ,ナンテ
# 言っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,言う,イッ,イッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# くれる	動詞,非自立,*,*,一段・クレル,基本形,くれる,クレル,クレル
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 少ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,少ない,スクナイ,スクナイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 思い	動詞,自立,*,*,五段・ワ行促音便,連用形,思う,オモイ,オモイ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
# ）	記号,括弧閉,*,*,*,*,）,）,）
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 勉強	名詞,サ変接続,*,*,*,*,勉強,ベンキョウ,ベンキョー
# 法	名詞,接尾,一般,*,*,*,法,ホウ,ホー
# ②.	名詞,サ変接続,*,*,*,*,②.,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 2	名詞,数,*,*,*,*,2,*,*
# 週間	名詞,接尾,助数詞,*,*,*,週間,シュウカン,シューカン
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 基礎	名詞,一般,*,*,*,*,基礎,キソ,キソ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 終わら	動詞,自立,*,*,五段・ラ行,未然形,終わる,オワラ,オワラ
# せる	動詞,接尾,*,*,一段,基本形,せる,セル,セル
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# 基礎	名詞,一般,*,*,*,*,基礎,キソ,キソ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# Progate	名詞,一般,*,*,*,*,Progate,*,*
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 十分	名詞,形容動詞語幹,*,*,*,*,十分,ジュウブン,ジューブン
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# ！	記号,一般,*,*,*,*,！,！,！
# これ	名詞,代名詞,一般,*,*,*,これ,コレ,コレ
# だけ	助詞,副助詞,*,*,*,*,だけ,ダケ,ダケ
# ...
#
#
#
#
#
#
#
#
#
#                         	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
#                         ,*,*
# 2019	名詞,数,*,*,*,*,2019,*,*
# /	名詞,サ変接続,*,*,*,*,/,*,*
# 01	名詞,数,*,*,*,*,01,*,*
# /	名詞,サ変接続,*,*,*,*,/,*,*
# 21	名詞,数,*,*,*,*,21,*,*
#
#                         	記号,空白,*,*,*,*,
#                         ,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# 体験	名詞,サ変接続,*,*,*,*,体験,タイケン,タイケン
# 談	名詞,接尾,一般,*,*,*,談,ダン,ダン
# 】	記号,括弧閉,*,*,*,*,】,】,】
# TechAcademy	名詞,固有名詞,組織,*,*,*,TechAcademy,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 評判	名詞,一般,*,*,*,*,評判,ヒョウバン,ヒョーバン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 確かめ	動詞,自立,*,*,一段,連用形,確かめる,タシカメ,タシカメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# エンジニア	名詞,一般,*,*,*,*,エンジニア,エンジニア,エンジニア
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 転職	名詞,サ変接続,*,*,*,*,転職,テンショク,テンショク
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 卒業生	名詞,一般,*,*,*,*,卒業生,ソツギョウセイ,ソツギョーセイ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# インタビュー	名詞,サ変接続,*,*,*,*,インタビュー,インタビュー,インタビュー
# 【	記号,括弧開,*,*,*,*,【,【,【
# PR	名詞,固有名詞,組織,*,*,*,PR,*,*
# 】	記号,括弧閉,*,*,*,*,】,】,】
#
#
#
#
#
#
#
#
# 							記号,空白,*,*,*,*,
#
#
#
#
#
#
#
# 						,*,*
# DAI	名詞,固有名詞,組織,*,*,*,DAI,*,*
#
#
#
#
#
#
# 						記号,空白,*,*,*,*,
#
#
#
#
#
# 					,*,*
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# とか	助詞,並立助詞,*,*,*,*,とか,トカ,トカ
# データアナリティクス	名詞,固有名詞,組織,*,*,*,データアナリティクス,*,*
# とか	助詞,並立助詞,*,*,*,*,とか,トカ,トカ
# マーケティング	名詞,一般,*,*,*,*,マーケティング,マーケティング,マーケティング
# とか	助詞,並立助詞,*,*,*,*,とか,トカ,トカ
# コンテンツマーケ	名詞,固有名詞,組織,*,*,*,コンテンツマーケ,*,*
# とか	助詞,並立助詞,*,*,*,*,とか,トカ,トカ
# SNS	名詞,固有名詞,組織,*,*,*,SNS,*,*
# とか	助詞,並立助詞,*,*,*,*,とか,トカ,トカ
# 好き	名詞,形容動詞語幹,*,*,*,*,好き,スキ,スキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# フリーランス	名詞,一般,*,*,*,*,フリーランス,*,*
# 。	記号,句点,*,*,*,*,。,。,。
# KADOKAWA	名詞,固有名詞,組織,*,*,*,KADOKAWA,*,*
# さん	名詞,接尾,人名,*,*,*,さん,サン,サン
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# 著書	名詞,一般,*,*,*,*,著書,チョショ,チョショ
# 『	記号,括弧開,*,*,*,*,『,『,『
# 独学	名詞,サ変接続,*,*,*,*,独学,ドクガク,ドクガク
# プログラマー	名詞,一般,*,*,*,*,プログラマー,プログラマー,プログラマー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# ため	名詞,非自立,副詞可能,*,*,*,ため,タメ,タメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# AI	名詞,一般,*,*,*,*,AI,*,*
# アプリ	名詞,一般,*,*,*,*,アプリ,*,*
# 開発	名詞,サ変接続,*,*,*,*,開発,カイハツ,カイハツ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# わかる	動詞,自立,*,*,五段・ラ行,基本形,わかる,ワカル,ワカル
# 本	名詞,一般,*,*,*,*,本,ホン,ホン
# 』	記号,括弧閉,*,*,*,*,』,』,』
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 出	動詞,自立,*,*,一段,連用形,出る,デ,デ
# まし	助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#  	記号,空白,*,*,*,*, ,*,*
# ICU	名詞,一般,*,*,*,*,ICU,*,*
# 卒	名詞,接尾,一般,*,*,*,卒,ソツ,ソツ
#
#
# 							記号,空白,*,*,*,*,
#
# 						,*,*
# プロフィール	名詞,一般,*,*,*,*,プロフィール,プロフィール,プロフィール
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 見る	動詞,自立,*,*,一段,基本形,見る,ミル,ミル
#
#
# 						記号,空白,*,*,*,*,
#
# 					,*,*
# カテゴリ	名詞,一般,*,*,*,*,カテゴリ,カテゴリ,カテゴリ
#
# 					記号,空白,*,*,*,*,
# 				,*,*
# AI	名詞,固有名詞,組織,*,*,*,AI,*,*
#
#
# 		記号,空白,*,*,*,*,
#
# 	,*,*
# GoogleAppsScript	名詞,固有名詞,組織,*,*,*,GoogleAppsScript,*,*
#
#
# 		記号,空白,*,*,*,*,
#
# 	,*,*
# IT	名詞,固有名詞,組織,*,*,*,IT,*,*
# 副業	名詞,一般,*,*,*,*,副業,フクギョウ,フクギョー
#
#
# 		記号,空白,*,*,*,*,
#
# 	,*,*
# Other	名詞,固有名詞,組織,*,*,*,Other,*,*
#
#
# 		記号,空白,*,*,*,*,
#
# 	,*,*
# Python	名詞,固有名詞,組織,*,*,*,Python,*,*
#
#
# 		記号,空白,*,*,*,*,
#
# 	,*,*
# R	名詞,固有名詞,組織,*,*,*,R,*,*
#
#
# 		記号,空白,*,*,*,*,
#
# 	,*,*
# redash	名詞,固有名詞,組織,*,*,*,redash,*,*
#
#
# 		記号,空白,*,*,*,*,
#
# 	,*,*
# Ruby	名詞,固有名詞,組織,*,*,*,Ruby,*,*
#
#
# 		記号,空白,*,*,*,*,
#
# 	,*,*
# Web	名詞,固有名詞,組織,*,*,*,Web,*,*
# デザイン	名詞,サ変接続,*,*,*,*,デザイン,デザイン,デザイン
#
#
# 		記号,空白,*,*,*,*,
#
# 	,*,*
# WordPress	名詞,固有名詞,組織,*,*,*,WordPress,*,*
#
#
# 		記号,空白,*,*,*,*,
#
# 	,*,*
# アフィリエイト	名詞,一般,*,*,*,*,アフィリエイト,*,*
#
#
# 		記号,空白,*,*,*,*,
#
# 	,*,*
# キャリア	名詞,一般,*,*,*,*,キャリア,キャリア,キャリア
#
#
# 		記号,空白,*,*,*,*,
#
# 	,*,*
# クラウドソーシング	名詞,一般,*,*,*,*,クラウドソーシング,*,*
#
#
# 		記号,空白,*,*,*,*,
#
# 	,*,*
# フリーランス	名詞,一般,*,*,*,*,フリーランス,*,*
#
#
# 		記号,空白,*,*,*,*,
#
# 	,*,*
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
#  	記号,空白,*,*,*,*, ,*,*
# 独学	名詞,サ変接続,*,*,*,*,独学,ドクガク,ドクガク
#
#
# 		記号,空白,*,*,*,*,
#
# 	,*,*
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# スクール	名詞,一般,*,*,*,*,スクール,スクール,スクール
#
#
# 		記号,空白,*,*,*,*,
#
# 	,*,*
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# 初心者	名詞,一般,*,*,*,*,初心者,ショシンシャ,ショシンシャ
#
#
# 		記号,空白,*,*,*,*,
#
# 	,*,*
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# 学習	名詞,サ変接続,*,*,*,*,学習,ガクシュウ,ガクシュー
# 法	名詞,接尾,一般,*,*,*,法,ホウ,ホー
#
#
# 		記号,空白,*,*,*,*,
#
# 	,*,*
# マーケティング	名詞,一般,*,*,*,*,マーケティング,マーケティング,マーケティング
#
#
#
# 								記号,空白,*,*,*,*,
#
#
# 							,*,*
# 最近	名詞,副詞可能,*,*,*,*,最近,サイキン,サイキン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 投稿	名詞,サ変接続,*,*,*,*,投稿,トウコウ,トーコー
#
#
# 						記号,空白,*,*,*,*,
#
# 					,*,*
# IT	名詞,一般,*,*,*,*,IT,*,*
# 系	名詞,接尾,一般,*,*,*,系,ケイ,ケイ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# フリーランス	名詞,一般,*,*,*,*,フリーランス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 職種	名詞,一般,*,*,*,*,職種,ショクシュ,ショクシュ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# 案件	名詞,一般,*,*,*,*,案件,アンケン,アンケン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 獲得	名詞,サ変接続,*,*,*,*,獲得,カクトク,カクトク
# 方法	名詞,一般,*,*,*,*,方法,ホウホウ,ホーホー
# について	助詞,格助詞,連語,*,*,*,について,ニツイテ,ニツイテ
# まとめ	動詞,自立,*,*,一段,連用形,まとめる,マトメ,マトメ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
#
#
#
# 						記号,空白,*,*,*,*,
#
#
# 					,*,*
# Web	名詞,固有名詞,組織,*,*,*,Web,*,*
# ライター	名詞,一般,*,*,*,*,ライター,ライター,ライター
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 副業	名詞,一般,*,*,*,*,副業,フクギョウ,フクギョー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# なら	助動詞,*,*,*,特殊・ダ,仮定形,だ,ナラ,ナラ
# おすすめ	名詞,サ変接続,*,*,*,*,おすすめ,オススメ,オススメ
# という	助詞,格助詞,連語,*,*,*,という,トイウ,トユウ
# 話	名詞,サ変接続,*,*,*,*,話,ハナシ,ハナシ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# 、	記号,読点,*,*,*,*,、,、,、
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 取り	動詞,自立,*,*,五段・ラ行,連用形,取る,トリ,トリ
# 方	名詞,接尾,特殊,*,*,*,方,カタ,カタ
# について	助詞,格助詞,連語,*,*,*,について,ニツイテ,ニツイテ
# まとめ	動詞,自立,*,*,一段,連用形,まとめる,マトメ,マトメ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
#
#
#
# 						記号,空白,*,*,*,*,
#
#
# 					,*,*
# Web	名詞,固有名詞,組織,*,*,*,Web,*,*
# ディレクター	名詞,一般,*,*,*,*,ディレクター,ディレクター,ディレクター
# へ	助詞,格助詞,一般,*,*,*,へ,ヘ,エ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 転職	名詞,サ変接続,*,*,*,*,転職,テンショク,テンショク
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# おすすめ	名詞,サ変接続,*,*,*,*,おすすめ,オススメ,オススメ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# 転職	名詞,サ変接続,*,*,*,*,転職,テンショク,テンショク
# エージェント	名詞,一般,*,*,*,*,エージェント,エージェント,エージェント
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# ？	記号,一般,*,*,*,*,？,？,？
# ディレクター	名詞,一般,*,*,*,*,ディレクター,ディレクター,ディレクター
# 職	名詞,接尾,一般,*,*,*,職,ショク,ショク
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 選び方	名詞,一般,*,*,*,*,選び方,エラビカタ,エラビカタ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# まとめ	動詞,自立,*,*,一段,連用形,まとめる,マトメ,マトメ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
#
#
#
# 						記号,空白,*,*,*,*,
#
#
# 					,*,*
# Web	名詞,固有名詞,組織,*,*,*,Web,*,*
# ディレクター	名詞,一般,*,*,*,*,ディレクター,ディレクター,ディレクター
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 副業	名詞,一般,*,*,*,*,副業,フクギョウ,フクギョー
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# ？	記号,一般,*,*,*,*,？,？,？
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 取り	動詞,自立,*,*,五段・ラ行,連用形,取る,トリ,トリ
# 方	名詞,接尾,特殊,*,*,*,方,カタ,カタ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# オススメ	名詞,サ変接続,*,*,*,*,オススメ,オススメ,オススメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# エージェント	名詞,一般,*,*,*,*,エージェント,エージェント,エージェント
# まで	助詞,副助詞,*,*,*,*,まで,マデ,マデ
# まとめ	動詞,自立,*,*,一段,連用形,まとめる,マトメ,マトメ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
#
#
#
# 						記号,空白,*,*,*,*,
#
#
# 					,*,*
# エンジニア	名詞,一般,*,*,*,*,エンジニア,エンジニア,エンジニア
# 転職	名詞,サ変接続,*,*,*,*,転職,テンショク,テンショク
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 始める	動詞,自立,*,*,一段,基本形,始める,ハジメル,ハジメル
# 前	名詞,副詞可能,*,*,*,*,前,マエ,マエ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# ！	記号,一般,*,*,*,*,！,！,！
# 知っ	動詞,自立,*,*,五段・ラ行,連用タ接続,知る,シッ,シッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# おき	動詞,非自立,*,*,五段・カ行イ音便,連用形,おく,オキ,オキ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# 業界	名詞,一般,*,*,*,*,業界,ギョウカイ,ギョーカイ
# 知識	名詞,一般,*,*,*,*,知識,チシキ,チシキ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 、	記号,読点,*,*,*,*,、,、,、
# 採用	名詞,サ変接続,*,*,*,*,採用,サイヨウ,サイヨー
# 担当	名詞,サ変接続,*,*,*,*,担当,タントウ,タントー
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# 開発	名詞,サ変接続,*,*,*,*,開発,カイハツ,カイハツ
# 会社	名詞,一般,*,*,*,*,会社,カイシャ,カイシャ
# CEO	名詞,一般,*,*,*,*,CEO,*,*
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# インタビュー	名詞,サ変接続,*,*,*,*,インタビュー,インタビュー,インタビュー
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
#
#
#
# 						記号,空白,*,*,*,*,
#
#
# 					,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# 保存	名詞,サ変接続,*,*,*,*,保存,ホゾン,ホゾン
# 版	名詞,接尾,一般,*,*,*,版,バン,バン
# 】	記号,括弧閉,*,*,*,*,】,】,】
# 統計	名詞,サ変接続,*,*,*,*,統計,トウケイ,トーケイ
# 学	名詞,接尾,一般,*,*,*,学,ガク,ガク
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# おすすめ	名詞,サ変接続,*,*,*,*,おすすめ,オススメ,オススメ
# 書籍	名詞,一般,*,*,*,*,書籍,ショセキ,ショセキ
# 8	名詞,数,*,*,*,*,8,*,*
# 選	名詞,接尾,一般,*,*,*,選,セン,セン
#  	記号,空白,*,*,*,*, ,*,*
# |	名詞,サ変接続,*,*,*,*,|,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 文系	名詞,一般,*,*,*,*,文系,ブンケイ,ブンケイ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# でも	助詞,副助詞,*,*,*,*,でも,デモ,デモ
# 基礎	名詞,一般,*,*,*,*,基礎,キソ,キソ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 理解	名詞,サ変接続,*,*,*,*,理解,リカイ,リカイ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 役立つ	動詞,自立,*,*,五段・タ行,基本形,役立つ,ヤクダツ,ヤクダツ
# 書籍	名詞,一般,*,*,*,*,書籍,ショセキ,ショセキ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# ピックアップ	名詞,サ変接続,*,*,*,*,ピックアップ,ピックアップ,ピックアップ
# ！	記号,一般,*,*,*,*,！,！,！
#
#
#
# 						記号,空白,*,*,*,*,
#
#
# 					,*,*
# フリーランス	名詞,一般,*,*,*,*,フリーランス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 案件	名詞,一般,*,*,*,*,案件,アンケン,アンケン
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# ？	記号,一般,*,*,*,*,？,？,？
# 職種	名詞,一般,*,*,*,*,職種,ショクシュ,ショクシュ
# 別	名詞,接尾,一般,*,*,*,別,ベツ,ベツ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# とり方	名詞,一般,*,*,*,*,とり方,トリカタ,トリカタ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# 案件	名詞,一般,*,*,*,*,案件,アンケン,アンケン
# 紹介	名詞,サ変接続,*,*,*,*,紹介,ショウカイ,ショーカイ
# サイト	名詞,一般,*,*,*,*,サイト,サイト,サイト
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# まとめ	動詞,自立,*,*,一段,連用形,まとめる,マトメ,マトメ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
#
#
#
# 						記号,空白,*,*,*,*,
#
#
# 					,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# 保存	名詞,サ変接続,*,*,*,*,保存,ホゾン,ホゾン
# 版	名詞,接尾,一般,*,*,*,版,バン,バン
# 】	記号,括弧閉,*,*,*,*,】,】,】
# WordPress	名詞,固有名詞,組織,*,*,*,WordPress,*,*
# 初心者	名詞,一般,*,*,*,*,初心者,ショシンシャ,ショシンシャ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 独学	名詞,サ変接続,*,*,*,*,独学,ドクガク,ドクガク
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# Web	名詞,一般,*,*,*,*,Web,*,*
# サイト	名詞,一般,*,*,*,*,サイト,サイト,サイト
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 作る	動詞,自立,*,*,五段・ラ行,基本形,作る,ツクル,ツクル
# ため	名詞,非自立,副詞可能,*,*,*,ため,タメ,タメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 必要	名詞,形容動詞語幹,*,*,*,*,必要,ヒツヨウ,ヒツヨー
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 6	名詞,数,*,*,*,*,6,*,*
# つ	助動詞,*,*,*,下二・タ行,基本形,つ,ツ,ツ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 学習	名詞,サ変接続,*,*,*,*,学習,ガクシュウ,ガクシュー
# ステップ	名詞,一般,*,*,*,*,ステップ,ステップ,ステップ
# まとめ	動詞,自立,*,*,一段,連用形,まとめる,マトメ,マトメ
#
#
#
# 						記号,空白,*,*,*,*,
#
#
# 					,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# 体験	名詞,サ変接続,*,*,*,*,体験,タイケン,タイケン
# 談	名詞,接尾,一般,*,*,*,談,ダン,ダン
# 】	記号,括弧閉,*,*,*,*,】,】,】
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 学ん	動詞,自立,*,*,五段・バ行,連用タ接続,学ぶ,マナン,マナン
# で	助詞,接続助詞,*,*,*,*,で,デ,デ
# フリーランス	名詞,一般,*,*,*,*,フリーランス,*,*
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なる	動詞,自立,*,*,五段・ラ行,基本形,なる,ナル,ナル
# 方法	名詞,一般,*,*,*,*,方法,ホウホウ,ホーホー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# まとめ	動詞,自立,*,*,一段,連用形,まとめる,マトメ,マトメ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
#
#
#
# 						記号,空白,*,*,*,*,
#
#
# 					,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# 体験	名詞,サ変接続,*,*,*,*,体験,タイケン,タイケン
# 談	名詞,接尾,一般,*,*,*,談,ダン,ダン
# 】	記号,括弧閉,*,*,*,*,】,】,】
# 第	接頭詞,数接続,*,*,*,*,第,ダイ,ダイ
# 二	名詞,数,*,*,*,*,二,ニ,ニ
# 新卒	名詞,一般,*,*,*,*,新卒,シンソツ,シンソツ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 転職	名詞,サ変接続,*,*,*,*,転職,テンショク,テンショク
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# 未	接頭詞,名詞接続,*,*,*,*,未,ミ,ミ
# 経験	名詞,サ変接続,*,*,*,*,経験,ケイケン,ケイケン
# 職	名詞,接尾,一般,*,*,*,職,ショク,ショク
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 成功	名詞,サ変接続,*,*,*,*,成功,セイコウ,セイコー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# ため	名詞,非自立,副詞可能,*,*,*,ため,タメ,タメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 3	名詞,数,*,*,*,*,3,*,*
# つ	助動詞,*,*,*,下二・タ行,基本形,つ,ツ,ツ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 方法	名詞,一般,*,*,*,*,方法,ホウホウ,ホーホー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# まとめ	動詞,自立,*,*,一段,連用形,まとめる,マトメ,マトメ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
#
#
# ['    プログラミング独学者でも効率的に学べる超絶お勧めの5つの勉強法をまとめてみた\n\t\t  \t\t全取材あり！ | エンジニアになれるプログラミングスクールおすすめ5社まとめ\n                  プログラミング独学者でも効率的に学べる超絶お勧めの5つの勉強法をまとめてみた\n                          プログラミング初心者,プログラミング学習法\n                      ≪DAINOTE編集部推薦のDAIが実際に取材、体験してみて、特にオススメのプログラミングスクール一覧≫\n【第1位】ポテパンキャンプ：サーバーサイドエンジニアに未経験から転職して年収700万円代を目指したい人向け！ | レビュー記事\n【第2位】CodeCamp: 未経験から副業でWeb制作し、副業で月10万円ほどを目指したい人向け！業界最安値！ | レビュー記事\n【第3位】TechAcademy:未経験から副業でWeb制作し、副業で月10万円ほどを目指したい人向け！ | レビュー記事\n【第4位】デジタルハリウッドスタジオbyLIG：未経験からWebデザイナーとして転職した人向け！教室で学びたい人向け！ | レビュー記事\n【第5位】Aidemy：Python・AIに特化したプログラミングスクール。 | レビュー記事\n\n\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t転職で全額キャッシュバッグ。エンジニア転職したいなら絶対にココ\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tポテパンキャンプ：未経験からの就職実績がNo1のRuby特化スクール\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tポテパンキャンプの公式HPを確認する\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\n\t\t\n\t\t\n\n\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t【副業特化 Web制作をするならココ！】\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCodeCamp: Web制作に特化したプログラミングスクール\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCodeCampで無料カウンセリングを受けてみる\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\n\t\t\n\t\t\n\n\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t業界最安のプログラミングスクール\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tTechAcademy:完全オフラインで学べる最も有名なプログラミングスクール\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tTechAcademy Webデザインコースで無料体験してみる\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\n\t\t\n\t\t\n\n\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t専門学校のコースが受けられる！\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tデジタルハリウッドStudio by LIG\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tデジタルハリウッドStudio by LIGを見てみる\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\n\t\t\n\t\t\n\n\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t大学法人・東証一部上場企業も導入\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tAidemy: AI教育No1の実績。本気でAIを学びたいならココ！\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tAidemyで無料カウンセリングを受けてみる\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\n\t\t\n\t\t\nこんにちは！DAINOTE編集部のDAIです。\n突然ですがプログラミングを学び始めの時って死ぬほど大変じゃないですか？プログラミングの学習って初心者だったときマジで非効率だったのを思い出しました。\nここ最近はクラウドソーシングで案件取ったり、データ分析などをPythonでできるようになってきたのですが、最初の勉強方法とだいぶ変わってきたなぁと感じています。\n\nそこで、最近ツイッターで初心者の視点からよい学習方法を発信しているのですが、ツイートの中で反響が大きかったものをまとめました。プログラミングを独学でやっている人に、おすすめの学習方法についてです。\n目次勉強法①. 作業ログをGithubのIssueに残す勉強法②. 2週間で基礎は終わらせる勉強法③. プロダクトベースのチュートリアルをやるRails チュートリアルTutorials PointsUdemyQiitaYoutube勉強法④. メンターに聞きながらトライアンドエラーをする仕事として通用するプログラミング力を得るためにはプログラミング独学で躓くポイントオススメのプログラミングスクール勉強法5. 自分のプロダクトを決めて作りはじめるその他 プログラミングを独学するうえでよくいただく質問「プログラミングを独学するなら、本の方がいいですか？Webの方がいいですか？」「プログラミングで独学するうえで、おすすめの言語を教えてください」まとめプログラミングスクールを選ぶなら\n勉強法①. 作業ログをGithubのIssueに残す\nGithubはソースコード管理を行えるソフトウェアですが、その中でIssueという掲示板みたいなものがあります。そこに、どういう処理を行っていて、何がうまくいっていないのかを作業ログとして残しておくのがおすすめです。\n\nプログラミング初心者はGithubで作業ログ残してツイッターに連携して作業すると、優しいお兄さんたちがコメントしてくれるのですごくおすすめ。作業も可視化されるし、質問しなくても何しようとしているのか見てわかればこたえてくれやすくなる。\n&mdash; DAI (@never_be_a_pm) April 14, 2018\n\nGithubのIssueとは、簡単いいうと掲示板みたいなもので、そこで開発についてやりとりができるんですよね。それがソースコード管理システムである、Githubに標準機能としておいてあります。例がないとわかりにくいと思うので、こちらが僕がツイッターの自動化アプリを作っているときのイシューです。 こんな感じで、自分が作業をしているときのログを適宜張り付けています。\n\nこれをやるのには2つメリットがあります。\n一つは、プログラミングの作業ログを残せるので、自分が今どのような処理をしているのか言語化しながら確認することで、状況の理解がしやすくなるという点です。独学しているときの形跡が残せるので、後で見直すときにも使えます。\nもう一つが、ツイッター上で自分のプログラムをGithubのイシューを公開しておくと、だれか優しい人がぱっと見てヒントを出してくれたりするからです。\nツイッター上だと、140文字しかないので、すべてを説明するには文字数が足りませんし、いきなり「ちょっと教えて」と見ず知らずの人に教えるのは正直ハードルが高いと思います。（しかも実際いいよ～なんて言ってくれる人も少ないと思います。）\n勉強法②. 2週間で基礎は終わらせる\n\nプログラミング基礎は、Progateで十分です！これだけで十分独学可能です。\n≫\xa0https://prog-8.com\n何カ月も基礎の本をず～とやっている人がいますが、Progateで学びたい言語をある程度勉強したら、さっさとプロダクトを創りましょう。基礎だけやってても球拾いだけやってるだけで、実際に野球ができるかって言われたら、実践詰まないとできないですよね。\n本は、それを利用して学習を進めていくよりも、困った時のリファレンスとして使う側面が大きいです。普通にプログラミング学習の基礎を学びたいのであれば、実際に書きながら基礎を学べるProgateやAidemyなどのサイトを利用して、独学でやってみるのが一番早いです。\nたまにず～とProgateでレベル上げしている人がいるのですが、これはポケモンで言うとひたすらマサラタウンでてひたすらコラッタを倒し続けているような状態なので、早く外に出たほうがいいです。\n勉強法③. プロダクトベースのチュートリアルをやる\nお勧めは、「～を作ろう！」系のチュートリアルをひたすらこなすのがよいです。\n写経でもよいので、どういうアプリがどういう構造で作られていて、どういう風に作ることができるのか、ひたすら型を学んで ...
# プログラミング(72) の(36) スクール(34) Web(27) チュートリアル(27) 独学(25) 人(24) 転職(21) おすすめ(19) エンジニア(18) 学習(17) こと(17) 勉強(15) 化(15) /(15) 法(14) よう(14) 的(13) ,(13) 副業(13) .(13) 制作(12) とき(12) お(11) 体験(11) CodeCamp(11) :(11) 機能(11) 記事(10) 2(10) 特(10) 方法(10) 基礎(10) プロダクト(10) 何(10) ポテパンキャンプ(9) 経験(9) 作業(9) メンター(9) 仕事(9) _(9) インタビュー(9) 5(8) 初心者(8) 1(8) 未(8) 3(8) TechAcademy(8) ツイッター(8) ログ(8)
