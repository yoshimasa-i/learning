# %% [markdown]
# ## テキストマイニング
#
# 出現頻度を取得

# %%
# text-mining.py
 
# python解析器janomeをインポート - 1
from janome.tokenizer import Tokenizer
 
# 形態素解析用オブジェクトの生成 - 2
text = Tokenizer()
 
# txtファイルからデータの読み込み - 3
text_file = open("text_suna.txt")
bindata = text_file.read()
txt = bindata
 
# txtから読み込んだデータを形態素解析 - 4
lines = txt.split("\r\n")
for i in lines:
    print(i)
    print("\n")
    text_c = text.tokenize(i)
    for j in text_c:
      print(j)
 
print("\n")
 
# テキストを一行ごとに処理 - 5
word_dic = {}
lines_1 = txt.split("\r\n")
print(lines_1)
print("\n")
for line in lines_1:
    malist = text.tokenize(line)
    for w in malist:
	    word = w.surface
	    ps = w.part_of_speech # 品詞 - 6
	    if ps.find("名詞") < 0: continue # 名詞だけをカウント - 7
	    if not word in word_dic:
		    word_dic[word] = 0
	    word_dic[word] += 1
 
# よく使われる単語を表示 - 8
keys = sorted(word_dic.items(), key=lambda x:x[1], reverse=True)
for word, cnt in keys[:50]:
    print("{0}({1}) ".format(word,cnt), end="")
# Out:
# LAKAI ラカイ(シューズ) - 南国スケボーショップ砂辺：スケートボード、デッキの通販に最適！
#
#
# 								SKATEBOARDスケートボード
#
#
#
#
# 完成済みスケートボード
#
# 	 COMPETE SKATEBOARD組み立て済みトリック用ボード
#
#
# 	 KIDS COMPLETE組み立て済みキッズサイズボード
#
#
# 	 CRUISER&LONGBOARD組み立て済みロング/クルーザー
#
#
# デッキ単品
#
# 	 DECKデッキ ブランド別一覧
#
#
# 	 BLANK格安無地デッキ
#
#
# 	 KIDS DECKキッズサイズ デッキ
#
#
# 	 OLDSCHOOLオールドスクールシェイプ
#
#
#
#
#
#
#
# 								SKATE PARTSスケボーパーツ
#
#
#
#
# 主要パーツ
#
# 	 TRUCKトラック
#
#
# 	 WHEELSトリック用ウィール
#
#
# 	 CRUISER WHEELSクルーザーウィール
#
#
# 	 BEARINGSベアリング
#
#
# 	 HARDWHEARハードウェア(ボルト)
#
#
# 	 GRIP TAPEデッキテープ
#
#
# アクセサリ/ギア
#
# 	 BUSHINGSブッシュ/クッシュゴム
#
#
# 	 RISER PADライザーパッド
#
#
# 	 SKATEBOARD WAXカーブ ワックス
#
#
# 	 SKATE TOOLスケートツール 工具
#
#
# 	 BOARD ACCESSORIESデッキ アクセサリー
#
#
# 	 SPARE & OTHERスペア その他
#
#
# 	 PROTECTORプロテクター
#
#
# 	 HELMETヘルメット
#
#
# 	 MEDIA & DVD映像/雑誌
#
#
# 	 OTHER X-TREAMその他Xポーツ用品
#
#
#
#
#
#
#
# 								SHOESシューズ
#
#
#
#
#
#
# 	 SHOES BRANDシューズ ブランド別一覧
#
#
# 	 WOMENS SHOESレディース シューズ
#
#
# 	 KIDS SHOESキッズシューズ
#
#
# 	 SANDALサンダル その他
#
#
#
#
#
#
#
# 								APPAREL服/ウェア
#
#
#
#
# メンズ
#
# 	 T-SHIRTSTシャツ
#
#
# 	 L/S TEEロングTシャツ
#
#
# 	 POLO & WOVENポロシャツ その他シャツ
#
#
# 	 SWAET & PARKAパーカー/スウェット
#
#
# 	 OUTER JACKETアウター/ジャケット
#
#
# 	 BOTTOMSボトム/パンツ
#
#
# ヘッド/ハードウェア
#
# 	 CAP & HATSキャップ/帽子
#
#
# 	 BEANIESニットキャップ/ビーニー
#
#
# 	 BAG & BACKPACKバッグ/バックパック
#
#
# キッズ&レディース
#
# 	 KIDS ITEMキッズアイテム一覧
#
#
# 	 WOMENS ITEMレディースアイテム一覧
#
#
#
#
#
#
#
# 								ACCESSORY小物/グッズ
#
#
#
#
#
#
# 	 STICKERステッカー
#
#
# 	 SUNGLASSサングラス
#
#
# 	 KEYCHAINキーホルダー
#
#
# 	 PATCHESパッチ/ワッペン
#
#
# 	 PINSピンバッチ
#
#
# 	 WATCH時計
#
#
# 	 WALET財布/ウォレット
#
#
# 	 BELTベルト
#
#
# 	 ACCESSORIESアクセサリー
#
#
# 	 SOCKSソックス/靴下
#
#
# 	 GLOVE手袋
#
#
# 	 WRISTBANDリストバンド
#
#
# 	 OTHER GOODSその他グッズ
#
#
#
#
#
#
#
# 								FINGERBOARD指スケ
#
#
#
#
#
#
# 	 ALL FINGER BOARDS指スケ全品
#
#
# 	 TECH DECKテックデッキ
#
#
# 	 CLOSE UPクローズアップ
#
#
# 	 BLACK RIVERブラックリバー
#
#
# 	 4CORNERフォーコーナー
#
#
# 	 CIRCUIT BOARDサーキット
#
#
# 	 FLICK TRIXフィンガーバイク
#
#
#
#
#
#
#
#
# 								POPULAR人気カテ
#
#
#
#
#
#
#
#  ブランド(一覧)
#
#
#
#
#  在庫処分セール会場
#
#
#
#
#  指スケ(全アイテム)
#
#
#
#
#  ワゴンセール
#
#
#
#
#
#
#
#
# 								CONTENT読み物
#
#
#
#
#
#
#
#  メルマガ登録・更新・解除
#
#
#
#
#  指スケって何？
#
#
#
#
#  よくあるご質問
#
#
#
#
#  ウェアハウス即売会(予約制)のお知らせ
#
#
#
#
#  スケートボードの購入方法
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    ご利用ガイド
#
#
#
#     お問い合わせ
#
#
#
#    ショップブログ
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   MENU
#
#
#
#   SEARCH
#
#
#
#
#
#   CART
#
#
#
#
#
#
#
#    メニューを閉じる
#
#
#
#
#
#
#
#
#    HOME
#
#
#
#
#   USER
#
#
#
#
#
#    会員登録
#
#
#
#
#    ログイン
#
#
#
#
#    アカウント
#
#
#
#   CATEGORY
#
#
#
#
#    SKATEBOARDスケートボードを探す
#
#
#
#
#
#
#
#    - 完成済みスケボー
#
# 	 COMPETE SKATEBOARD組み立て済みトリック用ボード
#
#
# 	 KIDS COMPLETE組み立て済みキッズサイズボード
#
#
# 	 CRUISER&LONGBOARD組み立て済みロング/クルーザー
#
#    - デッキ単品
#
# 	 DECKデッキ ブランド別一覧
#
#
# 	 BLANK格安無地デッキ
#
#
# 	 KIDS DECKキッズサイズ デッキ
#
#
# 	 OLDSCHOOLオールドスクールシェイプ
#
#
#
#
#
#
#    SKATE PARTSスケボーパーツを探す
#
#
#
#
#
#
#
#    - 主要パーツ
#
# 	 TRUCKトラック
#
#
# 	 WHEELSトリック用ウィール
#
#
# 	 CRUISER WHEELSクルーザーウィール
#
#
# 	 BEARINGSベアリング
#
#
# 	 HARDWHEARハードウェア(ボルト)
#
#
# 	 GRIP TAPEデッキテープ
#
#    - アクセサリ/ギア
#
# 	 BUSHINGSブッシュ/クッシュゴム
#
#
# 	 RISER PADライザーパッド
#
#
# 	 SKATEBOARD WAXカーブ ワックス
#
#
# 	 SKATE TOOLスケートツール 工具
#
#
# 	 BOARD ACCESSORIESデッキ アクセサリー
#
#
# 	 SPARE & OTHERスペア その他
#
#
# 	 PROTECTORプロテクター
#
#
# 	 HELMETヘルメット
#
#
# 	 MEDIA & DVD映像/雑誌
#
#
# 	 OTHER X-TREAMその他Xポーツ用品
#
#
#
#
#
#
#
#    SHOESシューズを探す
#
#
#
#
#
#
#
#
# 	 SHOES BRANDシューズ ブランド別一覧
#
#
# 	 WOMENS SHOESレディース シューズ
#
#
# 	 KIDS SHOESキッズシューズ
#
#
# 	 SANDALサンダル その他
#
#
#
#
#
#
#
#    APPAREL服/ウェアを探す
#
#
#
#
#
#
#
#    - メンズ
#
# 	 T-SHIRTSTシャツ
#
#
# 	 L/S TEEロングTシャツ
#
#
# 	 POLO & WOVENポロシャツ その他シャツ
#
#
# 	 SWAET & PARKAパーカー/スウェット
#
#
# 	 OUTER JACKETアウター/ジャケット
#
#
# 	 BOTTOMSボトム/パンツ
#    - ヘッド/ハードウェア
#
# 	 CAP & HATSキャップ/帽子
#
#
# 	 BEANIESニットキャップ/ビーニー
#
#
# 	 BAG & BACKPACKバッグ/バックパック
#
#    - キッズ&レディース
#
# 	 KIDS ITEMキッズアイテム一覧
#
#
# 	 WOMENS ITEMレディースアイテム一覧
#
#
#
#
#
#
#
#    ACCESSORY小物/グッズを探す
#
#
#
#
#
#
#
#
# 	 STICKERステッカー
#
#
# 	 SUNGLASSサングラス
#
#
# 	 KEYCHAINキーホルダー
#
#
# 	 PATCHESパッチ/ワッペン
#
#
# 	 PINSピンバッチ
#
#
# 	 WATCH時計
#
#
# 	 WALET財布/ウォレット
#
#
# 	 BELTベルト
#
#
# 	 ACCESSORIESアクセサリー
#
#
# 	 SOCKSソックス/靴下
#
#
# 	 GLOVE手袋
#
#
# 	 WRISTBANDリストバンド
#
#
# 	 OTHER GOODSその他グッズ
#
#
#
#
#
#
#
#    FINGERBOARD指スケを探す
#
#
#
#
#
#
#
#
# 	 ALL FINGER BOARDS指スケ全品
#
#
# 	 TECH DECKテックデッキ
#
#
# 	 CLOSE UPクローズアップ
#
#
# 	 BLACK RIVERブラックリバー
#
#
# 	 4CORNERフォーコーナー
#
#
# 	 CIRCUIT BOARDサーキット
#
#
# 	 FLICK TRIXフィンガーバイク
#
#
#
#
#
#   POPULAR
#
#
#
#
#
#    ブランド(一覧)
#
#
#
#
#    在庫処分セール会場
#
#
#
#
#    指スケ(全アイテム)
#
#
#
#
#    ワゴンセール
#
#
#
#   コンテンツ
#
#
#
#
#
#    メルマガ登録・更新・解除
#
#
#
#
#    指スケって何？
#
#
#
#
#    よくあるご質問
#
#
#
#
#    ウェアハウス即売会(予約制)のお知らせ
#
#
#
#
#    スケートボードの購入方法
#
#
#
#
#
#
#    ご利用ガイド
#
#
#
#
#    お問い合わせ
#
#
#
#
#    ショップブログ
#
#
#
#
#
#
#
#
#
#    ホーム
#
#
#
#    スニーカー(SHOES)
#
#
#
#    LAKAI ラカイ(シューズ)
#
#
#
#
#
#
#
#
#
# 5BORO ファイブボロ(全アイテム)
# ADIDAS SKATEBOARDING アディダス(全アイテム)
# ALIEN WORKSHOP エイリアンワークショップ(全アイテム)
# ACE TRUCKS エース(全アイテム)
# ANTIHERO アンタイヒーロー(全アイテム)
# ANDALE BEARINGS アンダレー(全アイテム)
# ALMOST オルモスト(全アイテム)
# ALTAMONT オルタモント(全アイテム)
# BAKER ベーカー(全アイテム)
# BIRD HOUSE バードハウス(全アイテム)
# BLACK LABEL ブラックレーベル(全アイテム)
# BLIND ブラインド(全アイテム)
# BONES ボーンズ(全アイテム)
# BRIXTON ブリクストン(全アイテム)
# BRONSON ブロンソン(全アイテム)
# BRO STYLE ブロスタイル(全アイテム)
# CHOCOLATE チョコレート(全アイテム)
# CITY SKATEBOARDS シティ(全アイテム)
# CLICHE クリシェ(全アイテム)
# CONVERSE CONS コンズ(全アイテム)
# CONSOLIDATED コンソリデーテッド(全アイテム)
# CREATURE クリーチャー(全アイテム)
# DARKSTAR ダークスター(全アイテム)
# DC ディーシー(全アイテム)
# DEATHWISH デスウィッシュ(全アイテム)
# DEATH DIGITAL デスデジタル(全アイテム)
# DGK ディージーケー(全アイテム)
# DIAMOND SUPPLY ダイヤモンドサプライ(全アイテム)
# DIAL TONE WHEELS ダイアルトーン(全アイテム)
# DOG TOWN ドッグタウン(全アイテム)
# EMERICA エメリカ(全アイテム)
# ETNIES エトニーズ(全アイテム)
# EXPEDITION ONE エクスぺディションワン(全アイテム)
# ENJOI エンジョイ(全アイテム)
# ES エス(全アイテム)
# ELEMENT エレメント(全アイテム)
# FALLEN フォールン(全アイテム)
# FOOTPRINT フットプリント(全アイテム)
# FOURSTAR フォースター(全アイテム)
# FOUNDATION ファンデーション(全アイテム)
# FKD エフケーディー(全アイテム)
# FLIP フリップ(全アイテム)
# FOX RACING フォックス(全アイテム)
# GOLD WHEELS ゴールド(全アイテム)
# GIRL ガールスケートボード(全アイテム)
# GLOBE グローブ(全アイテム)
# GRAVIS グラビス(全アイテム)
# GRIZZLY グリズリー(全アイテム)
# HABITAT ハビタット(全アイテム)
# HAPPY HOUR ハッピーアワー(全アイテム)
# HARD LUCK ハードラック(全アイテム)
# HEROIN ヘロイン(全アイテム)
# HOOK UPS フックアップ(全アイテム)
# HUBBA WHEELS ハバ(全アイテム)
# HUF ハフ(全アイテム)
# HURLEY ハーレー(全アイテム)
# I-PATH アイパス(全アイテム)
# INDEPENDENT インディペンデント(全アイテム)
# ISLE SKATEBOARDS アイル(全アイテム)
# JSLV ジャスリブ(全アイテム)
# KR3W クルー(全アイテム)
# KROOKED クルックド(全アイテム)
# KRUX クラックス(全アイテム)
# LAKAI ラカイ(全アイテム)
# LEVI’S SKATEBOARDING リーバイス(全アイテム)
# LUCKY ラッキー(全アイテム)
# LE SKATEBOARDS ライフエクステンション(全アイテム)
# LOUD HEADPHONES ラウド(全アイテム)
# LRG エルアールジー(全アイテム)
# MAGENTA マゼンタ(全アイテム)
# MAXALLURE マックスアルーア(全アイテム)
# MOMENTUM モメンタム(全アイテム)
# MONSTER ENERGY モンスターエナジー(全アイテム)
# MYSTERY ミステリー(全アイテム)
# NINJA ニンジャ(全アイテム)
# NOR CAL ノーカル(全アイテム)
# NESTA BRAND ネスタブランド(全アイテム)
# NEW BALANCE NUMERIC ニューバランス(全アイテム)
# NEFF ネフ(全アイテム)
# NIKE SB ナイキエスビー(全アイテム)
# OJ WHEELS オージェイ(全アイテム)
# ORGANIKA オルガニカ(全アイテム)
# PENNY ペニー(全アイテム)
# PLAN-B プランビー(全アイテム)
# PIG WHEELS ピッグ(全アイテム)
# POWELL パウエル(全アイテム)
# PRIMITIVE プリミティブ(全アイテム)
# POLAR ポーラー(全アイテム)
# REAL リアル(全アイテム)
# ROYAL TRUCK ロイヤル(全アイテム)
# ROXY ロキシー(全アイテム)
# SANTA CRUZ サンタクルーズ(全アイテム)
# SATORI サトリ(全アイテム)
# SHAKE JUNT シェイクジャント(全アイテム)
# SHORTYS ショーティーズ(全アイテム)
# SILVER シルバー(全アイテム)
# SK8MAFIA スケートマフィア(全アイテム)
# SKULL SKATES スカルスケーツ(全アイテム)
# SLAVE スレイブ(全アイテム)
# SPEED DEMONS スピードデーモン(全アイテム)
# SPITFIRE スピットファイア(全アイテム)
# STEREO ステレオ(全アイテム)
# STATE FOOTWEAR ステイト(全アイテム)
# STUSSY ステューシー(全アイテム)
# THRASHER スラッシャー(全アイテム)
# TOY MACHINE トイマシーン(全アイテム)
# THUNDER TRUCKS サンダー(全アイテム)
# THINK シンク(全アイテム)
# TENSOR テンサー(全アイテム)
# TRAFFIC トラフィック(全アイテム)
# VANS バンズ(全アイテム)
# ZOO YORK ズーヨーク(全アイテム)
# VENTURE ベンチャー(全アイテム)
# VOLCOM ボルコム(全アイテム)
# VOLCOM GIRLS ボルコム ガールズ(全アイテム)
# WELCOME ウェルカム(全アイテム)
# WKND ウィークエンド(全アイテム)
# WORLD INDUSTRIES ワールド(全アイテム)
# X-LARGE エクストララージ(全アイテム)
# Z-FLEX ジーフレックス(全アイテム)
# ZERO ゼロ(全アイテム)
#
# LAKAI ラカイ(シューズ)
#
#    【LAKAI LIMITED FOOTWEAR ラカイ スケート シューズ】RILEY HAWK 2 SHOES【バーガンディ】NO79
#
#
#  9,720円
#
#
#   	定価&nbsp;11,880円
#
#
#    LAKAI史上最高の衝撃吸収力！ライリー・ホークシグネチャーモデル第二弾！
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    【LAKAI LIMITED FOOTWEAR ラカイ スケート シューズ】GRIFFIN SHOES XLK【ブラックxクリスタル】NO78
#
#
#  11,178円
#
#
#   	定価&nbsp;12,420円
#
#
#    定番モデルにクリスタルソールとXLKを搭載したハイエンドモデル！
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    【LAKAI LIMITED FOOTWEAR ラカイ スケート シューズ】FREMONTE SHOES XLK【ブラックxホワイト】NO77
#
#
#  11,178円
#
#
#   	定価&nbsp;12,420円
#
#
#    脱げにくい一体型ソックスアッパー仕様！XLKを搭載した最上級モデル！
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    【LAKAI LIMITED FOOTWEAR ラカイ スケート シューズ】OWEN VLK SHOES NICO HIRAGA NO76
#
#
#  8,640円
#
#
#   	定価&nbsp;10,800円
#
#
#    軽快さと履き心地抜群！スリッポンシリーズからNICOプロモデル！
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    【LAKAI LIMITED FOOTWEAR ラカイ スケート シューズ】STAPLE【ブラック】NO75
#
#
#  8,694円
#
#
#   	定価&nbsp;12,420円
#
#
#    2001年発売の名作シューズが新技術で復刻！
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    【LAKAI LIMITED FOOTWEAR ラカイ スケート シューズ】GRIFFIN XLK SHOES スウェード【ネイビー】NO73
#
#
#  8,206円
#
#
#   	定価&nbsp;12,744円
#
#
#    XLKソールを装備したハイエンドモデル！
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    【ラカイ LAKAI スケート シューズ】CAMBY DUCK SHOES キャンバス【グリーン】NO68
#
#
#  5,428円
#
#
#   	定価&nbsp;10,800円
#
#
#    【オススメ】LAKAIシューズの CAMBY モデル新入荷！
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    【ラカイ LAKAI スケート シューズ】MJ DUCK SHOES スウェード x キャンバス【ネイビー】NO67
#
#
#  5,428円
#
#
#   	定価&nbsp;11,800円
#
#
#    【半額セール】LAKAIシューズの MJ モデル新入荷！
# LAKAI	名詞,固有名詞,組織,*,*,*,LAKAI,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ラカイ	名詞,一般,*,*,*,*,ラカイ,*,*
# (	名詞,サ変接続,*,*,*,*,(,*,*
# シューズ	名詞,一般,*,*,*,*,シューズ,シューズ,シューズ
# )	名詞,サ変接続,*,*,*,*,),*,*
#  	記号,空白,*,*,*,*, ,*,*
# -	名詞,サ変接続,*,*,*,*,-,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 南国	名詞,一般,*,*,*,*,南国,ナンゴク,ナンゴク
# スケボーショップ	名詞,一般,*,*,*,*,スケボーショップ,*,*
# 砂辺	名詞,固有名詞,地域,一般,*,*,砂辺,スナベ,スナベ
# ：	記号,一般,*,*,*,*,：,：,：
# スケート	名詞,一般,*,*,*,*,スケート,スケート,スケート
# ボード	名詞,一般,*,*,*,*,ボード,ボード,ボード
# 、	記号,読点,*,*,*,*,、,、,、
# デッキ	名詞,一般,*,*,*,*,デッキ,デッキ,デッキ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 通販	名詞,一般,*,*,*,*,通販,ツウハン,ツーハン
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 最適	名詞,一般,*,*,*,*,最適,サイテキ,サイテキ
# ！	記号,一般,*,*,*,*,！,！,！
#
#
#
# 									記号,空白,*,*,*,*,
#
#
# 								,*,*
# SKATEBOARD	名詞,固有名詞,組織,*,*,*,SKATEBOARD,*,*
# スケート	名詞,一般,*,*,*,*,スケート,スケート,スケート
# ボード	名詞,一般,*,*,*,*,ボード,ボード,ボード
#
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
#
# ,*,*
# 完成	名詞,サ変接続,*,*,*,*,完成,カンセイ,カンセイ
# 済み	名詞,接尾,一般,*,*,*,済み,ズミ,ズミ
# スケート	名詞,一般,*,*,*,*,スケート,スケート,スケート
# ボード	名詞,一般,*,*,*,*,ボード,ボード,ボード
#
#
# 	 	記号,空白,*,*,*,*,
#
# 	 ,*,*
# COMPETE	名詞,固有名詞,組織,*,*,*,COMPETE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# SKATEBOARD	名詞,固有名詞,組織,*,*,*,SKATEBOARD,*,*
# 組み立て	名詞,一般,*,*,*,*,組み立て,クミタテ,クミタテ
# 済み	名詞,接尾,一般,*,*,*,済み,ズミ,ズミ
# トリック	名詞,一般,*,*,*,*,トリック,トリック,トリック
# 用	名詞,接尾,一般,*,*,*,用,ヨウ,ヨー
# ボード	名詞,一般,*,*,*,*,ボード,ボード,ボード
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# KIDS	名詞,固有名詞,組織,*,*,*,KIDS,*,*
#  	記号,空白,*,*,*,*, ,*,*
# COMPLETE	名詞,固有名詞,組織,*,*,*,COMPLETE,*,*
# 組み立て	名詞,一般,*,*,*,*,組み立て,クミタテ,クミタテ
# 済み	名詞,接尾,一般,*,*,*,済み,ズミ,ズミ
# キッズサイズボード	名詞,一般,*,*,*,*,キッズサイズボード,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# CRUISER	名詞,固有名詞,組織,*,*,*,CRUISER,*,*
# &	名詞,サ変接続,*,*,*,*,&,*,*
# LONGBOARD	名詞,一般,*,*,*,*,LONGBOARD,*,*
# 組み立て	名詞,一般,*,*,*,*,組み立て,クミタテ,クミタテ
# 済み	名詞,接尾,一般,*,*,*,済み,ズミ,ズミ
# ロング	名詞,一般,*,*,*,*,ロング,ロング,ロング
# /	名詞,サ変接続,*,*,*,*,/,*,*
# クルーザー	名詞,一般,*,*,*,*,クルーザー,クルーザー,クルーザー
#
#
#
# 	記号,空白,*,*,*,*,
#
#
# ,*,*
# デッキ	名詞,一般,*,*,*,*,デッキ,デッキ,デッキ
# 単品	名詞,一般,*,*,*,*,単品,タンピン,タンピン
#
#
# 	 	記号,空白,*,*,*,*,
#
# 	 ,*,*
# DECK	名詞,固有名詞,組織,*,*,*,DECK,*,*
# デッキ	名詞,一般,*,*,*,*,デッキ,デッキ,デッキ
#  	記号,空白,*,*,*,*, ,*,*
# ブランド	名詞,一般,*,*,*,*,ブランド,ブランド,ブランド
# 別	名詞,接尾,一般,*,*,*,別,ベツ,ベツ
# 一覧	名詞,サ変接続,*,*,*,*,一覧,イチラン,イチラン
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# BLANK	名詞,固有名詞,組織,*,*,*,BLANK,*,*
# 格安	名詞,一般,*,*,*,*,格安,カクヤス,カクヤス
# 無地	名詞,一般,*,*,*,*,無地,ムジ,ムジ
# デッキ	名詞,一般,*,*,*,*,デッキ,デッキ,デッキ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# KIDS	名詞,固有名詞,組織,*,*,*,KIDS,*,*
#  	記号,空白,*,*,*,*, ,*,*
# DECK	名詞,固有名詞,組織,*,*,*,DECK,*,*
# キッズサイズ	名詞,一般,*,*,*,*,キッズサイズ,*,*
#  	記号,空白,*,*,*,*, ,*,*
# デッキ	名詞,一般,*,*,*,*,デッキ,デッキ,デッキ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# OLDSCHOOL	名詞,固有名詞,組織,*,*,*,OLDSCHOOL,*,*
# オールドスクールシェイプ	名詞,一般,*,*,*,*,オールドスクールシェイプ,*,*
#
#
#
#
#
#
#
#
# 									記号,空白,*,*,*,*,
#
#
#
#
#
#
#
# 								,*,*
# SKATE	名詞,固有名詞,組織,*,*,*,SKATE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# PARTS	名詞,固有名詞,組織,*,*,*,PARTS,*,*
# スケボーパーツ	名詞,一般,*,*,*,*,スケボーパーツ,*,*
#
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
#
# ,*,*
# 主要	名詞,形容動詞語幹,*,*,*,*,主要,シュヨウ,シュヨー
# パーツ	名詞,一般,*,*,*,*,パーツ,パーツ,パーツ
#
#
# 	 	記号,空白,*,*,*,*,
#
# 	 ,*,*
# TRUCK	名詞,固有名詞,組織,*,*,*,TRUCK,*,*
# トラック	名詞,一般,*,*,*,*,トラック,トラック,トラック
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# WHEELS	名詞,固有名詞,組織,*,*,*,WHEELS,*,*
# トリック	名詞,一般,*,*,*,*,トリック,トリック,トリック
# 用	名詞,接尾,一般,*,*,*,用,ヨウ,ヨー
# ウィール	名詞,一般,*,*,*,*,ウィール,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# CRUISER	名詞,固有名詞,組織,*,*,*,CRUISER,*,*
#  	記号,空白,*,*,*,*, ,*,*
# WHEELS	名詞,固有名詞,組織,*,*,*,WHEELS,*,*
# クルーザーウィール	名詞,一般,*,*,*,*,クルーザーウィール,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# BEARINGS	名詞,固有名詞,組織,*,*,*,BEARINGS,*,*
# ベアリング	名詞,一般,*,*,*,*,ベアリング,ベアリング,ベアリング
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# HARDWHEAR	名詞,固有名詞,組織,*,*,*,HARDWHEAR,*,*
# ハードウェア	名詞,一般,*,*,*,*,ハードウェア,ハードウェア,ハードウェア
# (	名詞,サ変接続,*,*,*,*,(,*,*
# ボルト	名詞,一般,*,*,*,*,ボルト,ボルト,ボルト
# )	名詞,サ変接続,*,*,*,*,),*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# GRIP	名詞,固有名詞,組織,*,*,*,GRIP,*,*
#  	記号,空白,*,*,*,*, ,*,*
# TAPE	名詞,固有名詞,組織,*,*,*,TAPE,*,*
# デッキ	名詞,一般,*,*,*,*,デッキ,デッキ,デッキ
# テープ	名詞,一般,*,*,*,*,テープ,テープ,テープ
#
#
#
# 	記号,空白,*,*,*,*,
#
#
# ,*,*
# アクセサリ	名詞,一般,*,*,*,*,アクセサリ,アクセサリ,アクセサリ
# /	名詞,サ変接続,*,*,*,*,/,*,*
# ギア	名詞,一般,*,*,*,*,ギア,ギア,ギア
#
#
# 	 	記号,空白,*,*,*,*,
#
# 	 ,*,*
# BUSHINGS	名詞,固有名詞,組織,*,*,*,BUSHINGS,*,*
# ブッシュ	名詞,固有名詞,人名,姓,*,*,ブッシュ,ブッシュ,ブッシュ
# /	名詞,サ変接続,*,*,*,*,/,*,*
# クッシュゴム	名詞,一般,*,*,*,*,クッシュゴム,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# RISER	名詞,固有名詞,組織,*,*,*,RISER,*,*
#  	記号,空白,*,*,*,*, ,*,*
# PAD	名詞,固有名詞,組織,*,*,*,PAD,*,*
# ライザーパッド	名詞,一般,*,*,*,*,ライザーパッド,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# SKATEBOARD	名詞,固有名詞,組織,*,*,*,SKATEBOARD,*,*
#  	記号,空白,*,*,*,*, ,*,*
# WAX	名詞,固有名詞,組織,*,*,*,WAX,*,*
# カーブ	名詞,サ変接続,*,*,*,*,カーブ,カーブ,カーブ
#  	記号,空白,*,*,*,*, ,*,*
# ワックス	名詞,一般,*,*,*,*,ワックス,ワックス,ワックス
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# SKATE	名詞,固有名詞,組織,*,*,*,SKATE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# TOOL	名詞,固有名詞,組織,*,*,*,TOOL,*,*
# スケート	名詞,一般,*,*,*,*,スケート,スケート,スケート
# ツール	名詞,固有名詞,地域,一般,*,*,ツール,ツール,ツール
#  	記号,空白,*,*,*,*, ,*,*
# 工具	名詞,一般,*,*,*,*,工具,コウグ,コーグ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# BOARD	名詞,固有名詞,組織,*,*,*,BOARD,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ACCESSORIES	名詞,固有名詞,組織,*,*,*,ACCESSORIES,*,*
# デッキ	名詞,一般,*,*,*,*,デッキ,デッキ,デッキ
#  	記号,空白,*,*,*,*, ,*,*
# アクセサリー	名詞,一般,*,*,*,*,アクセサリー,アクセサリー,アクセサリー
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# SPARE	名詞,固有名詞,組織,*,*,*,SPARE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# &	名詞,サ変接続,*,*,*,*,&,*,*
#  	記号,空白,*,*,*,*, ,*,*
# OTHER	名詞,固有名詞,組織,*,*,*,OTHER,*,*
# スペア	名詞,一般,*,*,*,*,スペア,スペア,スペア
#  	記号,空白,*,*,*,*, ,*,*
# その他	名詞,代名詞,一般,*,*,*,その他,ソノタ,ソノタ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# PROTECTOR	名詞,固有名詞,組織,*,*,*,PROTECTOR,*,*
# プロテクター	名詞,一般,*,*,*,*,プロテクター,プロテクター,プロテクター
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# HELMET	名詞,固有名詞,組織,*,*,*,HELMET,*,*
# ヘルメット	名詞,一般,*,*,*,*,ヘルメット,ヘルメット,ヘルメット
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# MEDIA	名詞,固有名詞,組織,*,*,*,MEDIA,*,*
#  	記号,空白,*,*,*,*, ,*,*
# &	名詞,サ変接続,*,*,*,*,&,*,*
#  	記号,空白,*,*,*,*, ,*,*
# DVD	名詞,固有名詞,組織,*,*,*,DVD,*,*
# 映像	名詞,一般,*,*,*,*,映像,エイゾウ,エイゾー
# /	名詞,サ変接続,*,*,*,*,/,*,*
# 雑誌	名詞,一般,*,*,*,*,雑誌,ザッシ,ザッシ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# OTHER	名詞,固有名詞,組織,*,*,*,OTHER,*,*
#  	記号,空白,*,*,*,*, ,*,*
# X	名詞,固有名詞,組織,*,*,*,X,*,*
# -	名詞,サ変接続,*,*,*,*,-,*,*
# TREAM	名詞,固有名詞,組織,*,*,*,TREAM,*,*
# その他	名詞,代名詞,一般,*,*,*,その他,ソノタ,ソノタ
# X	名詞,一般,*,*,*,*,X,*,*
# ポーツ	名詞,一般,*,*,*,*,ポーツ,*,*
# 用品	名詞,一般,*,*,*,*,用品,ヨウヒン,ヨーヒン
#
#
#
#
#
#
#
#
# 									記号,空白,*,*,*,*,
#
#
#
#
#
#
#
# 								,*,*
# SHOES	名詞,固有名詞,組織,*,*,*,SHOES,*,*
# シューズ	名詞,一般,*,*,*,*,シューズ,シューズ,シューズ
#
#
#
#
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
#
#
#
#
# 	 ,*,*
# SHOES	名詞,固有名詞,組織,*,*,*,SHOES,*,*
#  	記号,空白,*,*,*,*, ,*,*
# BRAND	名詞,固有名詞,組織,*,*,*,BRAND,*,*
# シューズ	名詞,一般,*,*,*,*,シューズ,シューズ,シューズ
#  	記号,空白,*,*,*,*, ,*,*
# ブランド	名詞,一般,*,*,*,*,ブランド,ブランド,ブランド
# 別	名詞,接尾,一般,*,*,*,別,ベツ,ベツ
# 一覧	名詞,サ変接続,*,*,*,*,一覧,イチラン,イチラン
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# WOMENS	名詞,固有名詞,組織,*,*,*,WOMENS,*,*
#  	記号,空白,*,*,*,*, ,*,*
# SHOES	名詞,固有名詞,組織,*,*,*,SHOES,*,*
# レディース	名詞,一般,*,*,*,*,レディース,レディース,レディース
#  	記号,空白,*,*,*,*, ,*,*
# シューズ	名詞,一般,*,*,*,*,シューズ,シューズ,シューズ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# KIDS	名詞,固有名詞,組織,*,*,*,KIDS,*,*
#  	記号,空白,*,*,*,*, ,*,*
# SHOES	名詞,固有名詞,組織,*,*,*,SHOES,*,*
# キッズシューズ	名詞,一般,*,*,*,*,キッズシューズ,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# SANDAL	名詞,固有名詞,組織,*,*,*,SANDAL,*,*
# サンダル	名詞,一般,*,*,*,*,サンダル,サンダル,サンダル
#  	記号,空白,*,*,*,*, ,*,*
# その他	名詞,代名詞,一般,*,*,*,その他,ソノタ,ソノタ
#
#
#
#
#
#
#
#
# 									記号,空白,*,*,*,*,
#
#
#
#
#
#
#
# 								,*,*
# APPAREL	名詞,一般,*,*,*,*,APPAREL,*,*
# 服	名詞,接尾,一般,*,*,*,服,フク,フク
# /	名詞,サ変接続,*,*,*,*,/,*,*
# ウェア	名詞,一般,*,*,*,*,ウェア,ウェア,ウェア
#
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
#
# ,*,*
# メンズ	名詞,一般,*,*,*,*,メンズ,メンズ,メンズ
#
#
# 	 	記号,空白,*,*,*,*,
#
# 	 ,*,*
# T	名詞,固有名詞,組織,*,*,*,T,*,*
# -	名詞,サ変接続,*,*,*,*,-,*,*
# SHIRTST	名詞,一般,*,*,*,*,SHIRTST,*,*
# シャツ	名詞,一般,*,*,*,*,シャツ,シャツ,シャツ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# L	名詞,固有名詞,組織,*,*,*,L,*,*
# /	名詞,サ変接続,*,*,*,*,/,*,*
# S	名詞,固有名詞,組織,*,*,*,S,*,*
#  	記号,空白,*,*,*,*, ,*,*
# TEE	名詞,固有名詞,組織,*,*,*,TEE,*,*
# ロング	名詞,一般,*,*,*,*,ロング,ロング,ロング
# Tシャツ	名詞,一般,*,*,*,*,Tシャツ,ティーシャツ,ティーシャツ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# POLO	名詞,固有名詞,組織,*,*,*,POLO,*,*
#  	記号,空白,*,*,*,*, ,*,*
# &	名詞,サ変接続,*,*,*,*,&,*,*
#  	記号,空白,*,*,*,*, ,*,*
# WOVEN	名詞,固有名詞,組織,*,*,*,WOVEN,*,*
# ポロシャツ	名詞,一般,*,*,*,*,ポロシャツ,ポロシャツ,ポロシャツ
#  	記号,空白,*,*,*,*, ,*,*
# その他	名詞,代名詞,一般,*,*,*,その他,ソノタ,ソノタ
# シャツ	名詞,一般,*,*,*,*,シャツ,シャツ,シャツ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# SWAET	名詞,固有名詞,組織,*,*,*,SWAET,*,*
#  	記号,空白,*,*,*,*, ,*,*
# &	名詞,サ変接続,*,*,*,*,&,*,*
#  	記号,空白,*,*,*,*, ,*,*
# PARKA	名詞,固有名詞,組織,*,*,*,PARKA,*,*
# パーカー	名詞,一般,*,*,*,*,パーカー,パーカー,パーカー
# /	名詞,サ変接続,*,*,*,*,/,*,*
# スウェット	名詞,一般,*,*,*,*,スウェット,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# OUTER	名詞,固有名詞,組織,*,*,*,OUTER,*,*
#  	記号,空白,*,*,*,*, ,*,*
# JACKET	名詞,固有名詞,組織,*,*,*,JACKET,*,*
# アウター	名詞,一般,*,*,*,*,アウター,*,*
# /	名詞,サ変接続,*,*,*,*,/,*,*
# ジャケット	名詞,一般,*,*,*,*,ジャケット,ジャケット,ジャケット
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# BOTTOMS	名詞,固有名詞,組織,*,*,*,BOTTOMS,*,*
# ボトム	名詞,一般,*,*,*,*,ボトム,ボトム,ボトム
# /	名詞,サ変接続,*,*,*,*,/,*,*
# パンツ	名詞,一般,*,*,*,*,パンツ,パンツ,パンツ
#
#
#
# 	記号,空白,*,*,*,*,
#
#
# ,*,*
# ヘッド	名詞,一般,*,*,*,*,ヘッド,ヘッド,ヘッド
# /	名詞,サ変接続,*,*,*,*,/,*,*
# ハードウェア	名詞,一般,*,*,*,*,ハードウェア,ハードウェア,ハードウェア
#
#
# 	 	記号,空白,*,*,*,*,
#
# 	 ,*,*
# CAP	名詞,固有名詞,組織,*,*,*,CAP,*,*
#  	記号,空白,*,*,*,*, ,*,*
# &	名詞,サ変接続,*,*,*,*,&,*,*
#  	記号,空白,*,*,*,*, ,*,*
# HATS	名詞,固有名詞,組織,*,*,*,HATS,*,*
# キャップ	名詞,一般,*,*,*,*,キャップ,キャップ,キャップ
# /	名詞,サ変接続,*,*,*,*,/,*,*
# 帽子	名詞,一般,*,*,*,*,帽子,ボウシ,ボーシ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# BEANIES	名詞,固有名詞,組織,*,*,*,BEANIES,*,*
# ニット	名詞,一般,*,*,*,*,ニット,ニット,ニット
# キャップ	名詞,一般,*,*,*,*,キャップ,キャップ,キャップ
# /	名詞,サ変接続,*,*,*,*,/,*,*
# ビーニー	名詞,一般,*,*,*,*,ビーニー,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# BAG	名詞,固有名詞,組織,*,*,*,BAG,*,*
#  	記号,空白,*,*,*,*, ,*,*
# &	名詞,サ変接続,*,*,*,*,&,*,*
#  	記号,空白,*,*,*,*, ,*,*
# BACKPACK	名詞,固有名詞,組織,*,*,*,BACKPACK,*,*
# バッグ	名詞,一般,*,*,*,*,バッグ,バッグ,バッグ
# /	名詞,サ変接続,*,*,*,*,/,*,*
# バック	名詞,サ変接続,*,*,*,*,バック,バック,バック
# パック	名詞,一般,*,*,*,*,パック,パック,パック
#
#
#
# 	記号,空白,*,*,*,*,
#
#
# ,*,*
# キッズ	名詞,一般,*,*,*,*,キッズ,*,*
# &	名詞,サ変接続,*,*,*,*,&,*,*
# レディース	名詞,一般,*,*,*,*,レディース,レディース,レディース
#
#
# 	 	記号,空白,*,*,*,*,
#
# 	 ,*,*
# KIDS	名詞,固有名詞,組織,*,*,*,KIDS,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ITEM	名詞,固有名詞,組織,*,*,*,ITEM,*,*
# キッズアイテム	名詞,一般,*,*,*,*,キッズアイテム,*,*
# 一覧	名詞,サ変接続,*,*,*,*,一覧,イチラン,イチラン
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# WOMENS	名詞,固有名詞,組織,*,*,*,WOMENS,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ITEM	名詞,固有名詞,組織,*,*,*,ITEM,*,*
# レディース	名詞,一般,*,*,*,*,レディース,レディース,レディース
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# 一覧	名詞,サ変接続,*,*,*,*,一覧,イチラン,イチラン
#
#
#
#
#
#
#
#
# 									記号,空白,*,*,*,*,
#
#
#
#
#
#
#
# 								,*,*
# ACCESSORY	名詞,固有名詞,組織,*,*,*,ACCESSORY,*,*
# 小物	名詞,一般,*,*,*,*,小物,コモノ,コモノ
# /	名詞,サ変接続,*,*,*,*,/,*,*
# グッズ	名詞,一般,*,*,*,*,グッズ,グッズ,グッズ
#
#
#
#
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
#
#
#
#
# 	 ,*,*
# STICKER	名詞,固有名詞,組織,*,*,*,STICKER,*,*
# ステッカー	名詞,一般,*,*,*,*,ステッカー,ステッカー,ステッカー
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# SUNGLASS	名詞,固有名詞,組織,*,*,*,SUNGLASS,*,*
# サングラス	名詞,一般,*,*,*,*,サングラス,サングラス,サングラス
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# KEYCHAIN	名詞,固有名詞,組織,*,*,*,KEYCHAIN,*,*
# キーホルダー	名詞,一般,*,*,*,*,キーホルダー,キーホルダー,キーホルダー
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# PATCHES	名詞,固有名詞,組織,*,*,*,PATCHES,*,*
# パッチ	名詞,一般,*,*,*,*,パッチ,パッチ,パッチ
# /	名詞,サ変接続,*,*,*,*,/,*,*
# ワッペン	名詞,一般,*,*,*,*,ワッペン,ワッペン,ワッペン
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# PINS	名詞,固有名詞,組織,*,*,*,PINS,*,*
# ピン	名詞,一般,*,*,*,*,ピン,ピン,ピン
# バッチ	名詞,一般,*,*,*,*,バッチ,バッチ,バッチ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# WATCH	名詞,固有名詞,組織,*,*,*,WATCH,*,*
# 時計	名詞,一般,*,*,*,*,時計,トケイ,トケイ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# WALET	名詞,固有名詞,組織,*,*,*,WALET,*,*
# 財布	名詞,一般,*,*,*,*,財布,サイフ,サイフ
# /	名詞,サ変接続,*,*,*,*,/,*,*
# ウォレット	名詞,一般,*,*,*,*,ウォレット,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# BELT	名詞,固有名詞,組織,*,*,*,BELT,*,*
# ベルト	名詞,一般,*,*,*,*,ベルト,ベルト,ベルト
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# ACCESSORIES	名詞,固有名詞,組織,*,*,*,ACCESSORIES,*,*
# アクセサリー	名詞,一般,*,*,*,*,アクセサリー,アクセサリー,アクセサリー
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# SOCKS	名詞,固有名詞,組織,*,*,*,SOCKS,*,*
# ソックス	名詞,一般,*,*,*,*,ソックス,ソックス,ソックス
# /	名詞,サ変接続,*,*,*,*,/,*,*
# 靴下	名詞,一般,*,*,*,*,靴下,クツシタ,クツシタ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# GLOVE	名詞,固有名詞,組織,*,*,*,GLOVE,*,*
# 手袋	名詞,一般,*,*,*,*,手袋,テブクロ,テブクロ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# WRISTBAND	名詞,固有名詞,組織,*,*,*,WRISTBAND,*,*
# リスト	名詞,一般,*,*,*,*,リスト,リスト,リスト
# バンド	名詞,一般,*,*,*,*,バンド,バンド,バンド
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# OTHER	名詞,固有名詞,組織,*,*,*,OTHER,*,*
#  	記号,空白,*,*,*,*, ,*,*
# GOODS	名詞,固有名詞,組織,*,*,*,GOODS,*,*
# その他	名詞,代名詞,一般,*,*,*,その他,ソノタ,ソノタ
# グッズ	名詞,一般,*,*,*,*,グッズ,グッズ,グッズ
#
#
#
#
#
#
#
#
# 									記号,空白,*,*,*,*,
#
#
#
#
#
#
#
# 								,*,*
# FINGERBOARD	名詞,固有名詞,組織,*,*,*,FINGERBOARD,*,*
# 指	名詞,一般,*,*,*,*,指,ユビ,ユビ
# スケ	名詞,一般,*,*,*,*,スケ,*,*
#
#
#
#
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
#
#
#
#
# 	 ,*,*
# ALL	名詞,固有名詞,組織,*,*,*,ALL,*,*
#  	記号,空白,*,*,*,*, ,*,*
# FINGER	名詞,固有名詞,組織,*,*,*,FINGER,*,*
#  	記号,空白,*,*,*,*, ,*,*
# BOARDS	名詞,固有名詞,組織,*,*,*,BOARDS,*,*
# 指	名詞,一般,*,*,*,*,指,ユビ,ユビ
# スケ	名詞,一般,*,*,*,*,スケ,*,*
# 全品	名詞,一般,*,*,*,*,全品,ゼンピン,ゼンピン
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# TECH	名詞,固有名詞,組織,*,*,*,TECH,*,*
#  	記号,空白,*,*,*,*, ,*,*
# DECK	名詞,固有名詞,組織,*,*,*,DECK,*,*
# テック	名詞,一般,*,*,*,*,テック,テック,テック
# デッキ	名詞,一般,*,*,*,*,デッキ,デッキ,デッキ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# CLOSE	名詞,固有名詞,組織,*,*,*,CLOSE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# UP	名詞,固有名詞,組織,*,*,*,UP,*,*
# クローズアップ	名詞,サ変接続,*,*,*,*,クローズアップ,クローズアップ,クローズアップ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# BLACK	名詞,固有名詞,組織,*,*,*,BLACK,*,*
#  	記号,空白,*,*,*,*, ,*,*
# RIVER	名詞,固有名詞,組織,*,*,*,RIVER,*,*
# ブラック	名詞,一般,*,*,*,*,ブラック,ブラック,ブラック
# リバー	名詞,一般,*,*,*,*,リバー,リバー,リバー
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# 4	名詞,数,*,*,*,*,4,*,*
# CORNER	名詞,一般,*,*,*,*,CORNER,*,*
# フォーコーナー	名詞,一般,*,*,*,*,フォーコーナー,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# CIRCUIT	名詞,固有名詞,組織,*,*,*,CIRCUIT,*,*
#  	記号,空白,*,*,*,*, ,*,*
# BOARD	名詞,固有名詞,組織,*,*,*,BOARD,*,*
# サーキット	名詞,一般,*,*,*,*,サーキット,サーキット,サーキット
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# FLICK	名詞,固有名詞,組織,*,*,*,FLICK,*,*
#  	記号,空白,*,*,*,*, ,*,*
# TRIX	名詞,固有名詞,組織,*,*,*,TRIX,*,*
# フィンガー	名詞,一般,*,*,*,*,フィンガー,フィンガー,フィンガー
# バイク	名詞,一般,*,*,*,*,バイク,バイク,バイク
#
#
#
#
#
#
#
#
#
# 									記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
# 								,*,*
# POPULAR	名詞,固有名詞,組織,*,*,*,POPULAR,*,*
# 人気	名詞,一般,*,*,*,*,人気,ニンキ,ニンキ
# カテ	名詞,一般,*,*,*,*,カテ,*,*
#
#
#
#
#
#
#
#
#  	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#  ,*,*
# ブランド	名詞,一般,*,*,*,*,ブランド,ブランド,ブランド
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 一覧	名詞,サ変接続,*,*,*,*,一覧,イチラン,イチラン
# )	名詞,サ変接続,*,*,*,*,),*,*
#
#
#
#
#
#  	記号,空白,*,*,*,*,
#
#
#
#
#  ,*,*
# 在庫	名詞,サ変接続,*,*,*,*,在庫,ザイコ,ザイコ
# 処分	名詞,サ変接続,*,*,*,*,処分,ショブン,ショブン
# セール	名詞,一般,*,*,*,*,セール,セール,セール
# 会場	名詞,一般,*,*,*,*,会場,カイジョウ,カイジョー
#
#
#
#
#
#  	記号,空白,*,*,*,*,
#
#
#
#
#  ,*,*
# 指	名詞,一般,*,*,*,*,指,ユビ,ユビ
# スケ	名詞,一般,*,*,*,*,スケ,*,*
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
#
#
#
#
#  	記号,空白,*,*,*,*,
#
#
#
#
#  ,*,*
# ワゴン	名詞,一般,*,*,*,*,ワゴン,ワゴン,ワゴン
# セール	名詞,一般,*,*,*,*,セール,セール,セール
#
#
#
#
#
#
#
#
#
# 									記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
# 								,*,*
# CONTENT	名詞,固有名詞,組織,*,*,*,CONTENT,*,*
# 読み物	名詞,一般,*,*,*,*,読み物,ヨミモノ,ヨミモノ
#
#
#
#
#
#
#
#
#  	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#  ,*,*
# メルマガ	名詞,一般,*,*,*,*,メルマガ,*,*
# 登録	名詞,サ変接続,*,*,*,*,登録,トウロク,トーロク
# ・	記号,一般,*,*,*,*,・,・,・
# 更新	名詞,サ変接続,*,*,*,*,更新,コウシン,コーシン
# ・	記号,一般,*,*,*,*,・,・,・
# 解除	名詞,サ変接続,*,*,*,*,解除,カイジョ,カイジョ
#
#
#
#
#
#  	記号,空白,*,*,*,*,
#
#
#
#
#  ,*,*
# 指	名詞,一般,*,*,*,*,指,ユビ,ユビ
# スケ	名詞,一般,*,*,*,*,スケ,*,*
# って	助詞,格助詞,連語,*,*,*,って,ッテ,ッテ
# 何	名詞,代名詞,一般,*,*,*,何,ナニ,ナニ
# ？	記号,一般,*,*,*,*,？,？,？
#
#
#
#
#
#  	記号,空白,*,*,*,*,
#
#
#
#
#  ,*,*
# よく	副詞,一般,*,*,*,*,よく,ヨク,ヨク
# ある	動詞,自立,*,*,五段・ラ行,基本形,ある,アル,アル
# ご	接頭詞,名詞接続,*,*,*,*,ご,ゴ,ゴ
# 質問	名詞,サ変接続,*,*,*,*,質問,シツモン,シツモン
#
#
#
#
#
#  	記号,空白,*,*,*,*,
#
#
#
#
#  ,*,*
# ウェア	名詞,一般,*,*,*,*,ウェア,ウェア,ウェア
# ハウス	名詞,一般,*,*,*,*,ハウス,ハウス,ハウス
# 即売	名詞,サ変接続,*,*,*,*,即売,ソクバイ,ソクバイ
# 会	名詞,接尾,一般,*,*,*,会,カイ,カイ
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 予約	名詞,サ変接続,*,*,*,*,予約,ヨヤク,ヨヤク
# 制	名詞,接尾,一般,*,*,*,制,セイ,セイ
# )	名詞,サ変接続,*,*,*,*,),*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# お知らせ	名詞,サ変接続,*,*,*,*,お知らせ,オシラセ,オシラセ
#
#
#
#
#
#  	記号,空白,*,*,*,*,
#
#
#
#
#  ,*,*
# スケート	名詞,一般,*,*,*,*,スケート,スケート,スケート
# ボード	名詞,一般,*,*,*,*,ボード,ボード,ボード
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 購入	名詞,サ変接続,*,*,*,*,購入,コウニュウ,コーニュー
# 方法	名詞,一般,*,*,*,*,方法,ホウホウ,ホーホー
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    ,*,*
# ご	接頭詞,名詞接続,*,*,*,*,ご,ゴ,ゴ
# 利用	名詞,サ変接続,*,*,*,*,利用,リヨウ,リヨー
# ガイド	名詞,サ変接続,*,*,*,*,ガイド,ガイド,ガイド
#
#
#
#
#     	記号,空白,*,*,*,*,
#
#
#
#     ,*,*
# お	接頭詞,名詞接続,*,*,*,*,お,オ,オ
# 問い合わせ	名詞,サ変接続,*,*,*,*,問い合わせ,トイアワセ,トイアワセ
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#    ,*,*
# ショップブログ	名詞,一般,*,*,*,*,ショップブログ,*,*
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   ,*,*
# MENU	名詞,固有名詞,組織,*,*,*,MENU,*,*
#
#
#
#
#   	記号,空白,*,*,*,*,
#
#
#
#   ,*,*
# SEARCH	名詞,固有名詞,組織,*,*,*,SEARCH,*,*
#
#
#
#
#
#
#   	記号,空白,*,*,*,*,
#
#
#
#
#
#   ,*,*
# CART	名詞,固有名詞,組織,*,*,*,CART,*,*
#
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#    ,*,*
# メニュー	名詞,一般,*,*,*,*,メニュー,メニュー,メニュー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 閉じる	動詞,自立,*,*,一段,基本形,閉じる,トジル,トジル
#
#
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
#    ,*,*
# HOME	名詞,固有名詞,組織,*,*,*,HOME,*,*
#
#
#
#
#
#   	記号,空白,*,*,*,*,
#
#
#
#
#   ,*,*
# USER	名詞,固有名詞,組織,*,*,*,USER,*,*
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#    ,*,*
# 会員	名詞,一般,*,*,*,*,会員,カイイン,カイイン
# 登録	名詞,サ変接続,*,*,*,*,登録,トウロク,トーロク
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#    ,*,*
# ログイン	名詞,一般,*,*,*,*,ログイン,ログイン,ログイン
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#    ,*,*
# アカウント	名詞,一般,*,*,*,*,アカウント,アカウント,アカウント
#
#
#
#
#   	記号,空白,*,*,*,*,
#
#
#
#   ,*,*
# CATEGORY	名詞,固有名詞,組織,*,*,*,CATEGORY,*,*
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#    ,*,*
# SKATEBOARD	名詞,固有名詞,組織,*,*,*,SKATEBOARD,*,*
# スケート	名詞,一般,*,*,*,*,スケート,スケート,スケート
# ボード	名詞,一般,*,*,*,*,ボード,ボード,ボード
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 探す	動詞,自立,*,*,五段・サ行,基本形,探す,サガス,サガス
#
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#    ,*,*
# -	名詞,サ変接続,*,*,*,*,-,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 完成	名詞,サ変接続,*,*,*,*,完成,カンセイ,カンセイ
# 済み	名詞,接尾,一般,*,*,*,済み,ズミ,ズミ
# スケボー	名詞,一般,*,*,*,*,スケボー,*,*
#
#
# 	 	記号,空白,*,*,*,*,
#
# 	 ,*,*
# COMPETE	名詞,固有名詞,組織,*,*,*,COMPETE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# SKATEBOARD	名詞,固有名詞,組織,*,*,*,SKATEBOARD,*,*
# 組み立て	名詞,一般,*,*,*,*,組み立て,クミタテ,クミタテ
# 済み	名詞,接尾,一般,*,*,*,済み,ズミ,ズミ
# トリック	名詞,一般,*,*,*,*,トリック,トリック,トリック
# 用	名詞,接尾,一般,*,*,*,用,ヨウ,ヨー
# ボード	名詞,一般,*,*,*,*,ボード,ボード,ボード
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# KIDS	名詞,固有名詞,組織,*,*,*,KIDS,*,*
#  	記号,空白,*,*,*,*, ,*,*
# COMPLETE	名詞,固有名詞,組織,*,*,*,COMPLETE,*,*
# 組み立て	名詞,一般,*,*,*,*,組み立て,クミタテ,クミタテ
# 済み	名詞,接尾,一般,*,*,*,済み,ズミ,ズミ
# キッズサイズボード	名詞,一般,*,*,*,*,キッズサイズボード,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# CRUISER	名詞,固有名詞,組織,*,*,*,CRUISER,*,*
# &	名詞,サ変接続,*,*,*,*,&,*,*
# LONGBOARD	名詞,一般,*,*,*,*,LONGBOARD,*,*
# 組み立て	名詞,一般,*,*,*,*,組み立て,クミタテ,クミタテ
# 済み	名詞,接尾,一般,*,*,*,済み,ズミ,ズミ
# ロング	名詞,一般,*,*,*,*,ロング,ロング,ロング
# /	名詞,サ変接続,*,*,*,*,/,*,*
# クルーザー	名詞,一般,*,*,*,*,クルーザー,クルーザー,クルーザー
#
#
#    	記号,空白,*,*,*,*,
#
#    ,*,*
# -	名詞,サ変接続,*,*,*,*,-,*,*
#  	記号,空白,*,*,*,*, ,*,*
# デッキ	名詞,一般,*,*,*,*,デッキ,デッキ,デッキ
# 単品	名詞,一般,*,*,*,*,単品,タンピン,タンピン
#
#
# 	 	記号,空白,*,*,*,*,
#
# 	 ,*,*
# DECK	名詞,固有名詞,組織,*,*,*,DECK,*,*
# デッキ	名詞,一般,*,*,*,*,デッキ,デッキ,デッキ
#  	記号,空白,*,*,*,*, ,*,*
# ブランド	名詞,一般,*,*,*,*,ブランド,ブランド,ブランド
# 別	名詞,接尾,一般,*,*,*,別,ベツ,ベツ
# 一覧	名詞,サ変接続,*,*,*,*,一覧,イチラン,イチラン
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# BLANK	名詞,固有名詞,組織,*,*,*,BLANK,*,*
# 格安	名詞,一般,*,*,*,*,格安,カクヤス,カクヤス
# 無地	名詞,一般,*,*,*,*,無地,ムジ,ムジ
# デッキ	名詞,一般,*,*,*,*,デッキ,デッキ,デッキ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# KIDS	名詞,固有名詞,組織,*,*,*,KIDS,*,*
#  	記号,空白,*,*,*,*, ,*,*
# DECK	名詞,固有名詞,組織,*,*,*,DECK,*,*
# キッズサイズ	名詞,一般,*,*,*,*,キッズサイズ,*,*
#  	記号,空白,*,*,*,*, ,*,*
# デッキ	名詞,一般,*,*,*,*,デッキ,デッキ,デッキ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# OLDSCHOOL	名詞,固有名詞,組織,*,*,*,OLDSCHOOL,*,*
# オールドスクールシェイプ	名詞,一般,*,*,*,*,オールドスクールシェイプ,*,*
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#    ,*,*
# SKATE	名詞,固有名詞,組織,*,*,*,SKATE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# PARTS	名詞,固有名詞,組織,*,*,*,PARTS,*,*
# スケボーパーツ	名詞,一般,*,*,*,*,スケボーパーツ,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 探す	動詞,自立,*,*,五段・サ行,基本形,探す,サガス,サガス
#
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#    ,*,*
# -	名詞,サ変接続,*,*,*,*,-,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 主要	名詞,形容動詞語幹,*,*,*,*,主要,シュヨウ,シュヨー
# パーツ	名詞,一般,*,*,*,*,パーツ,パーツ,パーツ
#
#
# 	 	記号,空白,*,*,*,*,
#
# 	 ,*,*
# TRUCK	名詞,固有名詞,組織,*,*,*,TRUCK,*,*
# トラック	名詞,一般,*,*,*,*,トラック,トラック,トラック
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# WHEELS	名詞,固有名詞,組織,*,*,*,WHEELS,*,*
# トリック	名詞,一般,*,*,*,*,トリック,トリック,トリック
# 用	名詞,接尾,一般,*,*,*,用,ヨウ,ヨー
# ウィール	名詞,一般,*,*,*,*,ウィール,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# CRUISER	名詞,固有名詞,組織,*,*,*,CRUISER,*,*
#  	記号,空白,*,*,*,*, ,*,*
# WHEELS	名詞,固有名詞,組織,*,*,*,WHEELS,*,*
# クルーザーウィール	名詞,一般,*,*,*,*,クルーザーウィール,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# BEARINGS	名詞,固有名詞,組織,*,*,*,BEARINGS,*,*
# ベアリング	名詞,一般,*,*,*,*,ベアリング,ベアリング,ベアリング
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# HARDWHEAR	名詞,固有名詞,組織,*,*,*,HARDWHEAR,*,*
# ハードウェア	名詞,一般,*,*,*,*,ハードウェア,ハードウェア,ハードウェア
# (	名詞,サ変接続,*,*,*,*,(,*,*
# ボルト	名詞,一般,*,*,*,*,ボルト,ボルト,ボルト
# )	名詞,サ変接続,*,*,*,*,),*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# GRIP	名詞,固有名詞,組織,*,*,*,GRIP,*,*
#  	記号,空白,*,*,*,*, ,*,*
# TAPE	名詞,固有名詞,組織,*,*,*,TAPE,*,*
# デッキ	名詞,一般,*,*,*,*,デッキ,デッキ,デッキ
# テープ	名詞,一般,*,*,*,*,テープ,テープ,テープ
#
#
#    	記号,空白,*,*,*,*,
#
#    ,*,*
# -	名詞,サ変接続,*,*,*,*,-,*,*
#  	記号,空白,*,*,*,*, ,*,*
# アクセサリ	名詞,一般,*,*,*,*,アクセサリ,アクセサリ,アクセサリ
# /	名詞,サ変接続,*,*,*,*,/,*,*
# ギア	名詞,一般,*,*,*,*,ギア,ギア,ギア
#
#
# 	 	記号,空白,*,*,*,*,
#
# 	 ,*,*
# BUSHINGS	名詞,固有名詞,組織,*,*,*,BUSHINGS,*,*
# ブッシュ	名詞,固有名詞,人名,姓,*,*,ブッシュ,ブッシュ,ブッシュ
# /	名詞,サ変接続,*,*,*,*,/,*,*
# クッシュゴム	名詞,一般,*,*,*,*,クッシュゴム,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# RISER	名詞,固有名詞,組織,*,*,*,RISER,*,*
#  	記号,空白,*,*,*,*, ,*,*
# PA	名詞,固有名詞,組織,*,*,*,PA,*,*
# D	名詞,固有名詞,組織,*,*,*,D,*,*
# ライザーパッド	名詞,一般,*,*,*,*,ライザーパッド,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# SKATEBOARD	名詞,固有名詞,組織,*,*,*,SKATEBOARD,*,*
#  	記号,空白,*,*,*,*, ,*,*
# WAX	名詞,固有名詞,組織,*,*,*,WAX,*,*
# カーブ	名詞,サ変接続,*,*,*,*,カーブ,カーブ,カーブ
#  	記号,空白,*,*,*,*, ,*,*
# ワックス	名詞,一般,*,*,*,*,ワックス,ワックス,ワックス
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# SKATE	名詞,固有名詞,組織,*,*,*,SKATE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# TOOL	名詞,固有名詞,組織,*,*,*,TOOL,*,*
# スケート	名詞,一般,*,*,*,*,スケート,スケート,スケート
# ツール	名詞,固有名詞,地域,一般,*,*,ツール,ツール,ツール
#  	記号,空白,*,*,*,*, ,*,*
# 工具	名詞,一般,*,*,*,*,工具,コウグ,コーグ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# BOARD	名詞,固有名詞,組織,*,*,*,BOARD,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ACCESSORIES	名詞,固有名詞,組織,*,*,*,ACCESSORIES,*,*
# デッキ	名詞,一般,*,*,*,*,デッキ,デッキ,デッキ
#  	記号,空白,*,*,*,*, ,*,*
# アクセサリー	名詞,一般,*,*,*,*,アクセサリー,アクセサリー,アクセサリー
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# SPARE	名詞,固有名詞,組織,*,*,*,SPARE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# &	名詞,サ変接続,*,*,*,*,&,*,*
#  	記号,空白,*,*,*,*, ,*,*
# OTHER	名詞,固有名詞,組織,*,*,*,OTHER,*,*
# スペア	名詞,一般,*,*,*,*,スペア,スペア,スペア
#  	記号,空白,*,*,*,*, ,*,*
# その他	名詞,代名詞,一般,*,*,*,その他,ソノタ,ソノタ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# PROTECTOR	名詞,固有名詞,組織,*,*,*,PROTECTOR,*,*
# プロテクター	名詞,一般,*,*,*,*,プロテクター,プロテクター,プロテクター
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# HELMET	名詞,固有名詞,組織,*,*,*,HELMET,*,*
# ヘルメット	名詞,一般,*,*,*,*,ヘルメット,ヘルメット,ヘルメット
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# MEDIA	名詞,固有名詞,組織,*,*,*,MEDIA,*,*
#  	記号,空白,*,*,*,*, ,*,*
# &	名詞,サ変接続,*,*,*,*,&,*,*
#  	記号,空白,*,*,*,*, ,*,*
# DVD	名詞,固有名詞,組織,*,*,*,DVD,*,*
# 映像	名詞,一般,*,*,*,*,映像,エイゾウ,エイゾー
# /	名詞,サ変接続,*,*,*,*,/,*,*
# 雑誌	名詞,一般,*,*,*,*,雑誌,ザッシ,ザッシ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# OTHER	名詞,固有名詞,組織,*,*,*,OTHER,*,*
#  	記号,空白,*,*,*,*, ,*,*
# X	名詞,固有名詞,組織,*,*,*,X,*,*
# -	名詞,サ変接続,*,*,*,*,-,*,*
# TREAM	名詞,固有名詞,組織,*,*,*,TREAM,*,*
# その他	名詞,代名詞,一般,*,*,*,その他,ソノタ,ソノタ
# X	名詞,一般,*,*,*,*,X,*,*
# ポーツ	名詞,一般,*,*,*,*,ポーツ,*,*
# 用品	名詞,一般,*,*,*,*,用品,ヨウヒン,ヨーヒン
#
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#    ,*,*
# SHOES	名詞,固有名詞,組織,*,*,*,SHOES,*,*
# シューズ	名詞,一般,*,*,*,*,シューズ,シューズ,シューズ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 探す	動詞,自立,*,*,五段・サ行,基本形,探す,サガス,サガス
#
#
#
#
#
#
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
# 	 ,*,*
# SHOES	名詞,固有名詞,組織,*,*,*,SHOES,*,*
#  	記号,空白,*,*,*,*, ,*,*
# BRAND	名詞,固有名詞,組織,*,*,*,BRAND,*,*
# シューズ	名詞,一般,*,*,*,*,シューズ,シューズ,シューズ
#  	記号,空白,*,*,*,*, ,*,*
# ブランド	名詞,一般,*,*,*,*,ブランド,ブランド,ブランド
# 別	名詞,接尾,一般,*,*,*,別,ベツ,ベツ
# 一覧	名詞,サ変接続,*,*,*,*,一覧,イチラン,イチラン
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# WOMENS	名詞,固有名詞,組織,*,*,*,WOMENS,*,*
#  	記号,空白,*,*,*,*, ,*,*
# SHOES	名詞,固有名詞,組織,*,*,*,SHOES,*,*
# レディース	名詞,一般,*,*,*,*,レディース,レディース,レディース
#  	記号,空白,*,*,*,*, ,*,*
# シューズ	名詞,一般,*,*,*,*,シューズ,シューズ,シューズ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# KIDS	名詞,固有名詞,組織,*,*,*,KIDS,*,*
#  	記号,空白,*,*,*,*, ,*,*
# SHOES	名詞,固有名詞,組織,*,*,*,SHOES,*,*
# キッズシューズ	名詞,一般,*,*,*,*,キッズシューズ,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# SANDAL	名詞,固有名詞,組織,*,*,*,SANDAL,*,*
# サンダル	名詞,一般,*,*,*,*,サンダル,サンダル,サンダル
#  	記号,空白,*,*,*,*, ,*,*
# その他	名詞,代名詞,一般,*,*,*,その他,ソノタ,ソノタ
#
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#    ,*,*
# APPAREL	名詞,一般,*,*,*,*,APPAREL,*,*
# 服	名詞,接尾,一般,*,*,*,服,フク,フク
# /	名詞,サ変接続,*,*,*,*,/,*,*
# ウェア	名詞,一般,*,*,*,*,ウェア,ウェア,ウェア
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 探す	動詞,自立,*,*,五段・サ行,基本形,探す,サガス,サガス
#
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#    ,*,*
# -	名詞,サ変接続,*,*,*,*,-,*,*
#  	記号,空白,*,*,*,*, ,*,*
# メンズ	名詞,一般,*,*,*,*,メンズ,メンズ,メンズ
#
#
# 	 	記号,空白,*,*,*,*,
#
# 	 ,*,*
# T	名詞,固有名詞,組織,*,*,*,T,*,*
# -	名詞,サ変接続,*,*,*,*,-,*,*
# SHIRTST	名詞,一般,*,*,*,*,SHIRTST,*,*
# シャツ	名詞,一般,*,*,*,*,シャツ,シャツ,シャツ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# L	名詞,固有名詞,組織,*,*,*,L,*,*
# /	名詞,サ変接続,*,*,*,*,/,*,*
# S	名詞,固有名詞,組織,*,*,*,S,*,*
#  	記号,空白,*,*,*,*, ,*,*
# TEE	名詞,固有名詞,組織,*,*,*,TEE,*,*
# ロング	名詞,一般,*,*,*,*,ロング,ロング,ロング
# Tシャツ	名詞,一般,*,*,*,*,Tシャツ,ティーシャツ,ティーシャツ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# POLO	名詞,固有名詞,組織,*,*,*,POLO,*,*
#  	記号,空白,*,*,*,*, ,*,*
# &	名詞,サ変接続,*,*,*,*,&,*,*
#  	記号,空白,*,*,*,*, ,*,*
# WOVEN	名詞,固有名詞,組織,*,*,*,WOVEN,*,*
# ポロシャツ	名詞,一般,*,*,*,*,ポロシャツ,ポロシャツ,ポロシャツ
#  	記号,空白,*,*,*,*, ,*,*
# その他	名詞,代名詞,一般,*,*,*,その他,ソノタ,ソノタ
# シャツ	名詞,一般,*,*,*,*,シャツ,シャツ,シャツ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# SWAET	名詞,固有名詞,組織,*,*,*,SWAET,*,*
#  	記号,空白,*,*,*,*, ,*,*
# &	名詞,サ変接続,*,*,*,*,&,*,*
#  	記号,空白,*,*,*,*, ,*,*
# PARKA	名詞,固有名詞,組織,*,*,*,PARKA,*,*
# パーカー	名詞,一般,*,*,*,*,パーカー,パーカー,パーカー
# /	名詞,サ変接続,*,*,*,*,/,*,*
# スウェット	名詞,一般,*,*,*,*,スウェット,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# OUTER	名詞,固有名詞,組織,*,*,*,OUTER,*,*
#  	記号,空白,*,*,*,*, ,*,*
# JACKET	名詞,固有名詞,組織,*,*,*,JACKET,*,*
# アウター	名詞,一般,*,*,*,*,アウター,*,*
# /	名詞,サ変接続,*,*,*,*,/,*,*
# ジャケット	名詞,一般,*,*,*,*,ジャケット,ジャケット,ジャケット
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# BOTTOMS	名詞,固有名詞,組織,*,*,*,BOTTOMS,*,*
# ボトム	名詞,一般,*,*,*,*,ボトム,ボトム,ボトム
# /	名詞,サ変接続,*,*,*,*,/,*,*
# パンツ	名詞,一般,*,*,*,*,パンツ,パンツ,パンツ
#
#    	記号,空白,*,*,*,*,
#    ,*,*
# -	名詞,サ変接続,*,*,*,*,-,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ヘッド	名詞,一般,*,*,*,*,ヘッド,ヘッド,ヘッド
# /	名詞,サ変接続,*,*,*,*,/,*,*
# ハードウェア	名詞,一般,*,*,*,*,ハードウェア,ハードウェア,ハードウェア
#
#
# 	 	記号,空白,*,*,*,*,
#
# 	 ,*,*
# CAP	名詞,固有名詞,組織,*,*,*,CAP,*,*
#  	記号,空白,*,*,*,*, ,*,*
# &	名詞,サ変接続,*,*,*,*,&,*,*
#  	記号,空白,*,*,*,*, ,*,*
# HATS	名詞,固有名詞,組織,*,*,*,HATS,*,*
# キャップ	名詞,一般,*,*,*,*,キャップ,キャップ,キャップ
# /	名詞,サ変接続,*,*,*,*,/,*,*
# 帽子	名詞,一般,*,*,*,*,帽子,ボウシ,ボーシ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# BEANIES	名詞,固有名詞,組織,*,*,*,BEANIES,*,*
# ニット	名詞,一般,*,*,*,*,ニット,ニット,ニット
# キャップ	名詞,一般,*,*,*,*,キャップ,キャップ,キャップ
# /	名詞,サ変接続,*,*,*,*,/,*,*
# ビーニー	名詞,一般,*,*,*,*,ビーニー,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# BAG	名詞,固有名詞,組織,*,*,*,BAG,*,*
#  	記号,空白,*,*,*,*, ,*,*
# &	名詞,サ変接続,*,*,*,*,&,*,*
#  	記号,空白,*,*,*,*, ,*,*
# BACKPACK	名詞,固有名詞,組織,*,*,*,BACKPACK,*,*
# バッグ	名詞,一般,*,*,*,*,バッグ,バッグ,バッグ
# /	名詞,サ変接続,*,*,*,*,/,*,*
# バック	名詞,サ変接続,*,*,*,*,バック,バック,バック
# パック	名詞,一般,*,*,*,*,パック,パック,パック
#
#
#    	記号,空白,*,*,*,*,
#
#    ,*,*
# -	名詞,サ変接続,*,*,*,*,-,*,*
#  	記号,空白,*,*,*,*, ,*,*
# キッズ	名詞,一般,*,*,*,*,キッズ,*,*
# &	名詞,サ変接続,*,*,*,*,&,*,*
# レディース	名詞,一般,*,*,*,*,レディース,レディース,レディース
#
#
# 	 	記号,空白,*,*,*,*,
#
# 	 ,*,*
# KIDS	名詞,固有名詞,組織,*,*,*,KIDS,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ITEM	名詞,固有名詞,組織,*,*,*,ITEM,*,*
# キッズアイテム	名詞,一般,*,*,*,*,キッズアイテム,*,*
# 一覧	名詞,サ変接続,*,*,*,*,一覧,イチラン,イチラン
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# WOMENS	名詞,固有名詞,組織,*,*,*,WOMENS,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ITEM	名詞,固有名詞,組織,*,*,*,ITEM,*,*
# レディース	名詞,一般,*,*,*,*,レディース,レディース,レディース
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# 一覧	名詞,サ変接続,*,*,*,*,一覧,イチラン,イチラン
#
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#    ,*,*
# ACCESSORY	名詞,固有名詞,組織,*,*,*,ACCESSORY,*,*
# 小物	名詞,一般,*,*,*,*,小物,コモノ,コモノ
# /	名詞,サ変接続,*,*,*,*,/,*,*
# グッズ	名詞,一般,*,*,*,*,グッズ,グッズ,グッズ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 探す	動詞,自立,*,*,五段・サ行,基本形,探す,サガス,サガス
#
#
#
#
#
#
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
# 	 ,*,*
# STICKER	名詞,固有名詞,組織,*,*,*,STICKER,*,*
# ステッカー	名詞,一般,*,*,*,*,ステッカー,ステッカー,ステッカー
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# SUNGLASS	名詞,固有名詞,組織,*,*,*,SUNGLASS,*,*
# サングラス	名詞,一般,*,*,*,*,サングラス,サングラス,サングラス
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# KEYCHAIN	名詞,固有名詞,組織,*,*,*,KEYCHAIN,*,*
# キーホルダー	名詞,一般,*,*,*,*,キーホルダー,キーホルダー,キーホルダー
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# PATCHES	名詞,固有名詞,組織,*,*,*,PATCHES,*,*
# パッチ	名詞,一般,*,*,*,*,パッチ,パッチ,パッチ
# /	名詞,サ変接続,*,*,*,*,/,*,*
# ワッペン	名詞,一般,*,*,*,*,ワッペン,ワッペン,ワッペン
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# PINS	名詞,固有名詞,組織,*,*,*,PINS,*,*
# ピン	名詞,一般,*,*,*,*,ピン,ピン,ピン
# バッチ	名詞,一般,*,*,*,*,バッチ,バッチ,バッチ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# WATCH	名詞,固有名詞,組織,*,*,*,WATCH,*,*
# 時計	名詞,一般,*,*,*,*,時計,トケイ,トケイ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# WALET	名詞,固有名詞,組織,*,*,*,WALET,*,*
# 財布	名詞,一般,*,*,*,*,財布,サイフ,サイフ
# /	名詞,サ変接続,*,*,*,*,/,*,*
# ウォレット	名詞,一般,*,*,*,*,ウォレット,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# BELT	名詞,固有名詞,組織,*,*,*,BELT,*,*
# ベルト	名詞,一般,*,*,*,*,ベルト,ベルト,ベルト
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# ACCESSORIES	名詞,固有名詞,組織,*,*,*,ACCESSORIES,*,*
# アクセサリー	名詞,一般,*,*,*,*,アクセサリー,アクセサリー,アクセサリー
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# SOCKS	名詞,固有名詞,組織,*,*,*,SOCKS,*,*
# ソックス	名詞,一般,*,*,*,*,ソックス,ソックス,ソックス
# /	名詞,サ変接続,*,*,*,*,/,*,*
# 靴下	名詞,一般,*,*,*,*,靴下,クツシタ,クツシタ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# GLOVE	名詞,固有名詞,組織,*,*,*,GLOVE,*,*
# 手袋	名詞,一般,*,*,*,*,手袋,テブクロ,テブクロ
#
# 		記号,空白,*,*,*,*,
# 	,*,*
#
#
# 	 	記号,空白,*,*,*,*,
#
# 	 ,*,*
# WRISTBAND	名詞,固有名詞,組織,*,*,*,WRISTBAND,*,*
# リスト	名詞,一般,*,*,*,*,リスト,リスト,リスト
# バンド	名詞,一般,*,*,*,*,バンド,バンド,バンド
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# OTHER	名詞,固有名詞,組織,*,*,*,OTHER,*,*
#  	記号,空白,*,*,*,*, ,*,*
# GOODS	名詞,固有名詞,組織,*,*,*,GOODS,*,*
# その他	名詞,代名詞,一般,*,*,*,その他,ソノタ,ソノタ
# グッズ	名詞,一般,*,*,*,*,グッズ,グッズ,グッズ
#
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#    ,*,*
# FINGERBOARD	名詞,固有名詞,組織,*,*,*,FINGERBOARD,*,*
# 指	名詞,一般,*,*,*,*,指,ユビ,ユビ
# スケ	名詞,一般,*,*,*,*,スケ,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 探す	動詞,自立,*,*,五段・サ行,基本形,探す,サガス,サガス
#
#
#
#
#
#
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
# 	 ,*,*
# ALL	名詞,固有名詞,組織,*,*,*,ALL,*,*
#  	記号,空白,*,*,*,*, ,*,*
# FINGER	名詞,固有名詞,組織,*,*,*,FINGER,*,*
#  	記号,空白,*,*,*,*, ,*,*
# BOARDS	名詞,固有名詞,組織,*,*,*,BOARDS,*,*
# 指	名詞,一般,*,*,*,*,指,ユビ,ユビ
# スケ	名詞,一般,*,*,*,*,スケ,*,*
# 全品	名詞,一般,*,*,*,*,全品,ゼンピン,ゼンピン
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# TECH	名詞,固有名詞,組織,*,*,*,TECH,*,*
#  	記号,空白,*,*,*,*, ,*,*
# DECK	名詞,固有名詞,組織,*,*,*,DECK,*,*
# テック	名詞,一般,*,*,*,*,テック,テック,テック
# デッキ	名詞,一般,*,*,*,*,デッキ,デッキ,デッキ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# CLOSE	名詞,固有名詞,組織,*,*,*,CLOSE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# UP	名詞,固有名詞,組織,*,*,*,UP,*,*
# クローズアップ	名詞,サ変接続,*,*,*,*,クローズアップ,クローズアップ,クローズアップ
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# BLACK	名詞,固有名詞,組織,*,*,*,BLACK,*,*
#  	記号,空白,*,*,*,*, ,*,*
# RIVER	名詞,固有名詞,組織,*,*,*,RIVER,*,*
# ブラック	名詞,一般,*,*,*,*,ブラック,ブラック,ブラック
# リバー	名詞,一般,*,*,*,*,リバー,リバー,リバー
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# 4	名詞,数,*,*,*,*,4,*,*
# CORNER	名詞,一般,*,*,*,*,CORNER,*,*
# フォーコーナー	名詞,一般,*,*,*,*,フォーコーナー,*,*
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# CIRCUIT	名詞,固有名詞,組織,*,*,*,CIRCUIT,*,*
#  	記号,空白,*,*,*,*, ,*,*
# BOARD	名詞,固有名詞,組織,*,*,*,BOARD,*,*
# サーキット	名詞,一般,*,*,*,*,サーキット,サーキット,サーキット
#
#
#
# 	 	記号,空白,*,*,*,*,
#
#
# 	 ,*,*
# FLICK	名詞,固有名詞,組織,*,*,*,FLICK,*,*
#  	記号,空白,*,*,*,*, ,*,*
# TRIX	名詞,固有名詞,組織,*,*,*,TRIX,*,*
# フィンガー	名詞,一般,*,*,*,*,フィンガー,フィンガー,フィンガー
# バイク	名詞,一般,*,*,*,*,バイク,バイク,バイク
#
#
#
#
#
#
#   	記号,空白,*,*,*,*,
#
#
#
#
#
#   ,*,*
# POPULAR	名詞,固有名詞,組織,*,*,*,POPULAR,*,*
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#    ,*,*
# ブランド	名詞,一般,*,*,*,*,ブランド,ブランド,ブランド
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 一覧	名詞,サ変接続,*,*,*,*,一覧,イチラン,イチラン
# )	名詞,サ変接続,*,*,*,*,),*,*
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#    ,*,*
# 在庫	名詞,サ変接続,*,*,*,*,在庫,ザイコ,ザイコ
# 処分	名詞,サ変接続,*,*,*,*,処分,ショブン,ショブン
# セール	名詞,一般,*,*,*,*,セール,セール,セール
# 会場	名詞,一般,*,*,*,*,会場,カイジョウ,カイジョー
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#    ,*,*
# 指	名詞,一般,*,*,*,*,指,ユビ,ユビ
# スケ	名詞,一般,*,*,*,*,スケ,*,*
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#    ,*,*
# ワゴン	名詞,一般,*,*,*,*,ワゴン,ワゴン,ワゴン
# セール	名詞,一般,*,*,*,*,セール,セール,セール
#
#
#
#
#   	記号,空白,*,*,*,*,
#
#
#
#   ,*,*
# コンテンツ	名詞,一般,*,*,*,*,コンテンツ,コンテンツ,コンテンツ
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#    ,*,*
# メルマガ	名詞,一般,*,*,*,*,メルマガ,*,*
# 登録	名詞,サ変接続,*,*,*,*,登録,トウロク,トーロク
# ・	記号,一般,*,*,*,*,・,・,・
# 更新	名詞,サ変接続,*,*,*,*,更新,コウシン,コーシン
# ・	記号,一般,*,*,*,*,・,・,・
# 解除	名詞,サ変接続,*,*,*,*,解除,カイジョ,カイジョ
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#    ,*,*
# 指	名詞,一般,*,*,*,*,指,ユビ,ユビ
# スケ	名詞,一般,*,*,*,*,スケ,*,*
# って	助詞,格助詞,連語,*,*,*,って,ッテ,ッテ
# 何	名詞,代名詞,一般,*,*,*,何,ナニ,ナニ
# ？	記号,一般,*,*,*,*,？,？,？
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#    ,*,*
# よく	副詞,一般,*,*,*,*,よく,ヨク,ヨク
# ある	動詞,自立,*,*,五段・ラ行,基本形,ある,アル,アル
# ご	接頭詞,名詞接続,*,*,*,*,ご,ゴ,ゴ
# 質問	名詞,サ変接続,*,*,*,*,質問,シツモン,シツモン
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#    ,*,*
# ウェア	名詞,一般,*,*,*,*,ウェア,ウェア,ウェア
# ハウス	名詞,一般,*,*,*,*,ハウス,ハウス,ハウス
# 即売	名詞,サ変接続,*,*,*,*,即売,ソクバイ,ソクバイ
# 会	名詞,接尾,一般,*,*,*,会,カイ,カイ
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 予約	名詞,サ変接続,*,*,*,*,予約,ヨヤク,ヨヤク
# 制	名詞,接尾,一般,*,*,*,制,セイ,セイ
# )	名詞,サ変接続,*,*,*,*,),*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# お知らせ	名詞,サ変接続,*,*,*,*,お知らせ,オシラセ,オシラセ
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#    ,*,*
# スケート	名詞,一般,*,*,*,*,スケート,スケート,スケート
# ボード	名詞,一般,*,*,*,*,ボード,ボード,ボード
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 購入	名詞,サ変接続,*,*,*,*,購入,コウニュウ,コーニュー
# 方法	名詞,一般,*,*,*,*,方法,ホウホウ,ホーホー
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#    ,*,*
# ご	接頭詞,名詞接続,*,*,*,*,ご,ゴ,ゴ
# 利用	名詞,サ変接続,*,*,*,*,利用,リヨウ,リヨー
# ガイド	名詞,サ変接続,*,*,*,*,ガイド,ガイド,ガイド
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#    ,*,*
# お	接頭詞,名詞接続,*,*,*,*,お,オ,オ
# 問い合わせ	名詞,サ変接続,*,*,*,*,問い合わせ,トイアワセ,トイアワセ
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#    ,*,*
# ショップブログ	名詞,一般,*,*,*,*,ショップブログ,*,*
#
#
#
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
#
#    ,*,*
# ホーム	名詞,一般,*,*,*,*,ホーム,ホーム,ホーム
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#    ,*,*
# スニーカー	名詞,一般,*,*,*,*,スニーカー,スニーカー,スニーカー
# (	名詞,サ変接続,*,*,*,*,(,*,*
# SHOES	名詞,一般,*,*,*,*,SHOES,*,*
# )	名詞,サ変接続,*,*,*,*,),*,*
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#    ,*,*
# LAKAI	名詞,固有名詞,組織,*,*,*,LAKAI,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ラカイ	名詞,一般,*,*,*,*,ラカイ,*,*
# (	名詞,サ変接続,*,*,*,*,(,*,*
# シューズ	名詞,一般,*,*,*,*,シューズ,シューズ,シューズ
# )	名詞,サ変接続,*,*,*,*,),*,*
#
#
#
#
#
#
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
#
# ,*,*
# 5	名詞,数,*,*,*,*,5,*,*
# BORO	名詞,固有名詞,組織,*,*,*,BORO,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ファイブボロ	名詞,一般,*,*,*,*,ファイブボロ,*,*
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ADIDAS	名詞,固有名詞,組織,*,*,*,ADIDAS,*,*
#  	記号,空白,*,*,*,*, ,*,*
# SKATEBOARDING	名詞,固有名詞,組織,*,*,*,SKATEBOARDING,*,*
#  	記号,空白,*,*,*,*, ,*,*
# アディダス	名詞,一般,*,*,*,*,アディダス,*,*
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ALIEN	名詞,固有名詞,組織,*,*,*,ALIEN,*,*
#  	記号,空白,*,*,*,*, ,*,*
# WORKSHOP	名詞,固有名詞,組織,*,*,*,WORKSHOP,*,*
#  	記号,空白,*,*,*,*, ,*,*
# エイリアン	名詞,一般,*,*,*,*,エイリアン,エイリアン,エイリアン
# ワークショップ	名詞,一般,*,*,*,*,ワークショップ,ワークショップ,ワークショップ
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ACE	名詞,固有名詞,組織,*,*,*,ACE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# TRUCKS	名詞,固有名詞,組織,*,*,*,TRUCKS,*,*
#  	記号,空白,*,*,*,*, ,*,*
# エース	名詞,一般,*,*,*,*,エース,エース,エース
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ANTIHERO	名詞,固有名詞,組織,*,*,*,ANTIHERO,*,*
#  	記号,空白,*,*,*,*, ,*,*
# アン	名詞,固有名詞,人名,名,*,*,アン,アン,アン
# タイ	名詞,固有名詞,地域,国,*,*,タイ,タイ,タイ
# ヒーロー	名詞,一般,*,*,*,*,ヒーロー,ヒーロー,ヒーロー
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ANDALE	名詞,固有名詞,組織,*,*,*,ANDALE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# BEARINGS	名詞,固有名詞,組織,*,*,*,BEARINGS,*,*
#  	記号,空白,*,*,*,*, ,*,*
# アンダレー	名詞,一般,*,*,*,*,アンダレー,*,*
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ALMOST	名詞,固有名詞,組織,*,*,*,ALMOST,*,*
#  	記号,空白,*,*,*,*, ,*,*
# オルモスト	名詞,一般,*,*,*,*,オルモスト,*,*
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ALTAMONT	名詞,固有名詞,組織,*,*,*,ALTAMONT,*,*
#  	記号,空白,*,*,*,*, ,*,*
# オルタモント	名詞,一般,*,*,*,*,オルタモント,*,*
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# BAKER	名詞,固有名詞,組織,*,*,*,BAKER,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ベーカー	名詞,固有名詞,人名,一般,*,*,ベーカー,ベーカー,ベーカー
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# BIRD	名詞,固有名詞,組織,*,*,*,BIRD,*,*
#  	記号,空白,*,*,*,*, ,*,*
# HOUSE	名詞,固有名詞,組織,*,*,*,HOUSE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# バード	名詞,固有名詞,人名,名,*,*,バード,バード,バード
# ハウス	名詞,一般,*,*,*,*,ハウス,ハウス,ハウス
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# BLACK	名詞,固有名詞,組織,*,*,*,BLACK,*,*
#  	記号,空白,*,*,*,*, ,*,*
# LABEL	名詞,固有名詞,組織,*,*,*,LABEL,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ブラック	名詞,一般,*,*,*,*,ブラック,ブラック,ブラック
# レーベル	名詞,一般,*,*,*,*,レーベル,レーベル,レーベル
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# BLIND	名詞,固有名詞,組織,*,*,*,BLIND,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ブラインド	名詞,一般,*,*,*,*,ブラインド,ブラインド,ブラインド
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# BONES	名詞,固有名詞,組織,*,*,*,BONES,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ボーンズ	名詞,一般,*,*,*,*,ボーンズ,*,*
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# BRIXTON	名詞,固有名詞,組織,*,*,*,BRIXTON,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ブリクス	名詞,固有名詞,人名,姓,*,*,ブリクス,ブリクス,ブリクス
# トン	名詞,固有名詞,人名,名,*,*,トン,トン,トン
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# BRONSON	名詞,固有名詞,組織,*,*,*,BRONSON,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ブロンソン	名詞,一般,*,*,*,*,ブロンソン,*,*
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# BRO	名詞,固有名詞,組織,*,*,*,BRO,*,*
#  	記号,空白,*,*,*,*, ,*,*
# STYLE	名詞,固有名詞,組織,*,*,*,STYLE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ブロス	名詞,固有名詞,人名,姓,*,*,ブロス,ブロス,ブロス
# タイル	名詞,一般,*,*,*,*,タイル,タイル,タイル
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# CHOCOLATE	名詞,固有名詞,組織,*,*,*,CHOCOLATE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# チョコレート	名詞,一般,*,*,*,*,チョコレート,チョコレート,チョコレート
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# CITY	名詞,固有名詞,組織,*,*,*,CITY,*,*
#  	記号,空白,*,*,*,*, ,*,*
# SKATEBOARDS	名詞,固有名詞,組織,*,*,*,SKATEBOARDS,*,*
#  	記号,空白,*,*,*,*, ,*,*
# シティ	名詞,一般,*,*,*,*,シティ,シティ,シティ
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# CLICHE	名詞,固有名詞,組織,*,*,*,CLICHE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# クリシェ	名詞,一般,*,*,*,*,クリシェ,*,*
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# CONVERSE	名詞,固有名詞,組織,*,*,*,CONVERSE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# CONS	名詞,固有名詞,組織,*,*,*,CONS,*,*
#  	記号,空白,*,*,*,*, ,*,*
# コンズ	名詞,一般,*,*,*,*,コンズ,*,*
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# CONSOLIDATED	名詞,固有名詞,組織,*,*,*,CONSOLIDATED,*,*
#  	記号,空白,*,*,*,*, ,*,*
# コンソリデーテッド	名詞,一般,*,*,*,*,コンソリデーテッド,*,*
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# CREATURE	名詞,固有名詞,組織,*,*,*,CREATURE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# クリーチャー	名詞,一般,*,*,*,*,クリーチャー,*,*
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# アイテム	名詞,一般,*,*,*,*,アイテム,アイテム,アイテム
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# DARKSTAR	名詞,固有名詞,組織,*,*,*,DARKSTAR,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ダーク	名詞,一般,*,*,*,*,ダーク,ダーク,ダーク
# スター	名詞,一般,*,*,*,*,スター,スター,スター
# ...
# ;	名詞,サ変接続,*,*,*,*,;,*,*
# 11	名詞,数,*,*,*,*,11,*,*
# ,	名詞,サ変接続,*,*,*,*,,,*,*
# 880	名詞,数,*,*,*,*,880,*,*
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#    ,*,*
# LAKAI	名詞,固有名詞,組織,*,*,*,LAKAI,*,*
# 史上	名詞,一般,*,*,*,*,史上,シジョウ,シジョー
# 最高	名詞,一般,*,*,*,*,最高,サイコウ,サイコー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 衝撃	名詞,一般,*,*,*,*,衝撃,ショウゲキ,ショーゲキ
# 吸収	名詞,サ変接続,*,*,*,*,吸収,キュウシュウ,キューシュー
# 力	名詞,接尾,一般,*,*,*,力,リョク,リョク
# ！	記号,一般,*,*,*,*,！,！,！
# ライリー・ホークシグネチャーモデル	名詞,一般,*,*,*,*,ライリー・ホークシグネチャーモデル,*,*
# 第	接頭詞,数接続,*,*,*,*,第,ダイ,ダイ
# 二	名詞,数,*,*,*,*,二,ニ,ニ
# 弾	名詞,接尾,助数詞,*,*,*,弾,ダン,ダン
# ！	記号,一般,*,*,*,*,！,！,！
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    ,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# LAKAI	名詞,固有名詞,組織,*,*,*,LAKAI,*,*
#  	記号,空白,*,*,*,*, ,*,*
# LIMITED	名詞,固有名詞,組織,*,*,*,LIMITED,*,*
#  	記号,空白,*,*,*,*, ,*,*
# FOOTWEAR	名詞,固有名詞,組織,*,*,*,FOOTWEAR,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ラカイ	名詞,一般,*,*,*,*,ラカイ,*,*
#  	記号,空白,*,*,*,*, ,*,*
# スケート	名詞,一般,*,*,*,*,スケート,スケート,スケート
#  	記号,空白,*,*,*,*, ,*,*
# シューズ	名詞,一般,*,*,*,*,シューズ,シューズ,シューズ
# 】	記号,括弧閉,*,*,*,*,】,】,】
# GRIFFIN	名詞,固有名詞,組織,*,*,*,GRIFFIN,*,*
#  	記号,空白,*,*,*,*, ,*,*
# SHOES	名詞,固有名詞,組織,*,*,*,SHOES,*,*
#  	記号,空白,*,*,*,*, ,*,*
# XLK	名詞,固有名詞,組織,*,*,*,XLK,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# ブラック	名詞,一般,*,*,*,*,ブラック,ブラック,ブラック
# x	名詞,一般,*,*,*,*,x,*,*
# クリスタル	名詞,一般,*,*,*,*,クリスタル,クリスタル,クリスタル
# 】	記号,括弧閉,*,*,*,*,】,】,】
# NO	名詞,一般,*,*,*,*,NO,*,*
# 78	名詞,数,*,*,*,*,78,*,*
#
#
#
#  	記号,空白,*,*,*,*,
#
#
#  ,*,*
# 11	名詞,数,*,*,*,*,11,*,*
# ,	名詞,サ変接続,*,*,*,*,,,*,*
# 178	名詞,数,*,*,*,*,178,*,*
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
#
#
#
#   		記号,空白,*,*,*,*,
#
#
#   	,*,*
# 定価	名詞,一般,*,*,*,*,定価,テイカ,テイカ
# &	名詞,サ変接続,*,*,*,*,&,*,*
# nbsp	名詞,一般,*,*,*,*,nbsp,*,*
# ;	名詞,サ変接続,*,*,*,*,;,*,*
# 12	名詞,数,*,*,*,*,12,*,*
# ,	名詞,サ変接続,*,*,*,*,,,*,*
# 420	名詞,数,*,*,*,*,420,*,*
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#    ,*,*
# 定番	名詞,一般,*,*,*,*,定番,テイバン,テイバン
# モデル	名詞,一般,*,*,*,*,モデル,モデル,モデル
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# クリスタルソール	名詞,一般,*,*,*,*,クリスタルソール,*,*
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# XLK	名詞,一般,*,*,*,*,XLK,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 搭載	名詞,サ変接続,*,*,*,*,搭載,トウサイ,トーサイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# ハイエンド	名詞,一般,*,*,*,*,ハイエンド,ハイエンド,ハイエンド
# モデル	名詞,一般,*,*,*,*,モデル,モデル,モデル
# ！	記号,一般,*,*,*,*,！,！,！
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    ,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# LAKAI	名詞,固有名詞,組織,*,*,*,LAKAI,*,*
#  	記号,空白,*,*,*,*, ,*,*
# LIMITED	名詞,固有名詞,組織,*,*,*,LIMITED,*,*
#  	記号,空白,*,*,*,*, ,*,*
# FOOTWEAR	名詞,固有名詞,組織,*,*,*,FOOTWEAR,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ラカイ	名詞,一般,*,*,*,*,ラカイ,*,*
#  	記号,空白,*,*,*,*, ,*,*
# スケート	名詞,一般,*,*,*,*,スケート,スケート,スケート
#  	記号,空白,*,*,*,*, ,*,*
# シューズ	名詞,一般,*,*,*,*,シューズ,シューズ,シューズ
# 】	記号,括弧閉,*,*,*,*,】,】,】
# FREMONTE	名詞,固有名詞,組織,*,*,*,FREMONTE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# SHOES	名詞,固有名詞,組織,*,*,*,SHOES,*,*
#  	記号,空白,*,*,*,*, ,*,*
# XLK	名詞,固有名詞,組織,*,*,*,XLK,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# ブラック	名詞,一般,*,*,*,*,ブラック,ブラック,ブラック
# x	名詞,一般,*,*,*,*,x,*,*
# ホワイト	名詞,一般,*,*,*,*,ホワイト,ホワイト,ホワイト
# 】	記号,括弧閉,*,*,*,*,】,】,】
# NO	名詞,一般,*,*,*,*,NO,*,*
# 77	名詞,数,*,*,*,*,77,*,*
#
#
#
#  	記号,空白,*,*,*,*,
#
#
#  ,*,*
# 11	名詞,数,*,*,*,*,11,*,*
# ,	名詞,サ変接続,*,*,*,*,,,*,*
# 178	名詞,数,*,*,*,*,178,*,*
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
#
#
#
#   		記号,空白,*,*,*,*,
#
#
#   	,*,*
# 定価	名詞,一般,*,*,*,*,定価,テイカ,テイカ
# &	名詞,サ変接続,*,*,*,*,&,*,*
# nbsp	名詞,一般,*,*,*,*,nbsp,*,*
# ;	名詞,サ変接続,*,*,*,*,;,*,*
# 12	名詞,数,*,*,*,*,12,*,*
# ,	名詞,サ変接続,*,*,*,*,,,*,*
# 420	名詞,数,*,*,*,*,420,*,*
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#    ,*,*
# 脱げ	動詞,自立,*,*,一段,連用形,脱げる,ヌゲ,ヌゲ
# にくい	形容詞,非自立,*,*,形容詞・アウオ段,基本形,にくい,ニクイ,ニクイ
# 一体	名詞,一般,*,*,*,*,一体,イッタイ,イッタイ
# 型	名詞,接尾,一般,*,*,*,型,ガタ,ガタ
# ソックス	名詞,一般,*,*,*,*,ソックス,ソックス,ソックス
# アッパー	名詞,一般,*,*,*,*,アッパー,アッパー,アッパー
# 仕様	名詞,一般,*,*,*,*,仕様,シヨウ,シヨー
# ！	記号,一般,*,*,*,*,！,！,！
# XLK	名詞,一般,*,*,*,*,XLK,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 搭載	名詞,サ変接続,*,*,*,*,搭載,トウサイ,トーサイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 最上級	名詞,一般,*,*,*,*,最上級,サイジョウキュウ,サイジョーキュー
# モデル	名詞,一般,*,*,*,*,モデル,モデル,モデル
# ！	記号,一般,*,*,*,*,！,！,！
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    ,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# LAKAI	名詞,固有名詞,組織,*,*,*,LAKAI,*,*
#  	記号,空白,*,*,*,*, ,*,*
# LIMITED	名詞,固有名詞,組織,*,*,*,LIMITED,*,*
#  	記号,空白,*,*,*,*, ,*,*
# FOOTWEAR	名詞,固有名詞,組織,*,*,*,FOOTWEAR,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ラカイ	名詞,一般,*,*,*,*,ラカイ,*,*
#  	記号,空白,*,*,*,*, ,*,*
# スケート	名詞,一般,*,*,*,*,スケート,スケート,スケート
#  	記号,空白,*,*,*,*, ,*,*
# シューズ	名詞,一般,*,*,*,*,シューズ,シューズ,シューズ
# 】	記号,括弧閉,*,*,*,*,】,】,】
# OWEN	名詞,固有名詞,組織,*,*,*,OWEN,*,*
#  	記号,空白,*,*,*,*, ,*,*
# VLK	名詞,固有名詞,組織,*,*,*,VLK,*,*
#  	記号,空白,*,*,*,*, ,*,*
# SHOES	名詞,固有名詞,組織,*,*,*,SHOES,*,*
#  	記号,空白,*,*,*,*, ,*,*
# NICO	名詞,固有名詞,組織,*,*,*,NICO,*,*
#  	記号,空白,*,*,*,*, ,*,*
# HIRAGA	名詞,固有名詞,組織,*,*,*,HIRAGA,*,*
#  	記号,空白,*,*,*,*, ,*,*
# NO	名詞,一般,*,*,*,*,NO,*,*
# 76	名詞,数,*,*,*,*,76,*,*
#
#
#
#  	記号,空白,*,*,*,*,
#
#
#  ,*,*
# 8	名詞,数,*,*,*,*,8,*,*
# ,	名詞,サ変接続,*,*,*,*,,,*,*
# 640	名詞,数,*,*,*,*,640,*,*
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
#
#
#
#   		記号,空白,*,*,*,*,
#
#
#   	,*,*
# 定価	名詞,一般,*,*,*,*,定価,テイカ,テイカ
# &	名詞,サ変接続,*,*,*,*,&,*,*
# nbsp	名詞,一般,*,*,*,*,nbsp,*,*
# ;	名詞,サ変接続,*,*,*,*,;,*,*
# 10	名詞,数,*,*,*,*,10,*,*
# ,	名詞,サ変接続,*,*,*,*,,,*,*
# 800	名詞,数,*,*,*,*,800,*,*
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#    ,*,*
# 軽快	名詞,形容動詞語幹,*,*,*,*,軽快,ケイカイ,ケイカイ
# さ	名詞,接尾,特殊,*,*,*,さ,サ,サ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 履き	動詞,自立,*,*,五段・カ行イ音便,連用形,履く,ハキ,ハキ
# 心地	名詞,接尾,一般,*,*,*,心地,ゴコチ,ゴコチ
# 抜群	名詞,一般,*,*,*,*,抜群,バツグン,バツグン
# ！	記号,一般,*,*,*,*,！,！,！
# スリッポンシリーズ	名詞,一般,*,*,*,*,スリッポンシリーズ,*,*
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# NICO	名詞,固有名詞,組織,*,*,*,NICO,*,*
# プロ	名詞,一般,*,*,*,*,プロ,プロ,プロ
# モデル	名詞,一般,*,*,*,*,モデル,モデル,モデル
# ！	記号,一般,*,*,*,*,！,！,！
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    ,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# LAKAI	名詞,固有名詞,組織,*,*,*,LAKAI,*,*
#  	記号,空白,*,*,*,*, ,*,*
# LIMITED	名詞,固有名詞,組織,*,*,*,LIMITED,*,*
#  	記号,空白,*,*,*,*, ,*,*
# FOOTWEAR	名詞,固有名詞,組織,*,*,*,FOOTWEAR,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ラカイ	名詞,一般,*,*,*,*,ラカイ,*,*
#  	記号,空白,*,*,*,*, ,*,*
# スケート	名詞,一般,*,*,*,*,スケート,スケート,スケート
#  	記号,空白,*,*,*,*, ,*,*
# シューズ	名詞,一般,*,*,*,*,シューズ,シューズ,シューズ
# 】	記号,括弧閉,*,*,*,*,】,】,】
# STAPLE	名詞,固有名詞,組織,*,*,*,STAPLE,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# ブラック	名詞,一般,*,*,*,*,ブラック,ブラック,ブラック
# 】	記号,括弧閉,*,*,*,*,】,】,】
# NO	名詞,一般,*,*,*,*,NO,*,*
# 75	名詞,数,*,*,*,*,75,*,*
#
#
#
#  	記号,空白,*,*,*,*,
#
#
#  ,*,*
# 8	名詞,数,*,*,*,*,8,*,*
# ,	名詞,サ変接続,*,*,*,*,,,*,*
# 694	名詞,数,*,*,*,*,694,*,*
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
#
#
#
#   		記号,空白,*,*,*,*,
#
#
#   	,*,*
# 定価	名詞,一般,*,*,*,*,定価,テイカ,テイカ
# &	名詞,サ変接続,*,*,*,*,&,*,*
# nbsp	名詞,一般,*,*,*,*,nbsp,*,*
# ;	名詞,サ変接続,*,*,*,*,;,*,*
# 12	名詞,数,*,*,*,*,12,*,*
# ,	名詞,サ変接続,*,*,*,*,,,*,*
# 420	名詞,数,*,*,*,*,420,*,*
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#    ,*,*
# 2001	名詞,数,*,*,*,*,2001,*,*
# 年	名詞,接尾,助数詞,*,*,*,年,ネン,ネン
# 発売	名詞,サ変接続,*,*,*,*,発売,ハツバイ,ハツバイ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 名作	名詞,一般,*,*,*,*,名作,メイサク,メイサク
# シューズ	名詞,一般,*,*,*,*,シューズ,シューズ,シューズ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 新	接頭詞,名詞接続,*,*,*,*,新,シン,シン
# 技術	名詞,一般,*,*,*,*,技術,ギジュツ,ギジュツ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 復刻	名詞,サ変接続,*,*,*,*,復刻,フッコク,フッコク
# ！	記号,一般,*,*,*,*,！,！,！
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    ,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# LAKAI	名詞,固有名詞,組織,*,*,*,LAKAI,*,*
#  	記号,空白,*,*,*,*, ,*,*
# LIMITED	名詞,固有名詞,組織,*,*,*,LIMITED,*,*
#  	記号,空白,*,*,*,*, ,*,*
# FOOTWEAR	名詞,固有名詞,組織,*,*,*,FOOTWEAR,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ラカイ	名詞,一般,*,*,*,*,ラカイ,*,*
#  	記号,空白,*,*,*,*, ,*,*
# スケート	名詞,一般,*,*,*,*,スケート,スケート,スケート
#  	記号,空白,*,*,*,*, ,*,*
# シューズ	名詞,一般,*,*,*,*,シューズ,シューズ,シューズ
# 】	記号,括弧閉,*,*,*,*,】,】,】
# GRIFFIN	名詞,固有名詞,組織,*,*,*,GRIFFIN,*,*
#  	記号,空白,*,*,*,*, ,*,*
# XLK	名詞,固有名詞,組織,*,*,*,XLK,*,*
#  	記号,空白,*,*,*,*, ,*,*
# SHOES	名詞,固有名詞,組織,*,*,*,SHOES,*,*
#  	記号,空白,*,*,*,*, ,*,*
# スウェード	名詞,一般,*,*,*,*,スウェード,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# ネイビー	名詞,固有名詞,一般,*,*,*,ネイビー,*,*
# 】	記号,括弧閉,*,*,*,*,】,】,】
# NO	名詞,一般,*,*,*,*,NO,*,*
# 73	名詞,数,*,*,*,*,73,*,*
#
#
#
#  	記号,空白,*,*,*,*,
#
#
#  ,*,*
# 8	名詞,数,*,*,*,*,8,*,*
# ,	名詞,サ変接続,*,*,*,*,,,*,*
# 206	名詞,数,*,*,*,*,206,*,*
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
#
#
#
#   		記号,空白,*,*,*,*,
#
#
#   	,*,*
# 定価	名詞,一般,*,*,*,*,定価,テイカ,テイカ
# &	名詞,サ変接続,*,*,*,*,&,*,*
# nbsp	名詞,一般,*,*,*,*,nbsp,*,*
# ;	名詞,サ変接続,*,*,*,*,;,*,*
# 12	名詞,数,*,*,*,*,12,*,*
# ,	名詞,サ変接続,*,*,*,*,,,*,*
# 744	名詞,数,*,*,*,*,744,*,*
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#    ,*,*
# XLK	名詞,固有名詞,組織,*,*,*,XLK,*,*
# ソール	名詞,一般,*,*,*,*,ソール,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 装備	名詞,サ変接続,*,*,*,*,装備,ソウビ,ソービ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# ハイエンド	名詞,一般,*,*,*,*,ハイエンド,ハイエンド,ハイエンド
# モデル	名詞,一般,*,*,*,*,モデル,モデル,モデル
# ！	記号,一般,*,*,*,*,！,！,！
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    ,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# ラカイ	名詞,一般,*,*,*,*,ラカイ,*,*
#  	記号,空白,*,*,*,*, ,*,*
# LAKAI	名詞,固有名詞,組織,*,*,*,LAKAI,*,*
#  	記号,空白,*,*,*,*, ,*,*
# スケート	名詞,一般,*,*,*,*,スケート,スケート,スケート
#  	記号,空白,*,*,*,*, ,*,*
# シューズ	名詞,一般,*,*,*,*,シューズ,シューズ,シューズ
# 】	記号,括弧閉,*,*,*,*,】,】,】
# CAMBY	名詞,固有名詞,組織,*,*,*,CAMBY,*,*
#  	記号,空白,*,*,*,*, ,*,*
# DUCK	名詞,固有名詞,組織,*,*,*,DUCK,*,*
#  	記号,空白,*,*,*,*, ,*,*
# SHOES	名詞,固有名詞,組織,*,*,*,SHOES,*,*
#  	記号,空白,*,*,*,*, ,*,*
# キャンバス	名詞,一般,*,*,*,*,キャンバス,キャンバス,キャンバス
# 【	記号,括弧開,*,*,*,*,【,【,【
# グリーン	名詞,一般,*,*,*,*,グリーン,グリーン,グリーン
# 】	記号,括弧閉,*,*,*,*,】,】,】
# NO	名詞,一般,*,*,*,*,NO,*,*
# 68	名詞,数,*,*,*,*,68,*,*
#
#
#
#  	記号,空白,*,*,*,*,
#
#
#  ,*,*
# 5	名詞,数,*,*,*,*,5,*,*
# ,	名詞,サ変接続,*,*,*,*,,,*,*
# 428	名詞,数,*,*,*,*,428,*,*
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
#
#
#
#   		記号,空白,*,*,*,*,
#
#
#   	,*,*
# 定価	名詞,一般,*,*,*,*,定価,テイカ,テイカ
# &	名詞,サ変接続,*,*,*,*,&,*,*
# nbsp	名詞,一般,*,*,*,*,nbsp,*,*
# ;	名詞,サ変接続,*,*,*,*,;,*,*
# 10	名詞,数,*,*,*,*,10,*,*
# ,	名詞,サ変接続,*,*,*,*,,,*,*
# 800	名詞,数,*,*,*,*,800,*,*
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#    ,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# オススメ	名詞,固有名詞,一般,*,*,*,オススメ,*,*
# 】	記号,括弧閉,*,*,*,*,】,】,】
# LAKAI	名詞,固有名詞,組織,*,*,*,LAKAI,*,*
# シューズ	名詞,一般,*,*,*,*,シューズ,シューズ,シューズ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
#  	記号,空白,*,*,*,*, ,*,*
# CAMBY	名詞,固有名詞,組織,*,*,*,CAMBY,*,*
#  	記号,空白,*,*,*,*, ,*,*
# モデル	名詞,一般,*,*,*,*,モデル,モデル,モデル
# 新	接頭詞,名詞接続,*,*,*,*,新,シン,シン
# 入荷	名詞,サ変接続,*,*,*,*,入荷,ニュウカ,ニューカ
# ！	記号,一般,*,*,*,*,！,！,！
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    ,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# ラカイ	名詞,一般,*,*,*,*,ラカイ,*,*
#  	記号,空白,*,*,*,*, ,*,*
# LAKAI	名詞,固有名詞,組織,*,*,*,LAKAI,*,*
#  	記号,空白,*,*,*,*, ,*,*
# スケート	名詞,一般,*,*,*,*,スケート,スケート,スケート
#  	記号,空白,*,*,*,*, ,*,*
# シューズ	名詞,一般,*,*,*,*,シューズ,シューズ,シューズ
# 】	記号,括弧閉,*,*,*,*,】,】,】
# MJ	名詞,固有名詞,組織,*,*,*,MJ,*,*
#  	記号,空白,*,*,*,*, ,*,*
# DUCK	名詞,固有名詞,組織,*,*,*,DUCK,*,*
#  	記号,空白,*,*,*,*, ,*,*
# SHOES	名詞,固有名詞,組織,*,*,*,SHOES,*,*
#  	記号,空白,*,*,*,*, ,*,*
# スウェード	名詞,一般,*,*,*,*,スウェード,*,*
#  	記号,空白,*,*,*,*, ,*,*
# x	名詞,固有名詞,組織,*,*,*,x,*,*
#  	記号,空白,*,*,*,*, ,*,*
# キャンバス	名詞,一般,*,*,*,*,キャンバス,キャンバス,キャンバス
# 【	記号,括弧開,*,*,*,*,【,【,【
# ネイビー	名詞,固有名詞,一般,*,*,*,ネイビー,*,*
# 】	記号,括弧閉,*,*,*,*,】,】,】
# NO	名詞,一般,*,*,*,*,NO,*,*
# 67	名詞,数,*,*,*,*,67,*,*
#
#
#
#  	記号,空白,*,*,*,*,
#
#
#  ,*,*
# 5	名詞,数,*,*,*,*,5,*,*
# ,	名詞,サ変接続,*,*,*,*,,,*,*
# 428	名詞,数,*,*,*,*,428,*,*
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
#
#
#
#   		記号,空白,*,*,*,*,
#
#
#   	,*,*
# 定価	名詞,一般,*,*,*,*,定価,テイカ,テイカ
# &	名詞,サ変接続,*,*,*,*,&,*,*
# nbsp	名詞,一般,*,*,*,*,nbsp,*,*
# ;	名詞,サ変接続,*,*,*,*,;,*,*
# 11	名詞,数,*,*,*,*,11,*,*
# ,	名詞,サ変接続,*,*,*,*,,,*,*
# 800	名詞,数,*,*,*,*,800,*,*
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
#
#
#
#    	記号,空白,*,*,*,*,
#
#
#    ,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# 半額	名詞,一般,*,*,*,*,半額,ハンガク,ハンガク
# セール	名詞,一般,*,*,*,*,セール,セール,セール
# 】	記号,括弧閉,*,*,*,*,】,】,】
# LAKAI	名詞,固有名詞,組織,*,*,*,LAKAI,*,*
# シューズ	名詞,一般,*,*,*,*,シューズ,シューズ,シューズ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
#  	記号,空白,*,*,*,*, ,*,*
# MJ	名詞,固有名詞,組織,*,*,*,MJ,*,*
#  	記号,空白,*,*,*,*, ,*,*
# モデル	名詞,一般,*,*,*,*,モデル,モデル,モデル
# 新	接頭詞,名詞接続,*,*,*,*,新,シン,シン
# 入荷	名詞,サ変接続,*,*,*,*,入荷,ニュウカ,ニューカ
# ！	記号,一般,*,*,*,*,！,！,！
#
#
# ['LAKAI ラカイ(シューズ) - 南国スケボーショップ砂辺：スケートボード、デッキの通販に最適！\n\n\n\t\t\t\t\t\t\t\tSKATEBOARDスケートボード\n    \n    \n    \n    \n完成済みスケートボード\n\t\n\t COMPETE SKATEBOARD組み立て済みトリック用ボード\n\t\n\t\n\t KIDS COMPLETE組み立て済みキッズサイズボード\n\t\n\t\n\t CRUISER&LONGBOARD組み立て済みロング/クルーザー\n\t\n\nデッキ単品\n\t\n\t DECKデッキ ブランド別一覧\n\t\n\t\n\t BLANK格安無地デッキ\n\t\n\t\n\t KIDS DECKキッズサイズ デッキ\n\t\n\t\n\t OLDSCHOOLオールドスクールシェイプ\n\t\n\n    \n    \n   \n   \n    \n\t\t\t\t\t\t\t\tSKATE PARTSスケボーパーツ\n    \n    \n    \n    \n主要パーツ\n\t\n\t TRUCKトラック\n\t\n\t\n\t WHEELSトリック用ウィール\n\t\n\t\n\t CRUISER WHEELSクルーザーウィール\n\t\n\t\n\t BEARINGSベアリング\n\t\n\t\n\t HARDWHEARハードウェア(ボルト)\n\t\n\t\n\t GRIP TAPEデッキテープ\n\t\n\nアクセサリ/ギア\n\t\n\t BUSHINGSブッシュ/クッシュゴム\n\t\n\t\n\t RISER PADライザーパッド\n\t\n\t\n\t SKATEBOARD WAXカーブ ワックス\n\t\n\t\n\t SKATE TOOLスケートツール 工具\n\t\n\t\n\t BOARD ACCESSORIESデッキ アクセサリー\n\t\n\t\n\t SPARE & OTHERスペア その他\n\t\n\t\n\t PROTECTORプロテクター\n\t\n\t\n\t HELMETヘルメット\n\t\n\t\n\t MEDIA & DVD映像/雑誌\n\t\n\t\n\t OTHER X-TREAMその他Xポーツ用品\n\t\n\n    \n    \n   \n   \n    \n\t\t\t\t\t\t\t\tSHOESシューズ\n    \n    \n    \n    \n\n\t\n\t SHOES BRANDシューズ ブランド別一覧\n\t\n\t\n\t WOMENS SHOESレディース シューズ\n\t\n\t\n\t KIDS SHOESキッズシューズ\n\t\n\t\n\t SANDALサンダル その他\n\t\n\n    \n    \n   \n   \n    \n\t\t\t\t\t\t\t\tAPPAREL服/ウェア\n    \n    \n    \n    \nメンズ\n\t\n\t T-SHIRTSTシャツ\n\t\n\t\n\t L/S TEEロングTシャツ\n\t\n\t\n\t POLO & WOVENポロシャツ その他シャツ\n\t\n\t\n\t SWAET & PARKAパーカー/スウェット\n\t\n\t\n\t OUTER JACKETアウター/ジャケット\n\t\n\t\n\t BOTTOMSボトム/パンツ\n\t\n\nヘッド/ハードウェア\n\t\n\t CAP & HATSキャップ/帽子\n\t\n\t\n\t BEANIESニットキャップ/ビーニー\n\t\n\t\n\t BAG & BACKPACKバッグ/バックパック\n\t\n\nキッズ&レディース\n\t\n\t KIDS ITEMキッズアイテム一覧\n\t\n\t\n\t WOMENS ITEMレディースアイテム一覧\n\t\n\n    \n    \n   \n   \n    \n\t\t\t\t\t\t\t\tACCESSORY小物/グッズ\n    \n    \n    \n    \n\n\t\n\t STICKERステッカー\n\t\n\t\n\t SUNGLASSサングラス\n\t\n\t\n\t KEYCHAINキーホルダー\n\t\n\t\n\t PATCHESパッチ/ワッペン\n\t\n\t\n\t PINSピンバッチ\n\t\n\t\n\t WATCH時計\n\t\n\t\n\t WALET財布/ウォレット\n\t\n\t\n\t BELTベルト\n\t\n\t\n\t ACCESSORIESアクセサリー\n\t\n\t\n\t SOCKSソックス/靴下\n\t\n\t\n\t GLOVE手袋\n\t\n\t\n\t WRISTBANDリストバンド\n\t\n\t\n\t OTHER GOODSその他グッズ\n\t\n\n    \n    \n   \n   \n    \n\t\t\t\t\t\t\t\tFINGERBOARD指スケ\n    \n    \n    \n    \n\n\t\n\t ALL FINGER BOARDS指スケ全品\n\t\n\t\n\t TECH DECKテックデッキ\n\t\n\t\n\t CLOSE UPクローズアップ\n\t\n\t\n\t BLACK RIVERブラックリバー\n\t\n\t\n\t 4CORNERフォーコーナー\n\t\n\t\n\t CIRCUIT BOARDサーキット\n\t\n\t\n\t FLICK TRIXフィンガーバイク\n\t\n\n    \n    \n   \n\n    \n    \n\t\t\t\t\t\t\t\tPOPULAR人気カテ\n    \n    \n    \n    \n\n\n \n ブランド(一覧)\n \n\n\n \n 在庫処分セール会場\n \n\n\n \n 指スケ(全アイテム)\n \n\n\n \n ワゴンセール\n \n\n\n    \n    \n   \n    \n    \n\t\t\t\t\t\t\t\tCONTENT読み物\n    \n    \n    \n    \n\n\n \n メルマガ登録・更新・解除\n \n\n\n \n 指スケって何？\n \n\n\n \n よくあるご質問\n \n\n\n \n ウェアハウス即売会(予約制)のお知らせ\n \n\n\n \n スケートボードの購入方法\n \n\n\n    \n    \n   \n \n  \n  \n \n \n  \n  \n   \n   ご利用ガイド\n   \n   \n   \n    お問い合わせ\n   \n   \n \n   ショップブログ\n   \n   \n    \n \n   \n    \n   \n   \n    \n   \n    \n   \n   \n    \n   \n    \n   \n   \n \n    \n \n \n\t\n \n \n  \n  MENU\n \n \n  \n  SEARCH\n \n \n  \n  \n  \n  CART\n \n \n \n \n  \n  \n   \n   メニューを閉じる\n  \n  \n  \n  \n   \n   \n\t \n   \n   HOME  \n\t \n  \n \n \n  USER\n \n \n   \n  \n   \n   会員登録  \n  \n    \n  \n   \n   ログイン  \n  \n \n  \n   \n   アカウント  \n  \n \n  \n  CATEGORY\n \n   \n  \n  \n   SKATEBOARDスケートボードを探す\n  \n  \n   \n  \n  \n  \n  \n   - 完成済みスケボー\n\t\n\t COMPETE SKATEBOARD組み立て済みトリック用ボード\n\t\n\t\n\t KIDS COMPLETE組み立て済みキッズサイズボード\n\t\n\t\n\t CRUISER&LONGBOARD組み立て済みロング/クルーザー\n\t\n   - デッキ単品\n\t\n\t DECKデッキ ブランド別一覧\n\t\n\t\n\t BLANK格安無地デッキ\n\t\n\t\n\t KIDS DECKキッズサイズ デッキ\n\t\n\t\n\t OLDSCHOOLオールドスクールシェイプ\n  \n  \n \n \n  \n  \n   SKATE PARTSスケボーパーツを探す\n  \n  \n   \n  \n  \n  \n  \n   - 主要パーツ\n\t\n\t TRUCKトラック\n\t\n\t\n\t WHEELSトリック用ウィール\n\t\n\t\n\t CRUISER WHEELSクルーザーウィール\n\t\n\t\n\t BEARINGSベアリング\n\t\n\t\n\t HARDWHEARハードウェア(ボルト)\n\t\n\t\n\t GRIP TAPEデッキテープ\n\t\n   - アクセサリ/ギア\n\t\n\t BUSHINGSブッシュ/クッシュゴム\n\t\n\t\n\t RISER PADライザーパッド\n\t\n\t\n\t SKATEBOARD WAXカーブ ワックス\n\t\n\t\n\t SKATE  ...
# ((133) )(133) アイテム(125) 全(123) /(34) &(24) シューズ(20) スケート(18) -(16) SHOES(16) ,(16) 円(16) LAKAI(15) デッキ(15) ラカイ(12) 一覧(10) その他(10) ボード(9) WHEELS(9) 済み(8) KIDS(8) 指(8) スケ(8) NO(8) 定価(8) nbsp(8) ;(8) FOOTWEAR(7) モデル(7) SKATEBOARD(6) 組み立て(6) DECK(6) ブランド(6) OTHER(6) レディース(6) ブラック(6) LIMITED(6) XLK(6) X(5) セール(5) トリック(4) 用(4) CRUISER(4) ロング(4) 別(4) SKATE(4) ハードウェア(4) BOARD(4) ACCESSORIES(4) アクセサリー(4)
