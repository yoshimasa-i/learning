# %% [markdown]
# ## テキストマイニング
#
# 出現頻度を取得

# %%
# text-mining.py
 
# python解析器janomeをインポート - 1
from janome.tokenizer import Tokenizer
 
# 形態素解析用オブジェクトの生成 - 2
text = Tokenizer()
 
# txtファイルからデータの読み込み - 3
text_file = open("text_1.txt")
bindata = text_file.read()
txt = bindata
 
# txtから読み込んだデータを形態素解析 - 4
lines = txt.split("\r\n")
for i in lines:
    print(i)
    print("\n")
    text_c = text.tokenize(i)
    for j in text_c:
      print(j)
 
print("\n")
 
# テキストを一行ごとに処理 - 5
word_dic = {}
lines_1 = txt.split("\r\n")
print(lines_1)
print("\n")
for line in lines_1:
    malist = text.tokenize(line)
    for w in malist:
	    word = w.surface
	    ps = w.part_of_speech # 品詞 - 6
	    if ps.find("名詞") < 0: continue # 名詞だけをカウント - 7
	    if not word in word_dic:
		    word_dic[word] = 0
	    word_dic[word] += 1
 
# よく使われる単語を表示 - 8
keys = sorted(word_dic.items(), key=lambda x:x[1], reverse=True)
for word, cnt in keys[:50]:
    print("{0}({1}) ".format(word,cnt), end="")
# Out:
# プルームテックプラスのたばこカプセルは全4種類。レギュラーとメンソール2種類ずつに分けられます。
#
# レギュラー：マイルドブレンド、ローストブレンド
# メンソール：クリアミント、コールドミント
#
# どっち派の人でも2つ買ってしまえば絞れるので選びやすいですよね。
#
# ちなみに私は基本レギュラー派なのですが、気分でメンソールも吸うため全種類何度もループしております。
#
# そこで改めて実感したんですけど、プルームテックプラスのフレーバー4種類はどれも吸いやすい。
#
# それぞれ個性がありつつもハズレがない印象です。てことで1つに固執しすぎて飽きがきても全然平気。素晴らしい。
#
# 今回はそんなプルームテックプラスのタバコカプセルをご紹介していきます。
#
# フレーバー全4種類
#
# メビウス・マイルドブレンド
# メビウス・ローストブレンド
# メビウス・クリアミント
# メビウス・コールドミント
#
# 1箱税込み500円。
#
# 開封するとパッケージ色がそのまんま中身に反映されてます。内容物はリキッド入りのカートリッジ1本とタバコカプセル5つ。
#
# カートリッジ1本→250パフ分
# タバコカプセル1個→50パフ分
#
# カートリッジ1本でタバコカプセル5本を消費できます。TOTAL250回の吸引で1箱吸い切る計算になりますね。
#
# カートリッジ自体にも商品名が記載されるのでうっかりミス防止に役立ちます。4つ並べてみるとローストだけ目立ってますね。
#
# 同じ低温加熱のプルームテックとの違いはタバコ葉とベイパーの増量。値段もサイズもアップしましたが、しっかりと吸い応えもアップです。
#
# ではそれぞれの紹介から味の感想まで一気にいきます！
#
# メビウス・マイルド・ブレンド【レギュラー】
#
# プルーム公式で香ばしさ＋奥深いコクと紹介されてました。
#
# 私が初めて吸った時に感じたのは、
# うんうん。ちょっと甘くて深いコク。香ばしさは強め。
#
# まんまでした。
#
# アイコスのディープブロンズ吸った時に近いものがありまして、どことなくカカオ系を連想する甘さとコクが印象的。
#
# たばこ感を求める方には最適だと思います。
#
# メビウス・クリア・ミント【メンソール】
#
# クリアミントを分かりやすく表現するならミント系ガムでしょう。
#
# メンソールは多少控えめでとても吸いやすく、味がハッキリして喉にもガツンと来る満足度の高いメンソール。
#
# スッキリしますね。メンソールではこちらが好き。
#
# メビウス・コールド・ミント【メンソール】
#
# コールドミントは冷涼感が特徴です。
#
# 口の中がスース―になるので夏に良く合うミントメンソール。クリアミントとの差別化はできてますが、これ系はとくに珍しくもありません。
#
# 歯磨きした後の様な爽快感が残ります。
#
# ゆっくり強めに、長めに吸ってみよう
#
# プルームテックの吸い方は
#
# ゆっくりと
# 長めに
# 強めに
# これが1番吸い応えを感じられます。早く強くても、ゆっくり弱くても、味とキック感がまるで異なります。
#
# また1カプセル50パフ吸い切りですが、後半は容量不足で満足度は明らかに下がります。
#
# その場合にもガンガン強めで絞り出す感じではなく、ゆっくり、長めに、強めにを心掛けてみて下さい。だいぶ変わってきます。
#
# 単純に吸いやすさを求めるならマウスピースがおすすめです。アクセサリー類もチェックしてみて下さいね。
#
#
#
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# 4	名詞,数,*,*,*,*,4,*,*
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
# 。	記号,句点,*,*,*,*,。,。,。
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# 2	名詞,数,*,*,*,*,2,*,*
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
# ずつ	助詞,副助詞,*,*,*,*,ずつ,ズツ,ズツ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 分け	動詞,自立,*,*,一段,未然形,分ける,ワケ,ワケ
# られ	動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# ：	記号,一般,*,*,*,*,：,：,：
# マイルドブレンド	名詞,固有名詞,組織,*,*,*,マイルドブレンド,*,*
# 、	記号,読点,*,*,*,*,、,、,、
# ロースト	名詞,一般,*,*,*,*,ロースト,ロースト,ロースト
# ブレンド	名詞,サ変接続,*,*,*,*,ブレンド,ブレンド,ブレンド
#
# 	記号,空白,*,*,*,*,
# ,*,*
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# ：	記号,一般,*,*,*,*,：,：,：
# クリア	名詞,サ変接続,*,*,*,*,クリア,クリア,クリア
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
# 、	記号,読点,*,*,*,*,、,、,、
# コールド	名詞,一般,*,*,*,*,コールド,コールド,コールド
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# どっち	名詞,代名詞,一般,*,*,*,どっち,ドッチ,ドッチ
# 派	名詞,接尾,一般,*,*,*,派,ハ,ハ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 2	名詞,数,*,*,*,*,2,*,*
# つ	助動詞,*,*,*,下二・タ行,基本形,つ,ツ,ツ
# 買っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,買う,カッ,カッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# しまえ	動詞,非自立,*,*,五段・ワ行促音便,仮定形,しまう,シマエ,シマエ
# ば	助詞,接続助詞,*,*,*,*,ば,バ,バ
# 絞れる	動詞,自立,*,*,一段,基本形,絞れる,シボレル,シボレル
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# 選び	動詞,自立,*,*,五段・バ行,連用形,選ぶ,エラビ,エラビ
# やすい	形容詞,非自立,*,*,形容詞・アウオ段,基本形,やすい,ヤスイ,ヤスイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# よ	助詞,終助詞,*,*,*,*,よ,ヨ,ヨ
# ね	助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# ちなみに	接続詞,*,*,*,*,*,ちなみに,チナミニ,チナミニ
# 私	名詞,代名詞,一般,*,*,*,私,ワタシ,ワタシ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 基本	名詞,一般,*,*,*,*,基本,キホン,キホン
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# 派	名詞,接尾,一般,*,*,*,派,ハ,ハ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# 気分	名詞,一般,*,*,*,*,気分,キブン,キブン
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 吸う	動詞,自立,*,*,五段・ワ行促音便,基本形,吸う,スウ,スウ
# ため	名詞,非自立,副詞可能,*,*,*,ため,タメ,タメ
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
# 何	名詞,数,*,*,*,*,何,ナン,ナン
# 度	名詞,接尾,助数詞,*,*,*,度,ド,ド
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# ループ	名詞,一般,*,*,*,*,ループ,ループ,ループ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# おり	動詞,非自立,*,*,五段・ラ行,連用形,おる,オリ,オリ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# そこで	接続詞,*,*,*,*,*,そこで,ソコデ,ソコデ
# 改めて	副詞,一般,*,*,*,*,改めて,アラタメテ,アラタメテ
# 実感	名詞,サ変接続,*,*,*,*,実感,ジッカン,ジッカン
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# ん	名詞,非自立,一般,*,*,*,ん,ン,ン
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# 、	記号,読点,*,*,*,*,、,、,、
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# フレーバー	名詞,一般,*,*,*,*,フレーバー,フレーバー,フレーバー
# 4	名詞,数,*,*,*,*,4,*,*
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# どれ	名詞,代名詞,一般,*,*,*,どれ,ドレ,ドレ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 吸い	動詞,自立,*,*,五段・ワ行促音便,連用形,吸う,スイ,スイ
# やすい	形容詞,非自立,*,*,形容詞・アウオ段,基本形,やすい,ヤスイ,ヤスイ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# それぞれ	名詞,副詞可能,*,*,*,*,それぞれ,ソレゾレ,ソレゾレ
# 個性	名詞,一般,*,*,*,*,個性,コセイ,コセイ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# あり	動詞,自立,*,*,五段・ラ行,連用形,ある,アリ,アリ
# つつ	助詞,接続助詞,*,*,*,*,つつ,ツツ,ツツ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# ハズレ	名詞,一般,*,*,*,*,ハズレ,ハズレ,ハズレ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# 印象	名詞,一般,*,*,*,*,印象,インショウ,インショー
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
# てこ	名詞,一般,*,*,*,*,てこ,テコ,テコ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 1	名詞,数,*,*,*,*,1,*,*
# つ	助動詞,*,*,*,下二・タ行,基本形,つ,ツ,ツ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 固執	名詞,サ変接続,*,*,*,*,固執,コシツ,コシツ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# すぎ	動詞,非自立,*,*,一段,連用形,すぎる,スギ,スギ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 飽き	名詞,一般,*,*,*,*,飽き,アキ,アキ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# き	動詞,自立,*,*,カ変・クル,連用形,くる,キ,キ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 全然	副詞,助詞類接続,*,*,*,*,全然,ゼンゼン,ゼンゼン
# 平気	名詞,一般,*,*,*,*,平気,ヘイキ,ヘイキ
# 。	記号,句点,*,*,*,*,。,。,。
# 素晴らしい	形容詞,自立,*,*,形容詞・イ段,基本形,素晴らしい,スバラシイ,スバラシイ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 今回	名詞,副詞可能,*,*,*,*,今回,コンカイ,コンカイ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# そんな	連体詞,*,*,*,*,*,そんな,ソンナ,ソンナ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# ご	接頭詞,名詞接続,*,*,*,*,ご,ゴ,ゴ
# 紹介	名詞,サ変接続,*,*,*,*,紹介,ショウカイ,ショーカイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いき	動詞,非自立,*,*,五段・カ行促音便,連用形,いく,イキ,イキ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# フレーバー	名詞,一般,*,*,*,*,フレーバー,フレーバー,フレーバー
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# 4	名詞,数,*,*,*,*,4,*,*
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# メビウス・マイルドブレンド	名詞,一般,*,*,*,*,メビウス・マイルドブレンド,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
# ・	記号,一般,*,*,*,*,・,・,・
# ロースト	名詞,一般,*,*,*,*,ロースト,ロースト,ロースト
# ブレンド	名詞,サ変接続,*,*,*,*,ブレンド,ブレンド,ブレンド
#
# 	記号,空白,*,*,*,*,
# ,*,*
# メビウス・クリアミント	名詞,一般,*,*,*,*,メビウス・クリアミント,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
# ・	記号,一般,*,*,*,*,・,・,・
# コールド	名詞,一般,*,*,*,*,コールド,コールド,コールド
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 1	名詞,数,*,*,*,*,1,*,*
# 箱	名詞,接尾,助数詞,*,*,*,箱,ハコ,ハコ
# 税込み	名詞,一般,*,*,*,*,税込み,ゼイコミ,ゼイコミ
# 500	名詞,数,*,*,*,*,500,*,*
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 開封	名詞,サ変接続,*,*,*,*,開封,カイフウ,カイフー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# パッケージ	名詞,一般,*,*,*,*,パッケージ,パッケージ,パッケージ
# 色	名詞,接尾,一般,*,*,*,色,ショク,ショク
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# その	連体詞,*,*,*,*,*,その,ソノ,ソノ
# まんま	名詞,非自立,副詞可能,*,*,*,まんま,マンマ,マンマ
# 中身	名詞,一般,*,*,*,*,中身,ナカミ,ナカミ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 反映	名詞,サ変接続,*,*,*,*,反映,ハンエイ,ハンエイ
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
# 内容	名詞,一般,*,*,*,*,内容,ナイヨウ,ナイヨー
# 物	名詞,接尾,一般,*,*,*,物,ブツ,ブツ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# リキッド	名詞,一般,*,*,*,*,リキッド,*,*
# 入り	名詞,接尾,サ変接続,*,*,*,入り,イリ,イリ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# カートリッジ	名詞,一般,*,*,*,*,カートリッジ,カートリッジ,カートリッジ
# 1	名詞,数,*,*,*,*,1,*,*
# 本	名詞,接尾,助数詞,*,*,*,本,ホン,ホン
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# 5	名詞,数,*,*,*,*,5,*,*
# つ	助動詞,*,*,*,下二・タ行,基本形,つ,ツ,ツ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# カートリッジ	名詞,一般,*,*,*,*,カートリッジ,カートリッジ,カートリッジ
# 1	名詞,数,*,*,*,*,1,*,*
# 本	名詞,接尾,助数詞,*,*,*,本,ホン,ホン
# →	記号,一般,*,*,*,*,→,→,→
# 250	名詞,数,*,*,*,*,250,*,*
# パフ	名詞,一般,*,*,*,*,パフ,パフ,パフ
# 分	名詞,接尾,一般,*,*,*,分,ブン,ブン
#
# 	記号,空白,*,*,*,*,
# ,*,*
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# 1	名詞,数,*,*,*,*,1,*,*
# 個	名詞,接尾,助数詞,*,*,*,個,コ,コ
# →	記号,一般,*,*,*,*,→,→,→
# 50	名詞,数,*,*,*,*,50,*,*
# パフ	名詞,一般,*,*,*,*,パフ,パフ,パフ
# 分	名詞,接尾,一般,*,*,*,分,ブン,ブン
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# カートリッジ	名詞,一般,*,*,*,*,カートリッジ,カートリッジ,カートリッジ
# 1	名詞,数,*,*,*,*,1,*,*
# 本	名詞,接尾,助数詞,*,*,*,本,ホン,ホン
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# 5	名詞,数,*,*,*,*,5,*,*
# 本	名詞,接尾,助数詞,*,*,*,本,ホン,ホン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 消費	名詞,サ変接続,*,*,*,*,消費,ショウヒ,ショーヒ
# でき	動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
# TOTAL	名詞,一般,*,*,*,*,TOTAL,*,*
# 250	名詞,数,*,*,*,*,250,*,*
# 回	名詞,接尾,助数詞,*,*,*,回,カイ,カイ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 吸引	名詞,サ変接続,*,*,*,*,吸引,キュウイン,キューイン
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 1	名詞,数,*,*,*,*,1,*,*
# 箱	名詞,接尾,助数詞,*,*,*,箱,ハコ,ハコ
# 吸い	動詞,自立,*,*,五段・ワ行促音便,連用形,吸う,スイ,スイ
# 切る	動詞,非自立,*,*,五段・ラ行,基本形,切る,キル,キル
# 計算	名詞,サ変接続,*,*,*,*,計算,ケイサン,ケイサン
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# ね	助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# カートリッジ	名詞,一般,*,*,*,*,カートリッジ,カートリッジ,カートリッジ
# 自体	名詞,一般,*,*,*,*,自体,ジタイ,ジタイ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 商品	名詞,一般,*,*,*,*,商品,ショウヒン,ショーヒン
# 名	名詞,接尾,一般,*,*,*,名,メイ,メイ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 記載	名詞,サ変接続,*,*,*,*,記載,キサイ,キサイ
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れる	動詞,接尾,*,*,一段,基本形,れる,レル,レル
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# うっかり	副詞,一般,*,*,*,*,うっかり,ウッカリ,ウッカリ
# ミス	名詞,サ変接続,*,*,*,*,ミス,ミス,ミス
# 防止	名詞,サ変接続,*,*,*,*,防止,ボウシ,ボーシ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 役立ち	動詞,自立,*,*,五段・タ行,連用形,役立つ,ヤクダチ,ヤクダチ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
# 4	名詞,数,*,*,*,*,4,*,*
# つ	助動詞,*,*,*,下二・タ行,基本形,つ,ツ,ツ
# 並べ	動詞,自立,*,*,一段,連用形,並べる,ナラベ,ナラベ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# みる	動詞,非自立,*,*,一段,基本形,みる,ミル,ミル
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# ロースト	名詞,一般,*,*,*,*,ロースト,ロースト,ロースト
# だけ	助詞,副助詞,*,*,*,*,だけ,ダケ,ダケ
# 目立っ	動詞,自立,*,*,五段・タ行,連用タ接続,目立つ,メダッ,メダッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# ね	助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 同じ	連体詞,*,*,*,*,*,同じ,オナジ,オナジ
# 低温	名詞,一般,*,*,*,*,低温,テイオン,テイオン
# 加熱	名詞,サ変接続,*,*,*,*,加熱,カネツ,カネツ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# プルームテック	名詞,一般,*,*,*,*,プルームテック,*,*
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 違い	名詞,ナイ形容詞語幹,*,*,*,*,違い,チガイ,チガイ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# 葉	名詞,一般,*,*,*,*,葉,ハ,ハ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# ベイ	名詞,一般,*,*,*,*,ベイ,ベイ,ベイ
# パー	名詞,一般,*,*,*,*,パー,パー,パー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 増量	名詞,サ変接続,*,*,*,*,増量,ゾウリョウ,ゾーリョー
# 。	記号,句点,*,*,*,*,。,。,。
# 値段	名詞,一般,*,*,*,*,値段,ネダン,ネダン
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# サイズ	名詞,一般,*,*,*,*,サイズ,サイズ,サイズ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# アップ	名詞,サ変接続,*,*,*,*,アップ,アップ,アップ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# まし	助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# しっかり	副詞,助詞類接続,*,*,*,*,しっかり,シッカリ,シッカリ
# と	助詞,副詞化,*,*,*,*,と,ト,ト
# 吸い	動詞,自立,*,*,五段・ワ行促音便,連用形,吸う,スイ,スイ
# 応え	名詞,一般,*,*,*,*,応え,コタエ,コタエ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# アップ	名詞,サ変接続,*,*,*,*,アップ,アップ,アップ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# では	接続詞,*,*,*,*,*,では,デハ,デワ
# それぞれ	名詞,副詞可能,*,*,*,*,それぞれ,ソレゾレ,ソレゾレ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 紹介	名詞,サ変接続,*,*,*,*,紹介,ショウカイ,ショーカイ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 感想	名詞,一般,*,*,*,*,感想,カンソウ,カンソー
# まで	助詞,副助詞,*,*,*,*,まで,マデ,マデ
# 一気に	副詞,一般,*,*,*,*,一気に,イッキニ,イッキニ
# いき	動詞,自立,*,*,五段・カ行促音便,連用形,いく,イキ,イキ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# ！	記号,一般,*,*,*,*,！,！,！
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# メビウス・マイルド・ブレンド	名詞,一般,*,*,*,*,メビウス・マイルド・ブレンド,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# 】	記号,括弧閉,*,*,*,*,】,】,】
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# プルーム	名詞,一般,*,*,*,*,プルーム,*,*
# 公式	名詞,形容動詞語幹,*,*,*,*,公式,コウシキ,コーシキ
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# 香ばし	形容詞,自立,*,*,形容詞・イ段,ガル接続,香ばしい,コウバシ,コーバシ
# さ	名詞,接尾,特殊,*,*,*,さ,サ,サ
# ＋	記号,一般,*,*,*,*,＋,タス,タス
# 奥深い	形容詞,自立,*,*,形容詞・アウオ段,基本形,奥深い,オクフカイ,オクフカイ
# コク	名詞,一般,*,*,*,*,コク,コク,コク
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# 紹介	名詞,サ変接続,*,*,*,*,紹介,ショウカイ,ショーカイ
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# まし	助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 私	名詞,代名詞,一般,*,*,*,私,ワタシ,ワタシ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 初めて	副詞,一般,*,*,*,*,初めて,ハジメテ,ハジメテ
# 吸っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,吸う,スッ,スッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 時	名詞,非自立,副詞可能,*,*,*,時,トキ,トキ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 感じ	動詞,自立,*,*,一段,連用形,感じる,カンジ,カンジ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
#
# 	記号,空白,*,*,*,*,
# ,*,*
# うん	感動詞,*,*,*,*,*,うん,ウン,ウン
# うん	感動詞,*,*,*,*,*,うん,ウン,ウン
# 。	記号,句点,*,*,*,*,。,。,。
# ちょっと	副詞,助詞類接続,*,*,*,*,ちょっと,チョット,チョット
# 甘く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,甘い,アマク,アマク
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 深い	形容詞,自立,*,*,形容詞・アウオ段,基本形,深い,フカイ,フカイ
# コク	名詞,一般,*,*,*,*,コク,コク,コク
# 。	記号,句点,*,*,*,*,。,。,。
# 香ばし	形容詞,自立,*,*,形容詞・イ段,ガル接続,香ばしい,コウバシ,コーバシ
# さ	名詞,接尾,特殊,*,*,*,さ,サ,サ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 強め	動詞,自立,*,*,一段,連用形,強める,ツヨメ,ツヨメ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# まんま	名詞,非自立,副詞可能,*,*,*,まんま,マンマ,マンマ
# でし	助動詞,*,*,*,特殊・デス,連用形,です,デシ,デシ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# アイコス	名詞,一般,*,*,*,*,アイコス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# ディープブロンズ	名詞,一般,*,*,*,*,ディープブロンズ,*,*
# 吸っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,吸う,スッ,スッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 時	名詞,非自立,副詞可能,*,*,*,時,トキ,トキ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 近い	形容詞,自立,*,*,形容詞・アウオ段,基本形,近い,チカイ,チカイ
# もの	名詞,非自立,一般,*,*,*,もの,モノ,モノ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# あり	動詞,自立,*,*,五段・ラ行,連用形,ある,アリ,アリ
# まし	助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# どことなく	副詞,一般,*,*,*,*,どことなく,ドコトナク,ドコトナク
# カカオ	名詞,一般,*,*,*,*,カカオ,カカオ,カカオ
# 系	名詞,接尾,一般,*,*,*,系,ケイ,ケイ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 連想	名詞,サ変接続,*,*,*,*,連想,レンソウ,レンソー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# 甘	形容詞,自立,*,*,形容詞・アウオ段,ガル接続,甘い,アマ,アマ
# さ	名詞,接尾,特殊,*,*,*,さ,サ,サ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# コク	名詞,一般,*,*,*,*,コク,コク,コク
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 印象	名詞,一般,*,*,*,*,印象,インショウ,インショー
# 的	名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# 感	名詞,接尾,一般,*,*,*,感,カン,カン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 求める	動詞,自立,*,*,一段,基本形,求める,モトメル,モトメル
# 方	名詞,非自立,一般,*,*,*,方,ホウ,ホー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 最適	名詞,一般,*,*,*,*,最適,サイテキ,サイテキ
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 思い	動詞,自立,*,*,五段・ワ行促音便,連用形,思う,オモイ,オモイ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
# ・	記号,一般,*,*,*,*,・,・,・
# クリア	名詞,サ変接続,*,*,*,*,クリア,クリア,クリア
# ・	記号,一般,*,*,*,*,・,・,・
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
# 【	記号,括弧開,*,*,*,*,【,【,【
# メンソール	名詞,固有名詞,一般,*,*,*,メンソール,*,*
# 】	記号,括弧閉,*,*,*,*,】,】,】
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# クリア	名詞,サ変接続,*,*,*,*,クリア,クリア,クリア
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 分かり	動詞,自立,*,*,五段・ラ行,連用形,分かる,ワカリ,ワカリ
# やすく	形容詞,非自立,*,*,形容詞・アウオ段,連用テ接続,やすい,ヤスク,ヤスク
# 表現	名詞,サ変接続,*,*,*,*,表現,ヒョウゲン,ヒョーゲン
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# なら	助動詞,*,*,*,特殊・ダ,仮定形,だ,ナラ,ナラ
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
# 系	名詞,接尾,一般,*,*,*,系,ケイ,ケイ
# ガム	名詞,一般,*,*,*,*,ガム,ガム,ガム
# でしょ	助動詞,*,*,*,特殊・デス,未然形,です,デショ,デショ
# う	助動詞,*,*,*,不変化型,基本形,う,ウ,ウ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 多少	副詞,助詞類接続,*,*,*,*,多少,タショウ,タショー
# 控えめ	名詞,一般,*,*,*,*,控えめ,ヒカエメ,ヒカエメ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# とても	副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ
# 吸い	動詞,自立,*,*,五段・ワ行促音便,連用形,吸う,スイ,スイ
# やすく	形容詞,非自立,*,*,形容詞・アウオ段,連用テ接続,やすい,ヤスク,ヤスク
# 、	記号,読点,*,*,*,*,、,、,、
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# ハッキリ	副詞,助詞類接続,*,*,*,*,ハッキリ,ハッキリ,ハッキリ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 喉	名詞,一般,*,*,*,*,喉,ノド,ノド
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# ガ	名詞,一般,*,*,*,*,ガ,ガ,ガ
# ツン	副詞,助詞類接続,*,*,*,*,ツン,ツン,ツン
# と	助詞,副詞化,*,*,*,*,と,ト,ト
# 来る	動詞,自立,*,*,カ変・来ル,基本形,来る,クル,クル
# 満足	名詞,サ変接続,*,*,*,*,満足,マンゾク,マンゾク
# 度	名詞,接尾,一般,*,*,*,度,ド,ド
# の	助詞,格助詞,一般,*,*,*,の,ノ,ノ
# 高い	形容詞,自立,*,*,形容詞・アウオ段,基本形,高い,タカイ,タカイ
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# スッキリ	副詞,助詞類接続,*,*,*,*,スッキリ,スッキリ,スッキリ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# ね	助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。	記号,句点,*,*,*,*,。,。,。
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# こちら	名詞,代名詞,一般,*,*,*,こちら,コチラ,コチラ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 好き	名詞,形容動詞語幹,*,*,*,*,好き,スキ,スキ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
# ・	記号,一般,*,*,*,*,・,・,・
# コールド	名詞,一般,*,*,*,*,コールド,コールド,コールド
# ・	記号,一般,*,*,*,*,・,・,・
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
# 【	記号,括弧開,*,*,*,*,【,【,【
# メンソール	名詞,固有名詞,一般,*,*,*,メンソール,*,*
# 】	記号,括弧閉,*,*,*,*,】,】,】
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# コールド	名詞,一般,*,*,*,*,コールド,コールド,コールド
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 冷涼	名詞,一般,*,*,*,*,冷涼,レイリョウ,レイリョー
# 感	名詞,接尾,一般,*,*,*,感,カン,カン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 特徴	名詞,一般,*,*,*,*,特徴,トクチョウ,トクチョー
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 口	名詞,一般,*,*,*,*,口,クチ,クチ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 中	名詞,非自立,副詞可能,*,*,*,中,ナカ,ナカ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# スース	名詞,一般,*,*,*,*,スース,*,*
# ―	記号,一般,*,*,*,*,―,―,―
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なる	動詞,自立,*,*,五段・ラ行,基本形,なる,ナル,ナル
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# 夏	名詞,一般,*,*,*,*,夏,ナツ,ナツ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 良く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,良い,ヨク,ヨク
# 合う	動詞,自立,*,*,五段・ワ行促音便,基本形,合う,アウ,アウ
# ミントメンソール	名詞,一般,*,*,*,*,ミントメンソール,*,*
# 。	記号,句点,*,*,*,*,。,。,。
# クリア	名詞,サ変接続,*,*,*,*,クリア,クリア,クリア
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 差別	名詞,サ変接続,*,*,*,*,差別,サベツ,サベツ
# 化	名詞,接尾,サ変接続,*,*,*,化,カ,カ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# でき	動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# これ	名詞,代名詞,一般,*,*,*,これ,コレ,コレ
# 系	名詞,接尾,一般,*,*,*,系,ケイ,ケイ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# とくに	副詞,一般,*,*,*,*,とくに,トクニ,トクニ
# 珍しく	形容詞,自立,*,*,形容詞・イ段,連用テ接続,珍しい,メズラシク,メズラシク
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# あり	動詞,自立,*,*,五段・ラ行,連用形,ある,アリ,アリ
# ませ	助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ
# ん	助動詞,*,*,*,不変化型,基本形,ん,ン,ン
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 歯磨き	名詞,サ変接続,*,*,*,*,歯磨き,ハミガキ,ハミガキ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 後	名詞,非自立,副詞可能,*,*,*,後,ノチ,ノチ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 様	名詞,非自立,助動詞語幹,*,*,*,様,ヨウ,ヨー
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 爽快	名詞,一般,*,*,*,*,爽快,ソウカイ,ソーカイ
# 感	名詞,接尾,一般,*,*,*,感,カン,カン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 残り	動詞,自立,*,*,五段・ラ行,連用形,残る,ノコリ,ノコリ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# ゆっくり	副詞,助詞類接続,*,*,*,*,ゆっくり,ユックリ,ユックリ
# 強め	動詞,自立,*,*,一段,連用形,強める,ツヨメ,ツヨメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 、	記号,読点,*,*,*,*,、,、,、
# 長め	名詞,形容動詞語幹,*,*,*,*,長め,ナガメ,ナガメ
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# 吸っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,吸う,スッ,スッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# みよ	動詞,非自立,*,*,一段,未然ウ接続,みる,ミヨ,ミヨ
# う	助動詞,*,*,*,不変化型,基本形,う,ウ,ウ
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# プルームテック	名詞,一般,*,*,*,*,プルームテック,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 吸い	動詞,自立,*,*,五段・ワ行促音便,連用形,吸う,スイ,スイ
# 方	名詞,接尾,特殊,*,*,*,方,カタ,カタ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# ゆっくり	副詞,助詞類接続,*,*,*,*,ゆっくり,ユックリ,ユックリ
# と	助詞,副詞化,*,*,*,*,と,ト,ト
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 長め	名詞,一般,*,*,*,*,長め,ナガメ,ナガメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 強め	動詞,自立,*,*,一段,連用形,強める,ツヨメ,ツヨメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# これ	名詞,代名詞,一般,*,*,*,これ,コレ,コレ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 1	名詞,数,*,*,*,*,1,*,*
# 番	名詞,接尾,助数詞,*,*,*,番,バン,バン
# 吸い	動詞,自立,*,*,五段・ワ行促音便,連用形,吸う,スイ,スイ
# 応え	名詞,一般,*,*,*,*,応え,コタエ,コタエ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 感じ	動詞,自立,*,*,一段,未然形,感じる,カンジ,カンジ
# られ	動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
# 早く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,早い,ハヤク,ハヤク
# 強く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,強い,ツヨク,ツヨク
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 、	記号,読点,*,*,*,*,、,、,、
# ゆっくり	副詞,助詞類接続,*,*,*,*,ゆっくり,ユックリ,ユックリ
# 弱く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,弱い,ヨワク,ヨワク
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 、	記号,読点,*,*,*,*,、,、,、
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# キック	名詞,サ変接続,*,*,*,*,キック,キック,キック
# 感	名詞,接尾,一般,*,*,*,感,カン,カン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# まるで	副詞,一般,*,*,*,*,まるで,マルデ,マルデ
# 異なり	動詞,自立,*,*,五段・ラ行,連用形,異なる,コトナリ,コトナリ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# また	接続詞,*,*,*,*,*,また,マタ,マタ
# 1	名詞,数,*,*,*,*,1,*,*
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# 50	名詞,数,*,*,*,*,50,*,*
# パフ	名詞,一般,*,*,*,*,パフ,パフ,パフ
# 吸い	動詞,自立,*,*,五段・ワ行促音便,連用形,吸う,スイ,スイ
# 切り	名詞,接尾,一般,*,*,*,切り,ギリ,ギリ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# 後半	名詞,副詞可能,*,*,*,*,後半,コウハン,コーハン
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 容量	名詞,一般,*,*,*,*,容量,ヨウリョウ,ヨーリョー
# 不足	名詞,サ変接続,*,*,*,*,不足,フソク,フソク
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 満足	名詞,サ変接続,*,*,*,*,満足,マンゾク,マンゾク
# 度	名詞,接尾,一般,*,*,*,度,ド,ド
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 明らか	名詞,形容動詞語幹,*,*,*,*,明らか,アキラカ,アキラカ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 下がり	動詞,自立,*,*,五段・ラ行,連用形,下がる,サガリ,サガリ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# その	連体詞,*,*,*,*,*,その,ソノ,ソノ
# 場合	名詞,副詞可能,*,*,*,*,場合,バアイ,バアイ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# ガンガン	副詞,一般,*,*,*,*,ガンガン,ガンガン,ガンガン
# 強め	動詞,自立,*,*,一段,連用形,強める,ツヨメ,ツヨメ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 絞り出す	動詞,自立,*,*,五段・サ行,基本形,絞り出す,シボリダス,シボリダス
# 感じ	名詞,一般,*,*,*,*,感じ,カンジ,カンジ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# なく	助動詞,*,*,*,特殊・ナイ,連用テ接続,ない,ナク,ナク
# 、	記号,読点,*,*,*,*,、,、,、
# ゆっくり	副詞,助詞類接続,*,*,*,*,ゆっくり,ユックリ,ユックリ
# 、	記号,読点,*,*,*,*,、,、,、
# 長め	名詞,形容動詞語幹,*,*,*,*,長め,ナガメ,ナガメ
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# 、	記号,読点,*,*,*,*,、,、,、
# 強め	動詞,自立,*,*,一段,連用形,強める,ツヨメ,ツヨメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 心掛け	動詞,自立,*,*,一段,連用形,心掛ける,ココロガケ,ココロガケ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 下さい	動詞,非自立,*,*,五段・ラ行特殊,命令ｉ,下さる,クダサイ,クダサイ
# 。	記号,句点,*,*,*,*,。,。,。
# だいぶ	副詞,一般,*,*,*,*,だいぶ,ダイブ,ダイブ
# 変わっ	動詞,自立,*,*,五段・ラ行,連用タ接続,変わる,カワッ,カワッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# き	動詞,非自立,*,*,カ変・クル,連用形,くる,キ,キ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 単純	名詞,形容動詞語幹,*,*,*,*,単純,タンジュン,タンジュン
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# 吸い	動詞,自立,*,*,五段・ワ行促音便,連用形,吸う,スイ,スイ
# やす	形容詞,非自立,*,*,形容詞・アウオ段,ガル接続,やすい,ヤス,ヤス
# さ	名詞,接尾,特殊,*,*,*,さ,サ,サ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 求める	動詞,自立,*,*,一段,基本形,求める,モトメル,モトメル
# なら	助動詞,*,*,*,特殊・ダ,仮定形,だ,ナラ,ナラ
# マウス	名詞,一般,*,*,*,*,マウス,マウス,マウス
# ピース	名詞,一般,*,*,*,*,ピース,ピース,ピース
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# おすすめ	名詞,サ変接続,*,*,*,*,おすすめ,オススメ,オススメ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
# アクセサリー	名詞,一般,*,*,*,*,アクセサリー,アクセサリー,アクセサリー
# 類	名詞,接尾,一般,*,*,*,類,ルイ,ルイ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# チェック	名詞,サ変接続,*,*,*,*,チェック,チェック,チェック
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 下さい	動詞,非自立,*,*,五段・ラ行特殊,命令ｉ,下さる,クダサイ,クダサイ
# ね	助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# ['プルームテックプラスのたばこカプセルは全4種類。レギュラーとメンソール2種類ずつに分けられます。\n\nレギュラー：マイルドブレンド、ローストブレンド\nメンソール：クリアミント、コールドミント\n\nどっち派の人でも2つ買ってしまえば絞れるので選びやすいですよね。\n\nちなみに私は基本レギュラー派なのですが、気分でメンソールも吸うため全種類何度もループしております。\n\nそこで改めて実感したんですけど、プルームテックプラスのフレーバー4種類はどれも吸いやすい。\n\nそれぞれ個性がありつつもハズレがない印象です。てことで1つに固執しすぎて飽きがきても全然平気。素晴らしい。\n\n今回はそんなプルームテックプラスのタバコカプセルをご紹介していきます。\n\nフレーバー全4種類\n\nメビウス・マイルドブレンド\nメビウス・ローストブレンド\nメビウス・クリアミント\nメビウス・コールドミント\n\n1箱税込み500円。\n\n開封するとパッケージ色がそのまんま中身に反映されてます。内容物はリキッド入りのカートリッジ1本とタバコカプセル5つ。\n\nカートリッジ1本→250パフ分\nタバコカプセル1個→50パフ分\n\nカートリッジ1本でタバコカプセル5本を消費できます。TOTAL250回の吸引で1箱吸い切る計算になりますね。\n\nカートリッジ自体にも商品名が記載されるのでうっかりミス防止に役立ちます。4つ並べてみるとローストだけ目立ってますね。\n\n同じ低温加熱のプルームテックとの違いはタバコ葉とベイパーの増量。値段もサイズもアップしましたが、しっかりと吸い応えもアップです。\n\nではそれぞれの紹介から味の感想まで一気にいきます！\n\nメビウス・マイルド・ブレンド【レギュラー】\n\nプルーム公式で香ばしさ＋奥深いコクと紹介されてました。\n\n私が初めて吸った時に感じたのは、\nうんうん。ちょっと甘くて深いコク。香ばしさは強め。\n\nまんまでした。\n\nアイコスのディープブロンズ吸った時に近いものがありまして、どことなくカカオ系を連想する甘さとコクが印象的。\n\nたばこ感を求める方には最適だと思います。\n\nメビウス・クリア・ミント【メンソール】\n\nクリアミントを分かりやすく表現するならミント系ガムでしょう。\n\nメンソールは多少控えめでとても吸いやすく、味がハッキリして喉にもガツンと来る満足度の高いメンソール。\n\nスッキリしますね。メンソールではこちらが好き。\n\nメビウス・コールド・ミント【メンソール】\n\nコールドミントは冷涼感が特徴です。\n\n口の中がスース―になるので夏に良く合うミントメンソール。クリアミントとの差別化はできてますが、これ系はとくに珍しくもありません。\n\n歯磨きした後の様な爽快感が残ります。\n\nゆっくり強めに、長めに吸ってみよう\n\nプルームテックの吸い方は\n\nゆっくりと\n長めに\n強めに\nこれが1番吸い応えを感じられます。早く強くても、ゆっくり弱くても、味とキック感がまるで異なります。\n\nまた1カプセル50パフ吸い切りですが、後半は容量不足で満足度は明らかに下がります。\n\nその場合にもガンガン強めで絞り出す感じではなく、ゆっくり、長めに、強めにを心掛けてみて下さい。だいぶ変わってきます。\n\n単純に吸いやすさを求めるならマウスピースがおすすめです。アクセサリー類もチェックしてみて下さいね。\n']
#
#
# ミント(9) 1(9) メンソール(8) カプセル(6) 種類(5) タバコ(5) 4(4) レギュラー(4) クリア(4) コールド(4) メビウス(4) カートリッジ(4) 本(4) さ(4) 感(4) プルームテックプラス(3) 全(3) ロースト(3) 度(3) 紹介(3) パフ(3) 味(3) コク(3) 系(3) 長め(3) たばこ(2) 2(2) ブレンド(2) 派(2) 私(2) の(2) フレーバー(2) それぞれ(2) 印象(2) 箱(2) まんま(2) 5(2) 250(2) 分(2) 50(2) プルームテック(2) アップ(2) 応え(2) 時(2) 方(2) 満足(2) これ(2) マイルドブレンド(1) どっち(1) 人(1)
