# %% [markdown]
# ## テキストマイニング
#
# 出現頻度を取得

# %%
# text-mining.py
 
# python解析器janomeをインポート - 1
from janome.tokenizer import Tokenizer
 
# 形態素解析用オブジェクトの生成 - 2
text = Tokenizer()
 
# txtファイルからデータの読み込み - 3
text_file = open("text_4.txt")
bindata = text_file.read()
txt = bindata
 
# txtから読み込んだデータを形態素解析 - 4
lines = txt.split("\r\n")
for i in lines:
    print(i)
    print("\n")
    text_c = text.tokenize(i)
    for j in text_c:
      print(j)
 
print("\n")
 
# テキストを一行ごとに処理 - 5
word_dic = {}
lines_1 = txt.split("\r\n")
print(lines_1)
print("\n")
for line in lines_1:
    malist = text.tokenize(line)
    for w in malist:
	    word = w.surface
	    ps = w.part_of_speech # 品詞 - 6
	    if ps.find("名詞") < 0: continue # 名詞だけをカウント - 7
	    if not word in word_dic:
		    word_dic[word] = 0
	    word_dic[word] += 1
 
# よく使われる単語を表示 - 8
keys = sorted(word_dic.items(), key=lambda x:x[1], reverse=True)
for word, cnt in keys[:50]:
    print("{0}({1}) ".format(word,cnt), end="")
# Out:
# プルームテックプラスのたばこカプセルの味【吸いごたえがアップしたフレーバー全4種類徹底レビュー】
#
# 今話題の低温加熱型電子たばこプルームテックプラス専用のたばこカプセルの味が気になる。「たばこカプセルにはどんなフレーバーの味があるのか知りたい… どうせならタバコカプセル全種類の味を詳しく教えてほしい」
#
# そんな疑問に答えます。
#
# ちなみに、プルームテックプラスにはレギュラーに2種の味、メンソールに2種の味、合計4種類のフレーバーの味があります。
#
# 以前『【レビュー】プルームテックプラスの進化に驚き！新型電子タバコ全部試してみた結果』の記事で書いたように進化したプルームテックプラスは味（キック感）・デザイン・使い勝手の進化がたまらなくいい。
#
# この記事では、プルームテックプラスのたばこカプセル全4種類の味の比較と旧型プルームテックと比べてどうなのか？を比較しています。
#
# プルームテックプラス買ってみたんだけど、カプセルコンビニ売ってなくて吸えない…なにこれ！笑#プルームテックプラス #新しい pic.twitter.com/qwtPYgpnec&mdash; ヨッシー / RESKY. (@reskysk8boarder) February 17, 2019
#
# ツイートのように、現在プルームテックプラスのたばこカプセルはコンビニでは購入できない… プルームテック直営店のみで買うことができる。
#
# 2019年4月1日から首都圏のコンビニでプルームテックプラスのたばこカプセルが購入できるようになりました。
#
# 低温加熱や高温加熱の電子タバコを全て試した僕が今1番だと感じている低温加熱プルームテックプラス（PloomTECH +）専用のたばこカプセルの味をレギュラー・メンソールの2タイプ全4種類を全部買って吸ってみたので徹底解説しながらレビューしたいと思う。
#
# 【プルームテックプラスたばこカプセルの味】フレーバーは全4種類
#
#
#
# これがプルームテックプラスに必要なたばこカプセル MEVIUS for Ploom TECH として販売されているプルームテックプラス専用たばこカプセル全4種類だ。
#
# 左からプルームテックプラス専用たばこカプセルのフレーバーの銘柄を説明すると
#
#
#
#
# 	【レギュラー】メビウス ロースト・ブレンド フォー プルーム・テック・プラス
# 	【レギュラー】メビウス マイルド・ブレンド プルーム・テック・プラス
# 	【メンソール】メビウス コールド・ミント フォー プルーム・テック・プラス
# 	【メンソール】メビウス クリア・ミント フォー プルーム・テック・プラス
#
#
#
#
# 左の2つがレギュラータイプのたばこカプセルで、右2つがメンソールタイプのたばこカプセルだ。
#
# メンソール好きなのか？レギュラー好きなのか？で選べば選択肢が狭まり好みの味を見つけやすいですね。
#
# 以下に、プルームテックプラスのたばこカプセルは全4種類の一覧表と吸ってみた味の比較を参考に載せておきます。
#
#  味の比較表
#
#
#
#
# メビウス クリア・ミント
# メビウス コールド・ミント
# メビウス ロースト・ブレンド
# メビウス マイルド・ブレンド
#
#
# ◎
# ×
# ○
# △
#
#
#
#
# 上記のフレーバーの味比較表に書いてあるとおり、僕がプルームテックプラス専用たばこカプセルのメンソールフレーバーの味で、1番吸いごたえもあって美味しいと感じたのはメビウス クリア・ミントで、レギュラーフレーバーの味ではメビウス ロースト・ブレンドが、キック感もありプルームテックプラスらしい刺激も感じれた。
#
# 新しくなったタバコカプセルは全4種類で、各たばこカプセル5個入、カートリッジ1個入りで500円（税込）だ。
#
#  メビウス クリア・ミント フォー プルーム・テック・プラスを開封したところ
#
# ちなみに、たばこカプセルを開封するとこんな感じ。
#
# カプセルの箱を開けると中には、たばこカプセル5つとカートリッジ1本が同梱されている。
#
# プルームテックプラスのバッテリーフル充電の状態で、たばこカプセル5つ分の吸引が可能だ。
#
#  たばこカプセルを吸える回数
#
#
#
#
# 	カートリッジ1本で250パフ
# 	タバコカプセル1個で50パフ
#
#
#
#
# 付属カートリッジにはリキッドと呼ばれる液体が充填されていて、カートリッジ1本につきたばこカプセル5つ分の蒸気を発生させることのできるリキッドが充填されていて、約50回吸引するとバッテリーの先端が40回青く点滅するので、その時がたばこカプセル交換の合図でカートリッジ1本でタバコカプセル5本が吸える。全部で250回吸うことができる。
#
# それではプルームテックプラスのタバコカプセルの味（フレーバー）を詳しく解説します。
#
# 1番目に美味しいと感じたフレーバーの味はメビウス クリア・ミント（メンソール）
#
#
#
# これが低温加熱たばこのプルームテックプラス専用のタバコカプセルで、正規名称は「メビウス クリア・ミント フォー プルーム・テック・プラス」と言う。全ての PloomTECH ＋ のたばこカプセルにフォー プルーム・テック・プラスとつく。
#
# プルームテックプラス専用のたばこカプセルの中で、1番美味しいと感じた味だったメビウス クリア・ミントはスタンダードなメンソールといった感じ。メンソール感が控えめでとても吸いタバコ味のハッキリした味が特長的で、喉にもガツンとくるのでキック感も感じれて満足度の高いメンソールだ。
#
#
#
# プルームテックプラスが40℃加熱になったことでキック感が増したのでシンプルに旨い！というのが、クリアミントフレーバーの第一印象だった。
#
# 僕の周りでプルームテックプラスを使っている女性にもメビウス クリア・ミントはメンソールらしいミントの爽やかな味が人気だ。
#
# プルームテックプラス専用フレーバーの味に迷ったらまずコレにしておけば間違いない！
#
# 2番目に美味しいと感じたフレーバーの味はメビウス ロースト・ブレンド（レギュラー）
#
#
#
# これがプルームテックプラス専用たばこカプセルの中で2番目に美味しいと感じたメビウス「ロースト・ブレンド」は、レギュラータイプで香ばしさと奥深いコクが味わいのたばこカプセルだ。
#
#
#
# メビウス ロースト・ブレンドはレギュラータイプの専用タバコカプセルで、メンソールとは違いタバコ本来のガツンとくる香ばしさと味わい深さが特長で、4種類の中で1番タバコの味が感じれた。
#
# ローストというだけあって炙った（あぶった）ような味わいがブレンドされた専用タバコカプセルだ。
#
# メンソールが苦手な人に一番おすすめしたい味だ。
#
# 3番目に美味しいと感じたフレーバーの味はメビウス マイルド・ブレンド（レギュラー）
#
#
#
# 3番目に美味しいと感じたのは、メビウス マイルド・ブレンド フォー プルーム・テック・プラス（レギュラー）だった。
#
#
#
# メビウス マイルド・ブレンドの味をレビューすると、香ばしさに優しさをプラスしたような味わいで少しお茶系（緑茶）の味するのが特長でフルーティーなフレーバーだ。
#
# 低温加熱 PloomTECH ＋専用たばこカプセルのメンソールとレギュラーの中間の味が味わえるというのが僕の感想です。
#
# 例えるならレギュラー50 × メンソール50といった感じのたばこカプセルなので、ミントのメンソールとブレンドのレギュラーをいいとこ取りしたい人におすすめのプルームテックプラス専用のたばこカプセル。
#
# メンソールとレギュラー両方の感じが欲しい人には1番おすすめの味な気がする。
#
# 4番目に美味しいと感じたフレーバーの味はメビウス コールド・ミント（メンソール）
#
#
#
# 4番目に美味しいと感じたのは、メンソールタイプのメビウス コールド・ミントだった。清涼感たっぷりな味が特長だ。
#
#
#
# メビウス コールド・ミントはメンソールタイプのたばこカプセルで、名前から味がイメージできる冷たいメンソールの味わいを堪能できるプルームテックプラス専用のタバコカプセルだ。
#
# 新しくなった PloomTECH + の特長でもあるキック感が苦手な人におすすめのメンソールフレーバーという感じで、プルームテックプラスのたばこカプセル4つの中で一番キック感が少なかった。
#
# 今までのプルームテックに近い吸い心地を味わうならメビウス コールド・ミント フォー プルーム・テック・プラスがおすすめだ。
#
# 【吸いごたえ】味とキック感の満足度をプラスする吸い方
#
#
#
# プルームテックプラスのたばこカプセルの味とキック感の満足度をプラスする吸い方を詳しく紹介します。
#
# どうするかと言うと、マウスピースを使うことでプルームテックプラスのたばこカプセルの味とキック感の満足度をプラスすることができるのでおすすめだ。
#
# マウスピースを本体の先端に装着するだけで吸いごたえアップ
#
# メビウス ロースト・ブレンド フォー プルーム・テック・プラスにマウスピースを使ったところ
#
# プルームテックプラスの吸いごたえをアップさせるマウスピースを使った「たばこカプセルの味」も気になるところですよね？
#
# マウスピースをプルームテックプラスの本体の先端に装着して吸うだけで驚くくらいにタバコカプセルの吸いごたえがアップします。さらに、マウスピースを使うとたばこカプセルの味にも変化があった。
#
#  マウスピースを使って美味しかったタバコカプセルの味
#
#
#
#
# 	メビウス ロースト・ブレンド フォー プルーム・テック・プラス（レギュラー）
# 	メビウス マイルド・ブレンド プルーム・テック・プラス（レギュラー）
# 	メビウス コールド・ミント フォー プルーム・テック・プラス（メンソール）
# 	メビウス クリア・ミント フォー プルーム・テック・プラス（メンソール）
#
#
#
#
# このような結果になりました。
#
# シンプルに吸いごたえがアップして、マウスピースを使わなかった時とまるで違った味の好みになりました。
#
# もともと、プルームテックプラス自体に吸いごたえがアップしているので、ガッツリくる味が好みではなない人はそのまま吸うのがいいと思います。
#
# 逆にフレーバーにより刺激がほしい人は使ってみることをおすすめします。僕はマウスピースありが好みの味でした。
#
# 累計77万個以上売れた人気アクセサリーは伊達ではないといった感じだ。
#
#
#
#  累計77万個以上売れたマウスピースの記事もよく読まれています。
#
# 関連記事累計77万個以上売れたマウスピースでプルームテックプラスの吸いごたえがアップする？！【吸口も清潔になる】
#
#
#
#
# 【味の違い】プルームテックプラスとプルームテックのたばこカプセルのフレーバー
#
# プルームテックとプルームテックプラスのたばこカプセルの味の違いを先に言うと大きな違いは2つある。
#
#  プルームテック・プラスを味で選ぶ場合
#
#
#
#
# 	フルール系など豊富な種類の味を楽しみたい人はプルームテック
# 	たばこカプセルの味にタバコ感を求める人はプルームテックプラス
#
#
#
#
# という感じだ。プルームテックプラスは発売したばかりなので味の種類はスタンダードな4種類しか今はない。
#
# 味の種類で選ぶならプルームテックで、味にタバコ感（吸った感じ）を求めるならプルームテックプラスといった感じだ。詳しくみていこう。
#
#  プルームテックプラスとプルームテックのたばこカプセル味の比較表
#
#
#
#
#
# プルームテックプラス
# プルームテック
#
#
# 味の種類
# 4種類の味がある
# 10種類の味がある
#
#
# 味のキック感
# ◎
# △
#
#
#
#
# プルームテックとプルームテックプラスのたばこカプセルの味を比較表にするとこんな感じだ。実際にどんな味があるのか？をみていこう。
#
# [caption id="attachment_4973" align="aligncenter" width="980"] 旧型プルームテックのたばこカプセル（メンソール）[/caption]
#
# これが旧型プルームテックのたばこカプセルだ。味は低温加熱30℃なのでキック感が物足りないが種類は豊富。
#
#  プルームテックの味の種類
#
#
#
#
# 	メビウス・レギュラー・フォー・プルーム・テック
# 	メビウス・メンソール・フォー・プルーム・テック
# 	メビウス・パープル・クーラー・フォー・プルーム・テック
# 	メビウス・レッド・クーラー・フォー・プルーム・テック
# 	メビウス・ブラウン・アロマ・フォー・プルーム・テック
# 	メビウス・ミックス・グリーン・クーラー・フォー・プルーム・テック
# 	ピアニッシモ・ストロベリー・マンゴー・ピンク・クーラー・フォー・プルーム・テック
# 	ピアニッシモ・レモンティー・ゴールド・アロマ・フォー・プルーム・テック
# 	ピアニッシモ・アリア・メンソール・フォー・プルーム・テック
# 	ピアニッシモ・パイナップル・ピーチ・イエロー・クーラー・フォー・プルーム・テック
#
#
#
#
# プルームテックのたばこカプセルの味の種類は10タイプある。
#
# 新型プルームテックプラスのたばこカプセル（メンソール）
#
# これが新型プルームテックプラスのたばこカプセルだ。味は40℃加熱になったことでキック感が増したので旧型プルームテックよりも満足度が高いが、発売したばかりなので味の種類は少ない。
#
#  プルームテックプラスの味の種類
#
#
#
#
# 	メビウス ロースト・ブレンド フォー プルーム・テック・プラス
# 	メビウス マイルド・ブレンド プルーム・テック・プラス
# 	メビウス コールド・ミント フォー プルーム・テック・プラス
# 	メビウス クリア・ミント フォー プルーム・テック・プラス
#
#
#
#
# プルームテックプラスのたばこカプセルの味の種類は4タイプある。
#
# 今は、プルームテックプラスの方が味の種類は少ないけど今後味は増えてくると思うので僕的には、本体・味の満足度が高いプルームテックプラスを選んでおけば間違いないと感じている。
#
# 10℃とはいえキック感がかなり増しているのでタバコ感を感じるのが嫌な人はプルームテックを使うのがいいと思う。ちなみに以下の記事で旧型プルームテックの本体や味については詳しく紹介しているので参考にしてみてほしい。
#
# 関連記事【プルームテックの使い方】他の電子タバコとの違いや味、吸ってみた感想をレビュー
#
# 【まとめ】プルームテックプラスのたばこカプセル全4種類のフレーバーの味
#
# 最後に【プルームテックプラス】新型たばこカプセル4種類を全部吸ってみた【味の比較】の記事をまとめると
#
#
#
#
# 	メンソール好きならクリア・ミントの味がおすすめ
# 	タバコ感を感じたいならガツンと香ばしいロースト・ブレンドの味がおすすめ
# 	両方をいいとこ取りしたいならマイルド・ブレンドの味がおすすめ
#
#
#
#
# という感じ。
#
# 2019年4月から首都圏のコンビニでプルームテックプラス専用たばこカプセルが販売されるまでは、プルームテック直営店・オンラインショップで購入可能だ。
#
# 2019年4月1日から首都圏のコンビニでプルームテックプラスのたばこカプセルが購入可能になったので、この機会に旧型に比べて味の満足度が格段にあがったプルームテックプラスを試してみてはどうだろうか。
#
#
#
#  進化したプルームテックプラスのレビュー記事もよく読まれています。
#
# iQOS3・glo2・PloomTECH +を3つ使ってみた結果「プルームテックプラスが1番満足度が高かった」
#
# 関連記事【レビュー】プルームテックプラスの進化に驚き！新型電子タバコ全部試してみた結果
#
#
#
#
# あわせて読みたい
#
#
#
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# 【	記号,括弧開,*,*,*,*,【,【,【
# 吸い	動詞,自立,*,*,五段・ワ行促音便,連用形,吸う,スイ,スイ
# ごたえ	名詞,接尾,一般,*,*,*,ごたえ,ゴタエ,ゴタエ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# アップ	名詞,サ変接続,*,*,*,*,アップ,アップ,アップ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# フレーバー	名詞,一般,*,*,*,*,フレーバー,フレーバー,フレーバー
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# 4	名詞,数,*,*,*,*,4,*,*
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
# 徹底	名詞,サ変接続,*,*,*,*,徹底,テッテイ,テッテイ
# レビュー	名詞,サ変接続,*,*,*,*,レビュー,レビュー,レビュー
# 】	記号,括弧閉,*,*,*,*,】,】,】
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 今	接頭詞,名詞接続,*,*,*,*,今,コン,コン
# 話題	名詞,一般,*,*,*,*,話題,ワダイ,ワダイ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 低温	名詞,一般,*,*,*,*,低温,テイオン,テイオン
# 加熱	名詞,サ変接続,*,*,*,*,加熱,カネツ,カネツ
# 型	名詞,接尾,一般,*,*,*,型,ガタ,ガタ
# 電子	名詞,一般,*,*,*,*,電子,デンシ,デンシ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# 専用	名詞,サ変接続,*,*,*,*,専用,センヨウ,センヨー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 気	名詞,一般,*,*,*,*,気,キ,キ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なる	動詞,自立,*,*,五段・ラ行,基本形,なる,ナル,ナル
# 。	記号,句点,*,*,*,*,。,。,。
# 「	記号,括弧開,*,*,*,*,「,「,「
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# どんな	連体詞,*,*,*,*,*,どんな,ドンナ,ドンナ
# フレーバー	名詞,一般,*,*,*,*,フレーバー,フレーバー,フレーバー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# ある	動詞,自立,*,*,五段・ラ行,基本形,ある,アル,アル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# 知り	動詞,自立,*,*,五段・ラ行,連用形,知る,シリ,シリ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# …	記号,一般,*,*,*,*,…,…,…
#  	記号,空白,*,*,*,*, ,*,*
# どうせ	副詞,一般,*,*,*,*,どうせ,ドウセ,ドーセ
# なら	助動詞,*,*,*,特殊・ダ,仮定形,だ,ナラ,ナラ
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 詳しく	形容詞,自立,*,*,形容詞・イ段,連用テ接続,詳しい,クワシク,クワシク
# 教え	動詞,自立,*,*,一段,連用形,教える,オシエ,オシエ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ほしい	形容詞,非自立,*,*,形容詞・イ段,基本形,ほしい,ホシイ,ホシイ
# 」	記号,括弧閉,*,*,*,*,」,」,」
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# そんな	連体詞,*,*,*,*,*,そんな,ソンナ,ソンナ
# 疑問	名詞,形容動詞語幹,*,*,*,*,疑問,ギモン,ギモン
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# 答え	動詞,自立,*,*,一段,連用形,答える,コタエ,コタエ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# ちなみに	接続詞,*,*,*,*,*,ちなみに,チナミニ,チナミニ
# 、	記号,読点,*,*,*,*,、,、,、
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 2	名詞,数,*,*,*,*,2,*,*
# 種	名詞,接尾,助数詞,*,*,*,種,シュ,シュ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# 、	記号,読点,*,*,*,*,、,、,、
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 2	名詞,数,*,*,*,*,2,*,*
# 種	名詞,接尾,助数詞,*,*,*,種,シュ,シュ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# 、	記号,読点,*,*,*,*,、,、,、
# 合計	名詞,サ変接続,*,*,*,*,合計,ゴウケイ,ゴーケイ
# 4	名詞,数,*,*,*,*,4,*,*
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# フレーバー	名詞,一般,*,*,*,*,フレーバー,フレーバー,フレーバー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# あり	動詞,自立,*,*,五段・ラ行,連用形,ある,アリ,アリ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 以前	名詞,副詞可能,*,*,*,*,以前,イゼン,イゼン
# 『	記号,括弧開,*,*,*,*,『,『,『
# 【	記号,括弧開,*,*,*,*,【,【,【
# レビュー	名詞,サ変接続,*,*,*,*,レビュー,レビュー,レビュー
# 】	記号,括弧閉,*,*,*,*,】,】,】
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 進化	名詞,サ変接続,*,*,*,*,進化,シンカ,シンカ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 驚き	動詞,自立,*,*,五段・カ行イ音便,連用形,驚く,オドロキ,オドロキ
# ！	記号,一般,*,*,*,*,！,！,！
# 新型	名詞,一般,*,*,*,*,新型,シンガタ,シンガタ
# 電子	名詞,一般,*,*,*,*,電子,デンシ,デンシ
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# 全部	名詞,副詞可能,*,*,*,*,全部,ゼンブ,ゼンブ
# 試し	動詞,自立,*,*,五段・サ行,連用形,試す,タメシ,タメシ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 結果	名詞,副詞可能,*,*,*,*,結果,ケッカ,ケッカ
# 』	記号,括弧閉,*,*,*,*,』,』,』
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 記事	名詞,一般,*,*,*,*,記事,キジ,キジ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 書い	動詞,自立,*,*,五段・カ行イ音便,連用タ接続,書く,カイ,カイ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# 進化	名詞,サ変接続,*,*,*,*,進化,シンカ,シンカ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# （	記号,括弧開,*,*,*,*,（,（,（
# キック	名詞,サ変接続,*,*,*,*,キック,キック,キック
# 感	名詞,接尾,一般,*,*,*,感,カン,カン
# ）	記号,括弧閉,*,*,*,*,）,）,）
# ・	記号,一般,*,*,*,*,・,・,・
# デザイン	名詞,サ変接続,*,*,*,*,デザイン,デザイン,デザイン
# ・	記号,一般,*,*,*,*,・,・,・
# 使い勝手	名詞,一般,*,*,*,*,使い勝手,ツカイガッテ,ツカイガッテ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 進化	名詞,サ変接続,*,*,*,*,進化,シンカ,シンカ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# たまらなく	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,たまらない,タマラナク,タマラナク
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# この	連体詞,*,*,*,*,*,この,コノ,コノ
# 記事	名詞,一般,*,*,*,*,記事,キジ,キジ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# 4	名詞,数,*,*,*,*,4,*,*
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 比較	名詞,サ変接続,*,*,*,*,比較,ヒカク,ヒカク
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# 旧型	名詞,一般,*,*,*,*,旧型,キュウガタ,キューガタ
# プルームテック	名詞,一般,*,*,*,*,プルームテック,*,*
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 比べ	動詞,自立,*,*,一段,連用形,比べる,クラベ,クラベ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# どう	副詞,助詞類接続,*,*,*,*,どう,ドウ,ドー
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# ？	記号,一般,*,*,*,*,？,？,？
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 比較	名詞,サ変接続,*,*,*,*,比較,ヒカク,ヒカク
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# い	動詞,非自立,*,*,一段,連用形,いる,イ,イ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# 買っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,買う,カッ,カッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# ん	名詞,非自立,一般,*,*,*,ん,ン,ン
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# 、	記号,読点,*,*,*,*,、,、,、
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# コンビニ	名詞,一般,*,*,*,*,コンビニ,コンビニ,コンビニ
# 売っ	動詞,自立,*,*,五段・ラ行,連用タ接続,売る,ウッ,ウッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# なく	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,ない,ナク,ナク
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 吸え	動詞,自立,*,*,一段,未然形,吸える,スエ,スエ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# …	記号,一般,*,*,*,*,…,…,…
# なに	名詞,代名詞,一般,*,*,*,なに,ナニ,ナニ
# これ	名詞,代名詞,一般,*,*,*,これ,コレ,コレ
# ！	記号,一般,*,*,*,*,！,！,！
# 笑	名詞,固有名詞,人名,名,*,*,笑,エミ,エミ
# #	名詞,サ変接続,*,*,*,*,#,*,*
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
#  	記号,空白,*,*,*,*, ,*,*
# #	名詞,サ変接続,*,*,*,*,#,*,*
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
#  	記号,空白,*,*,*,*, ,*,*
# pic	名詞,固有名詞,組織,*,*,*,pic,*,*
# .	名詞,サ変接続,*,*,*,*,.,*,*
# twitter	名詞,一般,*,*,*,*,twitter,*,*
# .	名詞,サ変接続,*,*,*,*,.,*,*
# com	名詞,一般,*,*,*,*,com,*,*
# /	名詞,サ変接続,*,*,*,*,/,*,*
# qwtPYgpnec	名詞,一般,*,*,*,*,qwtPYgpnec,*,*
# &	名詞,サ変接続,*,*,*,*,&,*,*
# mdash	名詞,一般,*,*,*,*,mdash,*,*
# ;	名詞,サ変接続,*,*,*,*,;,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ヨッシー	名詞,一般,*,*,*,*,ヨッシー,*,*
#  	記号,空白,*,*,*,*, ,*,*
# /	名詞,サ変接続,*,*,*,*,/,*,*
#  	記号,空白,*,*,*,*, ,*,*
# RESKY	名詞,固有名詞,組織,*,*,*,RESKY,*,*
# .	名詞,サ変接続,*,*,*,*,.,*,*
#  	記号,空白,*,*,*,*, ,*,*
# (@	名詞,サ変接続,*,*,*,*,(@,*,*
# reskysk	名詞,一般,*,*,*,*,reskysk,*,*
# 8	名詞,数,*,*,*,*,8,*,*
# boarder	名詞,一般,*,*,*,*,boarder,*,*
# )	名詞,サ変接続,*,*,*,*,),*,*
#  	記号,空白,*,*,*,*, ,*,*
# February	名詞,固有名詞,組織,*,*,*,February,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 17	名詞,数,*,*,*,*,17,*,*
# ,	名詞,サ変接続,*,*,*,*,,,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 2019	名詞,数,*,*,*,*,2019,*,*
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# ツイート	名詞,一般,*,*,*,*,ツイート,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# 、	記号,読点,*,*,*,*,、,、,、
# 現在	名詞,副詞可能,*,*,*,*,現在,ゲンザイ,ゲンザイ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# コンビニ	名詞,一般,*,*,*,*,コンビニ,コンビニ,コンビニ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 購入	名詞,サ変接続,*,*,*,*,購入,コウニュウ,コーニュー
# でき	動詞,自立,*,*,一段,未然形,できる,デキ,デキ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# …	記号,一般,*,*,*,*,…,…,…
#  	記号,空白,*,*,*,*, ,*,*
# プルームテック	名詞,一般,*,*,*,*,プルームテック,*,*
# 直営店	名詞,一般,*,*,*,*,直営店,チョクエイテン,チョクエイテン
# のみ	助詞,副助詞,*,*,*,*,のみ,ノミ,ノミ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 買う	動詞,自立,*,*,五段・ワ行促音便,基本形,買う,カウ,カウ
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# できる	動詞,自立,*,*,一段,基本形,できる,デキル,デキル
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 2019	名詞,数,*,*,*,*,2019,*,*
# 年	名詞,接尾,助数詞,*,*,*,年,ネン,ネン
# 4	名詞,数,*,*,*,*,4,*,*
# 月	名詞,一般,*,*,*,*,月,ツキ,ツキ
# 1	名詞,数,*,*,*,*,1,*,*
# 日	名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# 首都	名詞,一般,*,*,*,*,首都,シュト,シュト
# 圏	名詞,接尾,一般,*,*,*,圏,ケン,ケン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# コンビニ	名詞,一般,*,*,*,*,コンビニ,コンビニ,コンビニ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 購入	名詞,サ変接続,*,*,*,*,購入,コウニュウ,コーニュー
# できる	動詞,自立,*,*,一段,基本形,できる,デキル,デキル
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# まし	助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 低温	名詞,一般,*,*,*,*,低温,テイオン,テイオン
# 加熱	名詞,サ変接続,*,*,*,*,加熱,カネツ,カネツ
# や	助詞,並立助詞,*,*,*,*,や,ヤ,ヤ
# 高温	名詞,一般,*,*,*,*,高温,コウオン,コーオン
# 加熱	名詞,サ変接続,*,*,*,*,加熱,カネツ,カネツ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 電子	名詞,一般,*,*,*,*,電子,デンシ,デンシ
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 全て	名詞,副詞可能,*,*,*,*,全て,スベテ,スベテ
# 試し	動詞,自立,*,*,五段・サ行,連用形,試す,タメシ,タメシ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 僕	名詞,代名詞,一般,*,*,*,僕,ボク,ボク
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 今	名詞,副詞可能,*,*,*,*,今,イマ,イマ
# 1	名詞,数,*,*,*,*,1,*,*
# 番	名詞,接尾,助数詞,*,*,*,番,バン,バン
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 感じ	動詞,自立,*,*,一段,連用形,感じる,カンジ,カンジ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 低温	名詞,一般,*,*,*,*,低温,テイオン,テイオン
# 加熱	名詞,サ変接続,*,*,*,*,加熱,カネツ,カネツ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# （	記号,括弧開,*,*,*,*,（,（,（
# PloomTECH	名詞,固有名詞,組織,*,*,*,PloomTECH,*,*
#  	記号,空白,*,*,*,*, ,*,*
# +）	名詞,サ変接続,*,*,*,*,+）,*,*
# 専用	名詞,サ変接続,*,*,*,*,専用,センヨウ,センヨー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# レギュラー・メンソール	名詞,一般,*,*,*,*,レギュラー・メンソール,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 2	名詞,数,*,*,*,*,2,*,*
# タイプ	名詞,一般,*,*,*,*,タイプ,タイプ,タイプ
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# 4	名詞,数,*,*,*,*,4,*,*
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 全部	名詞,副詞可能,*,*,*,*,全部,ゼンブ,ゼンブ
# 買っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,買う,カッ,カッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 吸っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,吸う,スッ,スッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# 徹底	名詞,サ変接続,*,*,*,*,徹底,テッテイ,テッテイ
# 解説	名詞,サ変接続,*,*,*,*,解説,カイセツ,カイセツ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# ながら	助詞,接続助詞,*,*,*,*,ながら,ナガラ,ナガラ
# レビュー	名詞,サ変接続,*,*,*,*,レビュー,レビュー,レビュー
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 思う	動詞,自立,*,*,五段・ワ行促音便,基本形,思う,オモウ,オモウ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# プルームテックプラス	名詞,固有名詞,一般,*,*,*,プルームテックプラス,*,*
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# 】	記号,括弧閉,*,*,*,*,】,】,】
# フレーバー	名詞,一般,*,*,*,*,フレーバー,フレーバー,フレーバー
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# 4	名詞,数,*,*,*,*,4,*,*
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
# ,*,*
# これ	名詞,代名詞,一般,*,*,*,これ,コレ,コレ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 必要	名詞,形容動詞語幹,*,*,*,*,必要,ヒツヨウ,ヒツヨー
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
#  	記号,空白,*,*,*,*, ,*,*
# MEVIUS	名詞,固有名詞,組織,*,*,*,MEVIUS,*,*
#  	記号,空白,*,*,*,*, ,*,*
# for	名詞,固有名詞,組織,*,*,*,for,*,*
#  	記号,空白,*,*,*,*, ,*,*
# Ploom	名詞,固有名詞,組織,*,*,*,Ploom,*,*
#  	記号,空白,*,*,*,*, ,*,*
# TECH	名詞,固有名詞,組織,*,*,*,TECH,*,*
#  	記号,空白,*,*,*,*, ,*,*
# として	助詞,格助詞,連語,*,*,*,として,トシテ,トシテ
# 販売	名詞,サ変接続,*,*,*,*,販売,ハンバイ,ハンバイ
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# 専用	名詞,サ変接続,*,*,*,*,専用,センヨウ,センヨー
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# 4	名詞,数,*,*,*,*,4,*,*
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 左	名詞,一般,*,*,*,*,左,ヒダリ,ヒダリ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# 専用	名詞,サ変接続,*,*,*,*,専用,センヨウ,センヨー
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# フレーバー	名詞,一般,*,*,*,*,フレーバー,フレーバー,フレーバー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 銘柄	名詞,一般,*,*,*,*,銘柄,メイガラ,メイガラ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 説明	名詞,サ変接続,*,*,*,*,説明,セツメイ,セツメイ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
#
#
#
#
#
# 		記号,空白,*,*,*,*,
#
#
#
#
# 	,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# 】	記号,括弧閉,*,*,*,*,】,】,】
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# ロースト	名詞,一般,*,*,*,*,ロースト,ロースト,ロースト
# ・	記号,一般,*,*,*,*,・,・,・
# ブレンド	名詞,サ変接続,*,*,*,*,ブレンド,ブレンド,ブレンド
#  	記号,空白,*,*,*,*, ,*,*
# フォー	名詞,一般,*,*,*,*,フォー,*,*
#  	記号,空白,*,*,*,*, ,*,*
# プルーム・テック・プラス	名詞,一般,*,*,*,*,プルーム・テック・プラス,*,*
#
# 		記号,空白,*,*,*,*,
# 	,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# 】	記号,括弧閉,*,*,*,*,】,】,】
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# マイルド・ブレンド	名詞,一般,*,*,*,*,マイルド・ブレンド,*,*
#  	記号,空白,*,*,*,*, ,*,*
# プルーム・テック・プラス	名詞,一般,*,*,*,*,プルーム・テック・プラス,*,*
#
# 		記号,空白,*,*,*,*,
# 	,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# メンソール	名詞,固有名詞,一般,*,*,*,メンソール,*,*
# 】	記号,括弧閉,*,*,*,*,】,】,】
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# コールド	名詞,一般,*,*,*,*,コールド,コールド,コールド
# ・	記号,一般,*,*,*,*,・,・,・
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
#  	記号,空白,*,*,*,*, ,*,*
# フォー	名詞,一般,*,*,*,*,フォー,*,*
#  	記号,空白,*,*,*,*, ,*,*
# プルーム・テック・プラス	名詞,一般,*,*,*,*,プルーム・テック・プラス,*,*
#
# 		記号,空白,*,*,*,*,
# 	,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# メンソール	名詞,固有名詞,一般,*,*,*,メンソール,*,*
# 】	記号,括弧閉,*,*,*,*,】,】,】
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# クリア	名詞,サ変接続,*,*,*,*,クリア,クリア,クリア
# ・	記号,一般,*,*,*,*,・,・,・
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
#  	記号,空白,*,*,*,*, ,*,*
# フォー	名詞,一般,*,*,*,*,フォー,*,*
#  	記号,空白,*,*,*,*, ,*,*
# プルーム・テック・プラス	名詞,一般,*,*,*,*,プルーム・テック・プラス,*,*
#
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
#
# ,*,*
# 左	名詞,一般,*,*,*,*,左,ヒダリ,ヒダリ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 2	名詞,数,*,*,*,*,2,*,*
# つ	助動詞,*,*,*,下二・タ行,基本形,つ,ツ,ツ
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# タイプ	名詞,一般,*,*,*,*,タイプ,タイプ,タイプ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# 右	名詞,一般,*,*,*,*,右,ミギ,ミギ
# 2	名詞,数,*,*,*,*,2,*,*
# つ	助動詞,*,*,*,下二・タ行,基本形,つ,ツ,ツ
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# メンソールタイプ	名詞,一般,*,*,*,*,メンソールタイプ,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# 好き	名詞,接尾,形容動詞語幹,*,*,*,好き,スキ,スキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# ？	記号,一般,*,*,*,*,？,？,？
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# 好き	名詞,接尾,形容動詞語幹,*,*,*,好き,スキ,スキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# ？	記号,一般,*,*,*,*,？,？,？
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 選べ	動詞,自立,*,*,五段・バ行,仮定形,選ぶ,エラベ,エラベ
# ば	助詞,接続助詞,*,*,*,*,ば,バ,バ
# 選択肢	名詞,一般,*,*,*,*,選択肢,センタクシ,センタクシ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 狭まり	動詞,自立,*,*,五段・ラ行,連用形,狭まる,セバマリ,セバマリ
# 好み	名詞,一般,*,*,*,*,好み,コノミ,コノミ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 見つけ	動詞,自立,*,*,一段,連用形,見つける,ミツケ,ミツケ
# やすい	形容詞,非自立,*,*,形容詞・アウオ段,基本形,やすい,ヤスイ,ヤスイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# ね	助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 以下	名詞,非自立,副詞可能,*,*,*,以下,イカ,イカ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 、	記号,読点,*,*,*,*,、,、,、
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# 4	名詞,数,*,*,*,*,4,*,*
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 一覧	名詞,サ変接続,*,*,*,*,一覧,イチラン,イチラン
# 表	名詞,接尾,一般,*,*,*,表,ヒョウ,ヒョー
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# 吸っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,吸う,スッ,スッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 比較	名詞,サ変接続,*,*,*,*,比較,ヒカク,ヒカク
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 参考	名詞,サ変接続,*,*,*,*,参考,サンコウ,サンコー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 載せ	動詞,自立,*,*,一段,連用形,載せる,ノセ,ノセ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# おき	動詞,非自立,*,*,五段・カ行イ音便,連用形,おく,オキ,オキ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
#  	記号,空白,*,*,*,*,
#
#  ,*,*
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 比較	名詞,サ変接続,*,*,*,*,比較,ヒカク,ヒカク
# 表	名詞,接尾,一般,*,*,*,表,ヒョウ,ヒョー
#
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
#
# ,*,*
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# クリア	名詞,サ変接続,*,*,*,*,クリア,クリア,クリア
# ・	記号,一般,*,*,*,*,・,・,・
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
#
# 	記号,空白,*,*,*,*,
# ,*,*
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# コールド	名詞,一般,*,*,*,*,コールド,コールド,コールド
# ・	記号,一般,*,*,*,*,・,・,・
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
#
# 	記号,空白,*,*,*,*,
# ,*,*
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# ロースト	名詞,一般,*,*,*,*,ロースト,ロースト,ロースト
# ・	記号,一般,*,*,*,*,・,・,・
# ブレンド	名詞,サ変接続,*,*,*,*,ブレンド,ブレンド,ブレンド
#
# 	記号,空白,*,*,*,*,
# ,*,*
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# マイルド・ブレンド	名詞,一般,*,*,*,*,マイルド・ブレンド,*,*
#
#
#
# 	記号,空白,*,*,*,*,
#
#
# ,*,*
# ◎	記号,一般,*,*,*,*,◎,◎,◎
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ×	記号,一般,*,*,*,*,×,カケル,カケル
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ○	記号,一般,*,*,*,*,○,○,○
#
# 	記号,空白,*,*,*,*,
# ,*,*
# △	記号,一般,*,*,*,*,△,△,△
#
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
#
# ,*,*
# 上記	名詞,一般,*,*,*,*,上記,ジョウキ,ジョーキ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# フレーバー	名詞,一般,*,*,*,*,フレーバー,フレーバー,フレーバー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# 比較	名詞,サ変接続,*,*,*,*,比較,ヒカク,ヒカク
# 表	名詞,接尾,一般,*,*,*,表,ヒョウ,ヒョー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 書い	動詞,自立,*,*,五段・カ行イ音便,連用タ接続,書く,カイ,カイ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ある	動詞,非自立,*,*,五段・ラ行,基本形,ある,アル,アル
# とおり	名詞,非自立,副詞可能,*,*,*,とおり,トオリ,トーリ
# 、	記号,読点,*,*,*,*,、,、,、
# 僕	名詞,代名詞,一般,*,*,*,僕,ボク,ボク
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# 専用	名詞,サ変接続,*,*,*,*,専用,センヨウ,センヨー
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# メンソールフレーバー	名詞,一般,*,*,*,*,メンソールフレーバー,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# 1	名詞,数,*,*,*,*,1,*,*
# 番	名詞,接尾,助数詞,*,*,*,番,バン,バン
# 吸い	動詞,自立,*,*,五段・ワ行促音便,連用形,吸う,スイ,スイ
# ごたえ	名詞,接尾,一般,*,*,*,ごたえ,ゴタエ,ゴタエ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# あっ	動詞,自立,*,*,五段・ラ行,連用タ接続,ある,アッ,アッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 美味しい	形容詞,自立,*,*,形容詞・イ段,基本形,美味しい,オイシイ,オイシイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 感じ	動詞,自立,*,*,一段,連用形,感じる,カンジ,カンジ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# クリア	名詞,サ変接続,*,*,*,*,クリア,クリア,クリア
# ・	記号,一般,*,*,*,*,・,・,・
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# フレーバー	名詞,一般,*,*,*,*,フレーバー,フレーバー,フレーバー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# ロースト	名詞,一般,*,*,*,*,ロースト,ロースト,ロースト
# ・	記号,一般,*,*,*,*,・,・,・
# ブレンド	名詞,サ変接続,*,*,*,*,ブレンド,ブレンド,ブレンド
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# キック	名詞,サ変接続,*,*,*,*,キック,キック,キック
# 感	名詞,接尾,一般,*,*,*,感,カン,カン
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# あり	動詞,自立,*,*,五段・ラ行,連用形,ある,アリ,アリ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# らしい	助動詞,*,*,*,形容詞・イ段,基本形,らしい,ラシイ,ラシイ
# 刺激	名詞,サ変接続,*,*,*,*,刺激,シゲキ,シゲキ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 感じ	動詞,自立,*,*,一段,未然形,感じる,カンジ,カンジ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 新しく	形容詞,自立,*,*,形容詞・イ段,連用テ接続,新しい,アタラシク,アタラシク
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# 4	名詞,数,*,*,*,*,4,*,*
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# 各	接頭詞,名詞接続,*,*,*,*,各,カク,カク
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# 5	名詞,数,*,*,*,*,5,*,*
# 個	名詞,接尾,助数詞,*,*,*,個,コ,コ
# 入	名詞,固有名詞,地域,一般,*,*,入,イリ,イリ
# 、	記号,読点,*,*,*,*,、,、,、
# カートリッジ	名詞,一般,*,*,*,*,カートリッジ,カートリッジ,カートリッジ
# 1	名詞,数,*,*,*,*,1,*,*
# 個	名詞,接尾,助数詞,*,*,*,個,コ,コ
# 入り	名詞,接尾,サ変接続,*,*,*,入り,イリ,イリ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 500	名詞,数,*,*,*,*,500,*,*
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
# （	記号,括弧開,*,*,*,*,（,（,（
# 税込	名詞,一般,*,*,*,*,税込,ゼイコミ,ゼイコミ
# ）	記号,括弧閉,*,*,*,*,）,）,）
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
#  	記号,空白,*,*,*,*,
#
#  ,*,*
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# クリア	名詞,サ変接続,*,*,*,*,クリア,クリア,クリア
# ・	記号,一般,*,*,*,*,・,・,・
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
#  	記号,空白,*,*,*,*, ,*,*
# フォー	名詞,一般,*,*,*,*,フォー,*,*
#  	記号,空白,*,*,*,*, ,*,*
# プルーム・テック・プラス	名詞,一般,*,*,*,*,プルーム・テック・プラス,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 開封	名詞,サ変接続,*,*,*,*,開封,カイフウ,カイフー
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# ところ	名詞,非自立,副詞可能,*,*,*,ところ,トコロ,トコロ
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# ちなみに	接続詞,*,*,*,*,*,ちなみに,チナミニ,チナミニ
# 、	記号,読点,*,*,*,*,、,、,、
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 開封	名詞,サ変接続,*,*,*,*,開封,カイフウ,カイフー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# こんな	連体詞,*,*,*,*,*,こんな,コンナ,コンナ
# 感じ	名詞,一般,*,*,*,*,感じ,カンジ,カンジ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 箱	名詞,一般,*,*,*,*,箱,ハコ,ハコ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 開ける	動詞,自立,*,*,一段,基本形,開ける,アケル,アケル
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# 中	名詞,一般,*,*,*,*,中,ナカ,ナカ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# 5	名詞,数,*,*,*,*,5,*,*
# つと	副詞,一般,*,*,*,*,つと,ツト,ツト
# カートリッジ	名詞,一般,*,*,*,*,カートリッジ,カートリッジ,カートリッジ
# 1	名詞,数,*,*,*,*,1,*,*
# 本	名詞,接尾,助数詞,*,*,*,本,ホン,ホン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 同	接頭詞,名詞接続,*,*,*,*,同,ドウ,ドー
# 梱	名詞,一般,*,*,*,*,梱,コリ,コリ
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# バッテリー	名詞,一般,*,*,*,*,バッテリー,バッテリー,バッテリー
# フル	名詞,形容動詞語幹,*,*,*,*,フル,フル,フル
# 充電	名詞,サ変接続,*,*,*,*,充電,ジュウデン,ジューデン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 状態	名詞,一般,*,*,*,*,状態,ジョウタイ,ジョータイ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# 5	名詞,数,*,*,*,*,5,*,*
# つ	助動詞,*,*,*,下二・タ行,基本形,つ,ツ,ツ
# 分	名詞,接尾,一般,*,*,*,分,ブン,ブン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 吸引	名詞,サ変接続,*,*,*,*,吸引,キュウイン,キューイン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 可能	名詞,形容動詞語幹,*,*,*,*,可能,カノウ,カノー
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
#  	記号,空白,*,*,*,*,
#
#  ,*,*
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 吸える	動詞,自立,*,*,一段,基本形,吸える,スエル,スエル
# 回数	名詞,一般,*,*,*,*,回数,カイスウ,カイスー
#
#
#
#
#
# 		記号,空白,*,*,*,*,
#
#
#
#
# 	,*,*
# カートリッジ	名詞,一般,*,*,*,*,カートリッジ,カートリッジ,カートリッジ
# 1	名詞,数,*,*,*,*,1,*,*
# 本	名詞,接尾,助数詞,*,*,*,本,ホン,ホン
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 250	名詞,数,*,*,*,*,250,*,*
# パフ	名詞,一般,*,*,*,*,パフ,パフ,パフ
#
# 		記号,空白,*,*,*,*,
# 	,*,*
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# 1	名詞,数,*,*,*,*,1,*,*
# 個	名詞,接尾,助数詞,*,*,*,個,コ,コ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 50	名詞,数,*,*,*,*,50,*,*
# パフ	名詞,一般,*,*,*,*,パフ,パフ,パフ
#
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
#
# ,*,*
# 付属	名詞,サ変接続,*,*,*,*,付属,フゾク,フゾク
# カートリッジ	名詞,一般,*,*,*,*,カートリッジ,カートリッジ,カートリッジ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# リキッド	名詞,一般,*,*,*,*,リキッド,*,*
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 呼ば	動詞,自立,*,*,五段・バ行,未然形,呼ぶ,ヨバ,ヨバ
# れる	動詞,接尾,*,*,一段,基本形,れる,レル,レル
# 液体	名詞,一般,*,*,*,*,液体,エキタイ,エキタイ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 充填	名詞,サ変接続,*,*,*,*,充填,ジュウテン,ジューテン
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# い	動詞,非自立,*,*,一段,連用形,いる,イ,イ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# カートリッジ	名詞,一般,*,*,*,*,カートリッジ,カートリッジ,カートリッジ
# 1	名詞,数,*,*,*,*,1,*,*
# 本	名詞,接尾,助数詞,*,*,*,本,ホン,ホン
# につき	助詞,格助詞,連語,*,*,*,につき,ニツキ,ニツキ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# 5	名詞,数,*,*,*,*,5,*,*
# つ	助動詞,*,*,*,下二・タ行,基本形,つ,ツ,ツ
# 分	名詞,接尾,一般,*,*,*,分,ブン,ブン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 蒸気	名詞,一般,*,*,*,*,蒸気,ジョウキ,ジョーキ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 発生	名詞,サ変接続,*,*,*,*,発生,ハッセイ,ハッセイ
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# せる	動詞,接尾,*,*,一段,基本形,せる,セル,セル
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# の	助詞,格助詞,一般,*,*,*,の,ノ,ノ
# できる	動詞,自立,*,*,一段,基本形,できる,デキル,デキル
# リキッド	名詞,一般,*,*,*,*,リキッド,*,*
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 充填	名詞,サ変接続,*,*,*,*,充填,ジュウテン,ジューテン
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# い	動詞,非自立,*,*,一段,連用形,いる,イ,イ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 約	接頭詞,数接続,*,*,*,*,約,ヤク,ヤク
# 50	名詞,数,*,*,*,*,50,*,*
# 回	名詞,接尾,助数詞,*,*,*,回,カイ,カイ
# 吸引	名詞,サ変接続,*,*,*,*,吸引,キュウイン,キューイン
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# バッテリー	名詞,一般,*,*,*,*,バッテリー,バッテリー,バッテリー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 先端	名詞,一般,*,*,*,*,先端,センタン,センタン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 40	名詞,数,*,*,*,*,40,*,*
# 回	名詞,接尾,助数詞,*,*,*,回,カイ,カイ
# 青く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,青い,アオク,アオク
# 点滅	名詞,サ変接続,*,*,*,*,点滅,テンメツ,テンメツ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# 、	記号,読点,*,*,*,*,、,、,、
# その	連体詞,*,*,*,*,*,その,ソノ,ソノ
# 時	名詞,非自立,副詞可能,*,*,*,時,トキ,トキ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# 交換	名詞,サ変接続,*,*,*,*,交換,コウカン,コーカン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 合図	名詞,サ変接続,*,*,*,*,合図,アイズ,アイズ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# カートリッジ	名詞,一般,*,*,*,*,カートリッジ,カートリッジ,カートリッジ
# 1	名詞,数,*,*,*,*,1,*,*
# 本	名詞,接尾,助数詞,*,*,*,本,ホン,ホン
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# 5	名詞,数,*,*,*,*,5,*,*
# 本	名詞,接尾,助数詞,*,*,*,本,ホン,ホン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 吸える	動詞,自立,*,*,一段,基本形,吸える,スエル,スエル
# 。	記号,句点,*,*,*,*,。,。,。
# 全部	名詞,副詞可能,*,*,*,*,全部,ゼンブ,ゼンブ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 250	名詞,数,*,*,*,*,250,*,*
# 回	名詞,接尾,助数詞,*,*,*,回,カイ,カイ
# 吸う	動詞,自立,*,*,五段・ワ行促音便,基本形,吸う,スウ,スウ
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# できる	動詞,自立,*,*,一段,基本形,できる,デキル,デキル
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# それでは	接続詞,*,*,*,*,*,それでは,ソレデハ,ソレデワ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# （	記号,括弧開,*,*,*,*,（,（,（
# フレーバー	名詞,一般,*,*,*,*,フレーバー,フレーバー,フレーバー
# ）	記号,括弧閉,*,*,*,*,）,）,）
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 詳しく	形容詞,自立,*,*,形容詞・イ段,連用テ接続,詳しい,クワシク,クワシク
# 解説	名詞,サ変接続,*,*,*,*,解説,カイセツ,カイセツ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 1	名詞,数,*,*,*,*,1,*,*
# 番目	名詞,接尾,助数詞,*,*,*,番目,バンメ,バンメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 美味しい	形容詞,自立,*,*,形容詞・イ段,基本形,美味しい,オイシイ,オイシイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 感じ	動詞,自立,*,*,一段,連用形,感じる,カンジ,カンジ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# フレーバー	名詞,一般,*,*,*,*,フレーバー,フレーバー,フレーバー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# クリア	名詞,サ変接続,*,*,*,*,クリア,クリア,クリア
# ・	記号,一般,*,*,*,*,・,・,・
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
# （	記号,括弧開,*,*,*,*,（,（,（
# メンソール	名詞,固有名詞,一般,*,*,*,メンソール,*,*
# ）	記号,括弧閉,*,*,*,*,）,）,）
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
# ,*,*
# これ	名詞,代名詞,一般,*,*,*,これ,コレ,コレ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 低温	名詞,一般,*,*,*,*,低温,テイオン,テイオン
# 加熱	名詞,サ変接続,*,*,*,*,加熱,カネツ,カネツ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# 専用	名詞,サ変接続,*,*,*,*,専用,センヨウ,センヨー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# 正規	名詞,一般,*,*,*,*,正規,セイキ,セイキ
# 名称	名詞,一般,*,*,*,*,名称,メイショウ,メイショー
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 「	記号,括弧開,*,*,*,*,「,「,「
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# クリア	名詞,サ変接続,*,*,*,*,クリア,クリア,クリア
# ・	記号,一般,*,*,*,*,・,・,・
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
#  	記号,空白,*,*,*,*, ,*,*
# フォー	名詞,一般,*,*,*,*,フォー,*,*
#  	記号,空白,*,*,*,*, ,*,*
# プルーム・テック・プラス	名詞,一般,*,*,*,*,プルーム・テック・プラス,*,*
# 」	記号,括弧閉,*,*,*,*,」,」,」
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 言う	動詞,自立,*,*,五段・ワ行促音便,基本形,言う,イウ,イウ
# 。	記号,句点,*,*,*,*,。,。,。
# 全て	名詞,副詞可能,*,*,*,*,全て,スベテ,スベテ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
#  	記号,空白,*,*,*,*, ,*,*
# PloomTECH	名詞,固有名詞,組織,*,*,*,PloomTECH,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ＋	記号,一般,*,*,*,*,＋,タス,タス
#  	記号,空白,*,*,*,*, ,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# フォー	名詞,一般,*,*,*,*,フォー,*,*
#  	記号,空白,*,*,*,*, ,*,*
# プルーム・テック・プラス	名詞,一般,*,*,*,*,プルーム・テック・プラス,*,*
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# つく	動詞,自立,*,*,五段・カ行イ音便,基本形,つく,ツク,ツク
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# 専用	名詞,サ変接続,*,*,*,*,専用,センヨウ,センヨー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 中	名詞,非自立,副詞可能,*,*,*,中,ナカ,ナカ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# 1	名詞,数,*,*,*,*,1,*,*
# 番	名詞,接尾,助数詞,*,*,*,番,バン,バン
# 美味しい	形容詞,自立,*,*,形容詞・イ段,基本形,美味しい,オイシイ,オイシイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 感じ	動詞,自立,*,*,一段,連用形,感じる,カンジ,カンジ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# だっ	助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# クリア	名詞,サ変接続,*,*,*,*,クリア,クリア,クリア
# ・	記号,一般,*,*,*,*,・,・,・
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# スタンダード	名詞,形容動詞語幹,*,*,*,*,スタンダード,スタンダード,スタンダード
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# といった	助詞,格助詞,連語,*,*,*,といった,トイッタ,トイッタ
# 感じ	名詞,一般,*,*,*,*,感じ,カンジ,カンジ
# 。	記号,句点,*,*,*,*,。,。,。
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# 感	名詞,接尾,一般,*,*,*,感,カン,カン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 控えめ	名詞,一般,*,*,*,*,控えめ,ヒカエメ,ヒカエメ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# とても	副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ
# 吸い	動詞,自立,*,*,五段・ワ行促音便,連用形,吸う,スイ,スイ
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# 味	名詞,接尾,一般,*,*,*,味,ミ,ミ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# ハッキリ	副詞,助詞類接続,*,*,*,*,ハッキリ,ハッキリ,ハッキリ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 特長	名詞,一般,*,*,*,*,特長,トクチョウ,トクチョー
# 的	名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# 喉	名詞,一般,*,*,*,*,喉,ノド,ノド
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# ガ	名詞,一般,*,*,*,*,ガ,ガ,ガ
# ツン	副詞,助詞類接続,*,*,*,*,ツン,ツン,ツン
# と	助詞,副詞化,*,*,*,*,と,ト,ト
# くる	動詞,自立,*,*,カ変・クル,基本形,くる,クル,クル
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# キック	名詞,サ変接続,*,*,*,*,キック,キック,キック
# 感	名詞,接尾,一般,*,*,*,感,カン,カン
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 感じ	動詞,自立,*,*,一段,未然形,感じる,カンジ,カンジ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 満足	名詞,サ変接続,*,*,*,*,満足,マンゾク,マンゾク
# 度	名詞,接尾,一般,*,*,*,度,ド,ド
# の	助詞,格助詞,一般,*,*,*,の,ノ,ノ
# 高い	形容詞,自立,*,*,形容詞・アウオ段,基本形,高い,タカイ,タカイ
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
# ,*,*
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 40	名詞,数,*,*,*,*,40,*,*
# ℃	名詞,サ変接続,*,*,*,*,℃,*,*
# 加熱	名詞,サ変接続,*,*,*,*,加熱,カネツ,カネツ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# キック	名詞,サ変接続,*,*,*,*,キック,キック,キック
# 感	名詞,接尾,一般,*,*,*,感,カン,カン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 増し	動詞,自立,*,*,五段・サ行,連用形,増す,マシ,マシ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# シンプル	名詞,形容動詞語幹,*,*,*,*,シンプル,シンプル,シンプル
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# 旨い	形容詞,自立,*,*,形容詞・アウオ段,基本形,旨い,ウマイ,ウマイ
# ！	記号,一般,*,*,*,*,！,！,！
# という	助詞,格助詞,連語,*,*,*,という,トイウ,トユウ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# クリアミントフレーバー	名詞,一般,*,*,*,*,クリアミントフレーバー,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 第	接頭詞,数接続,*,*,*,*,第,ダイ,ダイ
# 一	名詞,数,*,*,*,*,一,イチ,イチ
# 印象	名詞,一般,*,*,*,*,印象,インショウ,インショー
# だっ	助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 僕	名詞,代名詞,一般,*,*,*,僕,ボク,ボク
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 周り	名詞,一般,*,*,*,*,周り,マワリ,マワリ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 使っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,使う,ツカッ,ツカッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 女性	名詞,一般,*,*,*,*,女性,ジョセイ,ジョセイ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# クリア	名詞,サ変接続,*,*,*,*,クリア,クリア,クリア
# ・	記号,一般,*,*,*,*,・,・,・
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# らしい	助動詞,*,*,*,形容詞・イ段,基本形,らしい,ラシイ,ラシイ
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 爽やか	名詞,形容動詞語幹,*,*,*,*,爽やか,サワヤカ,サワヤカ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 人気	名詞,一般,*,*,*,*,人気,ニンキ,ニンキ
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# 専用	名詞,サ変接続,*,*,*,*,専用,センヨウ,センヨー
# フレーバー	名詞,一般,*,*,*,*,フレーバー,フレーバー,フレーバー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 迷っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,迷う,マヨッ,マヨッ
# たら	助動詞,*,*,*,特殊・タ,仮定形,た,タラ,タラ
# まず	副詞,一般,*,*,*,*,まず,マズ,マズ
# コレ	名詞,一般,*,*,*,*,コレ,*,*
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# おけ	動詞,非自立,*,*,五段・カ行イ音便,仮定形,おく,オケ,オケ
# ば	助詞,接続助詞,*,*,*,*,ば,バ,バ
# 間違い	名詞,ナイ形容詞語幹,*,*,*,*,間違い,マチガイ,マチガイ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# ！	記号,一般,*,*,*,*,！,！,！
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 2	名詞,数,*,*,*,*,2,*,*
# 番目	名詞,接尾,助数詞,*,*,*,番目,バンメ,バンメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 美味しい	形容詞,自立,*,*,形容詞・イ段,基本形,美味しい,オイシイ,オイシイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 感じ	動詞,自立,*,*,一段,連用形,感じる,カンジ,カンジ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# フレーバー	名詞,一般,*,*,*,*,フレーバー,フレーバー,フレーバー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# ロースト	名詞,一般,*,*,*,*,ロースト,ロースト,ロースト
# ・	記号,一般,*,*,*,*,・,・,・
# ブレンド	名詞,サ変接続,*,*,*,*,ブレンド,ブレンド,ブレンド
# （	記号,括弧開,*,*,*,*,（,（,（
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# ）	記号,括弧閉,*,*,*,*,）,）,）
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
# ,*,*
# これ	名詞,代名詞,一般,*,*,*,これ,コレ,コレ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# 専用	名詞,サ変接続,*,*,*,*,専用,センヨウ,センヨー
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 中	名詞,非自立,副詞可能,*,*,*,中,ナカ,ナカ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 2	名詞,数,*,*,*,*,2,*,*
# 番目	名詞,接尾,助数詞,*,*,*,番目,バンメ,バンメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 美味しい	形容詞,自立,*,*,形容詞・イ段,基本形,美味しい,オイシイ,オイシイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 感じ	動詞,自立,*,*,一段,連用形,感じる,カンジ,カンジ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
# 「	記号,括弧開,*,*,*,*,「,「,「
# ロースト	名詞,一般,*,*,*,*,ロースト,ロースト,ロースト
# ・	記号,一般,*,*,*,*,・,・,・
# ブレンド	名詞,サ変接続,*,*,*,*,ブレンド,ブレンド,ブレンド
# 」	記号,括弧閉,*,*,*,*,」,」,」
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# タイプ	名詞,一般,*,*,*,*,タイプ,タイプ,タイプ
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# 香ばし	形容詞,自立,*,*,形容詞・イ段,ガル接続,香ばしい,コウバシ,コーバシ
# さ	名詞,接尾,特殊,*,*,*,さ,サ,サ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# 奥深い	形容詞,自立,*,*,形容詞・アウオ段,基本形,奥深い,オクフカイ,オクフカイ
# コク	名詞,一般,*,*,*,*,コク,コク,コク
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 味わい	名詞,一般,*,*,*,*,味わい,アジワイ,アジワイ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
# ,*,*
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# ロースト	名詞,一般,*,*,*,*,ロースト,ロースト,ロースト
# ・	記号,一般,*,*,*,*,・,・,・
# ブレンド	名詞,サ変接続,*,*,*,*,ブレンド,ブレンド,ブレンド
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# タイプ	名詞,一般,*,*,*,*,タイプ,タイプ,タイプ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 専用	名詞,サ変接続,*,*,*,*,専用,センヨウ,センヨー
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 違い	動詞,自立,*,*,五段・ワ行促音便,連用形,違う,チガイ,チガイ
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# 本来	名詞,副詞可能,*,*,*,*,本来,ホンライ,ホンライ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# ガ	名詞,一般,*,*,*,*,ガ,ガ,ガ
# ツン	副詞,助詞類接続,*,*,*,*,ツン,ツン,ツン
# と	助詞,副詞化,*,*,*,*,と,ト,ト
# くる	動詞,自立,*,*,カ変・クル,基本形,くる,クル,クル
# 香ばし	形容詞,自立,*,*,形容詞・イ段,ガル接続,香ばしい,コウバシ,コーバシ
# さ	名詞,接尾,特殊,*,*,*,さ,サ,サ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# 味わい深	形容詞,自立,*,*,形容詞・アウオ段,ガル接続,味わい深い,アジワイブカ,アジワイブカ
# さ	名詞,接尾,特殊,*,*,*,さ,サ,サ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 特長	名詞,一般,*,*,*,*,特長,トクチョウ,トクチョー
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# 4	名詞,数,*,*,*,*,4,*,*
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 中	名詞,非自立,副詞可能,*,*,*,中,ナカ,ナカ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 1	名詞,数,*,*,*,*,1,*,*
# 番	名詞,接尾,助数詞,*,*,*,番,バン,バン
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 感じ	動詞,自立,*,*,一段,未然形,感じる,カンジ,カンジ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# ロースト	名詞,一般,*,*,*,*,ロースト,ロースト,ロースト
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# いう	動詞,自立,*,*,五段・ワ行促音便,基本形,いう,イウ,イウ
# だけ	助詞,副助詞,*,*,*,*,だけ,ダケ,ダケ
# あっ	動詞,自立,*,*,五段・ラ行,連用タ接続,ある,アッ,アッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 炙っ	動詞,自立,*,*,五段・ラ行,連用タ接続,炙る,アブッ,アブッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# （	記号,括弧開,*,*,*,*,（,（,（
# あぶっ	動詞,自立,*,*,五段・ラ行,連用タ接続,あぶる,アブッ,アブッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# ）	記号,括弧閉,*,*,*,*,）,）,）
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 味わい	名詞,一般,*,*,*,*,味わい,アジワイ,アジワイ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# ブレンド	名詞,サ変接続,*,*,*,*,ブレンド,ブレンド,ブレンド
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 専用	名詞,サ変接続,*,*,*,*,専用,センヨウ,センヨー
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 苦手	名詞,形容動詞語幹,*,*,*,*,苦手,ニガテ,ニガテ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 一番	名詞,副詞可能,*,*,*,*,一番,イチバン,イチバン
# おすすめ	名詞,サ変接続,*,*,*,*,おすすめ,オススメ,オススメ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 3	名詞,数,*,*,*,*,3,*,*
# 番目	名詞,接尾,助数詞,*,*,*,番目,バンメ,バンメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 美味しい	形容詞,自立,*,*,形容詞・イ段,基本形,美味しい,オイシイ,オイシイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 感じ	動詞,自立,*,*,一段,連用形,感じる,カンジ,カンジ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# フレーバー	名詞,一般,*,*,*,*,フレーバー,フレーバー,フレーバー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# マイルド・ブレンド	名詞,一般,*,*,*,*,マイルド・ブレンド,*,*
# （	記号,括弧開,*,*,*,*,（,（,（
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# ）	記号,括弧閉,*,*,*,*,）,）,）
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
# ,*,*
# 3	名詞,数,*,*,*,*,3,*,*
# 番目	名詞,接尾,助数詞,*,*,*,番目,バンメ,バンメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 美味しい	形容詞,自立,*,*,形容詞・イ段,基本形,美味しい,オイシイ,オイシイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 感じ	動詞,自立,*,*,一段,連用形,感じる,カンジ,カンジ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# マイルド・ブレンド	名詞,一般,*,*,*,*,マイルド・ブレンド,*,*
#  	記号,空白,*,*,*,*, ,*,*
# フォー	名詞,一般,*,*,*,*,フォー,*,*
#  	記号,空白,*,*,*,*, ,*,*
# プルーム・テック・プラス	名詞,一般,*,*,*,*,プルーム・テック・プラス,*,*
# （	記号,括弧開,*,*,*,*,（,（,（
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# ）	記号,括弧閉,*,*,*,*,）,）,）
# だっ	助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
# ,*,*
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# マイルド・ブレンド	名詞,一般,*,*,*,*,マイルド・ブレンド,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# レビュー	名詞,サ変接続,*,*,*,*,レビュー,レビュー,レビュー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# 、	記号,読点,*,*,*,*,、,、,、
# 香ばし	形容詞,自立,*,*,形容詞・イ段,ガル接続,香ばしい,コウバシ,コーバシ
# さ	名詞,接尾,特殊,*,*,*,さ,サ,サ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 優し	形容詞,自立,*,*,形容詞・イ段,ガル接続,優しい,ヤサシ,ヤサシ
# さ	名詞,接尾,特殊,*,*,*,さ,サ,サ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# プラス	名詞,一般,*,*,*,*,プラス,プラス,プラス
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 味わい	名詞,一般,*,*,*,*,味わい,アジワイ,アジワイ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 少し	副詞,助詞類接続,*,*,*,*,少し,スコシ,スコシ
# お茶	名詞,一般,*,*,*,*,お茶,オチャ,オチャ
# 系	名詞,接尾,一般,*,*,*,系,ケイ,ケイ
# （	記号,括弧開,*,*,*,*,（,（,（
# 緑茶	名詞,一般,*,*,*,*,緑茶,リョクチャ,リョクチャ
# ）	記号,括弧閉,*,*,*,*,）,）,）
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 特長	名詞,一般,*,*,*,*,特長,トクチョウ,トクチョー
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# フルーティー	名詞,形容動詞語幹,*,*,*,*,フルーティー,フルーティー,フルーティー
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# フレーバー	名詞,一般,*,*,*,*,フレーバー,フレーバー,フレーバー
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 低温	名詞,一般,*,*,*,*,低温,テイオン,テイオン
# 加熱	名詞,サ変接続,*,*,*,*,加熱,カネツ,カネツ
#  	記号,空白,*,*,*,*, ,*,*
# PloomTECH	名詞,固有名詞,組織,*,*,*,PloomTECH,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ＋	記号,一般,*,*,*,*,＋,タス,タス
# 専用	名詞,サ変接続,*,*,*,*,専用,センヨウ,センヨー
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 中間	名詞,一般,*,*,*,*,中間,チュウカン,チューカン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 味わえる	動詞,自立,*,*,一段,基本形,味わえる,アジワエル,アジワエル
# という	助詞,格助詞,連語,*,*,*,という,トイウ,トユウ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 僕	名詞,代名詞,一般,*,*,*,僕,ボク,ボク
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 感想	名詞,一般,*,*,*,*,感想,カンソウ,カンソー
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 例える	動詞,自立,*,*,一段,基本形,例える,タトエル,タトエル
# なら	助動詞,*,*,*,特殊・ダ,仮定形,だ,ナラ,ナラ
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# 50	名詞,数,*,*,*,*,50,*,*
#  	記号,空白,*,*,*,*, ,*,*
# ×	記号,一般,*,*,*,*,×,カケル,カケル
#  	記号,空白,*,*,*,*, ,*,*
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# 50	名詞,数,*,*,*,*,50,*,*
# といった	助詞,格助詞,連語,*,*,*,といった,トイッタ,トイッタ
# 感じ	名詞,一般,*,*,*,*,感じ,カンジ,カンジ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# 、	記号,読点,*,*,*,*,、,、,、
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# ブレンド	名詞,サ変接続,*,*,*,*,ブレンド,ブレンド,ブレンド
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# とこ	名詞,一般,*,*,*,*,とこ,トコ,トコ
# 取り	名詞,接尾,一般,*,*,*,取り,トリ,トリ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# おすすめ	名詞,サ変接続,*,*,*,*,おすすめ,オススメ,オススメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# 専用	名詞,サ変接続,*,*,*,*,専用,センヨウ,センヨー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# レギュラー	名詞,一般,*,*,*,*,レギュラー,レギュラー,レギュラー
# 両方	名詞,一般,*,*,*,*,両方,リョウホウ,リョーホー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 感じ	名詞,一般,*,*,*,*,感じ,カンジ,カンジ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 欲しい	形容詞,自立,*,*,形容詞・イ段,基本形,欲しい,ホシイ,ホシイ
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 1	名詞,数,*,*,*,*,1,*,*
# 番	名詞,接尾,助数詞,*,*,*,番,バン,バン
# おすすめ	名詞,サ変接続,*,*,*,*,おすすめ,オススメ,オススメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 気	名詞,非自立,一般,*,*,*,気,キ,キ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 4	名詞,数,*,*,*,*,4,*,*
# 番目	名詞,接尾,助数詞,*,*,*,番目,バンメ,バンメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 美味しい	形容詞,自立,*,*,形容詞・イ段,基本形,美味しい,オイシイ,オイシイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 感じ	動詞,自立,*,*,一段,連用形,感じる,カンジ,カンジ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# フレーバー	名詞,一般,*,*,*,*,フレーバー,フレーバー,フレーバー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# コールド	名詞,一般,*,*,*,*,コールド,コールド,コールド
# ・	記号,一般,*,*,*,*,・,・,・
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
# （	記号,括弧開,*,*,*,*,（,（,（
# メンソール	名詞,固有名詞,一般,*,*,*,メンソール,*,*
# ）	記号,括弧閉,*,*,*,*,）,）,）
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
# ,*,*
# 4	名詞,数,*,*,*,*,4,*,*
# 番目	名詞,接尾,助数詞,*,*,*,番目,バンメ,バンメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 美味しい	形容詞,自立,*,*,形容詞・イ段,基本形,美味しい,オイシイ,オイシイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 感じ	動詞,自立,*,*,一段,連用形,感じる,カンジ,カンジ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# メンソールタイプ	名詞,一般,*,*,*,*,メンソールタイプ,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# コールド	名詞,一般,*,*,*,*,コールド,コールド,コールド
# ・	記号,一般,*,*,*,*,・,・,・
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
# だっ	助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ
# ...
# マイルド・ブレンド	名詞,一般,*,*,*,*,マイルド・ブレンド,*,*
#  	記号,空白,*,*,*,*, ,*,*
# プルーム・テック・プラス	名詞,一般,*,*,*,*,プルーム・テック・プラス,*,*
#
# 		記号,空白,*,*,*,*,
# 	,*,*
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# コールド	名詞,一般,*,*,*,*,コールド,コールド,コールド
# ・	記号,一般,*,*,*,*,・,・,・
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
#  	記号,空白,*,*,*,*, ,*,*
# フォー	名詞,一般,*,*,*,*,フォー,*,*
#  	記号,空白,*,*,*,*, ,*,*
# プルーム・テック・プラス	名詞,一般,*,*,*,*,プルーム・テック・プラス,*,*
#
# 		記号,空白,*,*,*,*,
# 	,*,*
# メビウス	名詞,一般,*,*,*,*,メビウス,メビウス,メビウス
#  	記号,空白,*,*,*,*, ,*,*
# クリア	名詞,サ変接続,*,*,*,*,クリア,クリア,クリア
# ・	記号,一般,*,*,*,*,・,・,・
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
#  	記号,空白,*,*,*,*, ,*,*
# フォー	名詞,一般,*,*,*,*,フォー,*,*
#  	記号,空白,*,*,*,*, ,*,*
# プルーム・テック・プラス	名詞,一般,*,*,*,*,プルーム・テック・プラス,*,*
#
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
#
# ,*,*
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 4	名詞,数,*,*,*,*,4,*,*
# タイプ	名詞,一般,*,*,*,*,タイプ,タイプ,タイプ
# ある	動詞,自立,*,*,五段・ラ行,基本形,ある,アル,アル
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 今	名詞,副詞可能,*,*,*,*,今,イマ,イマ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 方	名詞,非自立,一般,*,*,*,方,ホウ,ホー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 少ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,少ない,スクナイ,スクナイ
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# 今後	名詞,副詞可能,*,*,*,*,今後,コンゴ,コンゴ
# 味	名詞,接尾,一般,*,*,*,味,ミ,ミ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 増え	動詞,自立,*,*,一段,連用形,増える,フエ,フエ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# くる	動詞,非自立,*,*,カ変・クル,基本形,くる,クル,クル
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 思う	動詞,自立,*,*,五段・ワ行促音便,基本形,思う,オモウ,オモウ
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# 僕	名詞,代名詞,一般,*,*,*,僕,ボク,ボク
# 的	名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# 本体	名詞,一般,*,*,*,*,本体,ホンタイ,ホンタイ
# ・	記号,一般,*,*,*,*,・,・,・
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 満足	名詞,サ変接続,*,*,*,*,満足,マンゾク,マンゾク
# 度	名詞,接尾,一般,*,*,*,度,ド,ド
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 高い	形容詞,自立,*,*,形容詞・アウオ段,基本形,高い,タカイ,タカイ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 選ん	動詞,自立,*,*,五段・バ行,連用タ接続,選ぶ,エラン,エラン
# で	助詞,接続助詞,*,*,*,*,で,デ,デ
# おけ	動詞,非自立,*,*,五段・カ行イ音便,仮定形,おく,オケ,オケ
# ば	助詞,接続助詞,*,*,*,*,ば,バ,バ
# 間違い	名詞,ナイ形容詞語幹,*,*,*,*,間違い,マチガイ,マチガイ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 感じ	動詞,自立,*,*,一段,連用形,感じる,カンジ,カンジ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 10	名詞,数,*,*,*,*,10,*,*
# ℃	名詞,サ変接続,*,*,*,*,℃,*,*
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# いえ	動詞,自立,*,*,五段・ワ行促音便,命令ｅ,いう,イエ,イエ
# キック	名詞,サ変接続,*,*,*,*,キック,キック,キック
# 感	名詞,接尾,一般,*,*,*,感,カン,カン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# かなり	副詞,一般,*,*,*,*,かなり,カナリ,カナリ
# 増し	動詞,自立,*,*,五段・サ行,連用形,増す,マシ,マシ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# 感	名詞,接尾,一般,*,*,*,感,カン,カン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 感じる	動詞,自立,*,*,一段,基本形,感じる,カンジル,カンジル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 嫌	名詞,形容動詞語幹,*,*,*,*,嫌,イヤ,イヤ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# プルームテック	名詞,一般,*,*,*,*,プルームテック,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 使う	動詞,自立,*,*,五段・ワ行促音便,基本形,使う,ツカウ,ツカウ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 思う	動詞,自立,*,*,五段・ワ行促音便,基本形,思う,オモウ,オモウ
# 。	記号,句点,*,*,*,*,。,。,。
# ちなみに	接続詞,*,*,*,*,*,ちなみに,チナミニ,チナミニ
# 以下	名詞,非自立,副詞可能,*,*,*,以下,イカ,イカ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 記事	名詞,一般,*,*,*,*,記事,キジ,キジ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 旧型	名詞,一般,*,*,*,*,旧型,キュウガタ,キューガタ
# プルームテック	名詞,一般,*,*,*,*,プルームテック,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 本体	名詞,一般,*,*,*,*,本体,ホンタイ,ホンタイ
# や	助詞,並立助詞,*,*,*,*,や,ヤ,ヤ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# について	助詞,格助詞,連語,*,*,*,について,ニツイテ,ニツイテ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 詳しく	形容詞,自立,*,*,形容詞・イ段,連用テ接続,詳しい,クワシク,クワシク
# 紹介	名詞,サ変接続,*,*,*,*,紹介,ショウカイ,ショーカイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# 参考	名詞,サ変接続,*,*,*,*,参考,サンコウ,サンコー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ほしい	形容詞,非自立,*,*,形容詞・イ段,基本形,ほしい,ホシイ,ホシイ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 関連	名詞,サ変接続,*,*,*,*,関連,カンレン,カンレン
# 記事	名詞,一般,*,*,*,*,記事,キジ,キジ
# 【	記号,括弧開,*,*,*,*,【,【,【
# プルームテック	名詞,一般,*,*,*,*,プルームテック,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 使い方	名詞,一般,*,*,*,*,使い方,ツカイカタ,ツカイカタ
# 】	記号,括弧閉,*,*,*,*,】,】,】
# 他	名詞,一般,*,*,*,*,他,タ,タ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 電子	名詞,一般,*,*,*,*,電子,デンシ,デンシ
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 違い	名詞,ナイ形容詞語幹,*,*,*,*,違い,チガイ,チガイ
# や	助詞,並立助詞,*,*,*,*,や,ヤ,ヤ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# 、	記号,読点,*,*,*,*,、,、,、
# 吸っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,吸う,スッ,スッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 感想	名詞,一般,*,*,*,*,感想,カンソウ,カンソー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# レビュー	名詞,サ変接続,*,*,*,*,レビュー,レビュー,レビュー
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# まとめ	名詞,一般,*,*,*,*,まとめ,マトメ,マトメ
# 】	記号,括弧閉,*,*,*,*,】,】,】
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# 全	接頭詞,名詞接続,*,*,*,*,全,ゼン,ゼン
# 4	名詞,数,*,*,*,*,4,*,*
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# フレーバー	名詞,一般,*,*,*,*,フレーバー,フレーバー,フレーバー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 最後	名詞,一般,*,*,*,*,最後,サイゴ,サイゴ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 【	記号,括弧開,*,*,*,*,【,【,【
# プルームテックプラス	名詞,固有名詞,一般,*,*,*,プルームテックプラス,*,*
# 】	記号,括弧閉,*,*,*,*,】,】,】
# 新型	名詞,一般,*,*,*,*,新型,シンガタ,シンガタ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# 4	名詞,数,*,*,*,*,4,*,*
# 種類	名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 全部	名詞,副詞可能,*,*,*,*,全部,ゼンブ,ゼンブ
# 吸っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,吸う,スッ,スッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 【	記号,括弧開,*,*,*,*,【,【,【
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 比較	名詞,サ変接続,*,*,*,*,比較,ヒカク,ヒカク
# 】	記号,括弧閉,*,*,*,*,】,】,】
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 記事	名詞,一般,*,*,*,*,記事,キジ,キジ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# まとめる	動詞,自立,*,*,一段,基本形,まとめる,マトメル,マトメル
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
#
#
#
#
#
# 		記号,空白,*,*,*,*,
#
#
#
#
# 	,*,*
# メンソール	名詞,一般,*,*,*,*,メンソール,*,*
# 好き	名詞,接尾,形容動詞語幹,*,*,*,好き,スキ,スキ
# なら	助動詞,*,*,*,特殊・ダ,仮定形,だ,ナラ,ナラ
# クリア	名詞,サ変接続,*,*,*,*,クリア,クリア,クリア
# ・	記号,一般,*,*,*,*,・,・,・
# ミント	名詞,一般,*,*,*,*,ミント,ミント,ミント
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# おすすめ	名詞,サ変接続,*,*,*,*,おすすめ,オススメ,オススメ
#
# 		記号,空白,*,*,*,*,
# 	,*,*
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# 感	名詞,接尾,一般,*,*,*,感,カン,カン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 感じ	動詞,自立,*,*,一段,連用形,感じる,カンジ,カンジ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# なら	助動詞,*,*,*,特殊・ダ,仮定形,だ,ナラ,ナラ
# ガ	名詞,一般,*,*,*,*,ガ,ガ,ガ
# ツン	副詞,助詞類接続,*,*,*,*,ツン,ツン,ツン
# と	助詞,副詞化,*,*,*,*,と,ト,ト
# 香ばしい	形容詞,自立,*,*,形容詞・イ段,基本形,香ばしい,コウバシイ,コーバシイ
# ロースト	名詞,一般,*,*,*,*,ロースト,ロースト,ロースト
# ・	記号,一般,*,*,*,*,・,・,・
# ブレンド	名詞,サ変接続,*,*,*,*,ブレンド,ブレンド,ブレンド
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# おすすめ	名詞,サ変接続,*,*,*,*,おすすめ,オススメ,オススメ
#
# 		記号,空白,*,*,*,*,
# 	,*,*
# 両方	名詞,一般,*,*,*,*,両方,リョウホウ,リョーホー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# とこ	名詞,一般,*,*,*,*,とこ,トコ,トコ
# 取り	名詞,接尾,一般,*,*,*,取り,トリ,トリ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# なら	助動詞,*,*,*,特殊・ダ,仮定形,だ,ナラ,ナラ
# マイルド・ブレンド	名詞,一般,*,*,*,*,マイルド・ブレンド,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# おすすめ	名詞,サ変接続,*,*,*,*,おすすめ,オススメ,オススメ
#
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
#
# ,*,*
# という	助詞,格助詞,連語,*,*,*,という,トイウ,トユウ
# 感じ	名詞,一般,*,*,*,*,感じ,カンジ,カンジ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 2019	名詞,数,*,*,*,*,2019,*,*
# 年	名詞,接尾,助数詞,*,*,*,年,ネン,ネン
# 4	名詞,数,*,*,*,*,4,*,*
# 月	名詞,一般,*,*,*,*,月,ツキ,ツキ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# 首都	名詞,一般,*,*,*,*,首都,シュト,シュト
# 圏	名詞,接尾,一般,*,*,*,圏,ケン,ケン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# コンビニ	名詞,一般,*,*,*,*,コンビニ,コンビニ,コンビニ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# 専用	名詞,サ変接続,*,*,*,*,専用,センヨウ,センヨー
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 販売	名詞,サ変接続,*,*,*,*,販売,ハンバイ,ハンバイ
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れる	動詞,接尾,*,*,一段,基本形,れる,レル,レル
# まで	助詞,副助詞,*,*,*,*,まで,マデ,マデ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# プルームテック	名詞,一般,*,*,*,*,プルームテック,*,*
# 直営店	名詞,一般,*,*,*,*,直営店,チョクエイテン,チョクエイテン
# ・	記号,一般,*,*,*,*,・,・,・
# オンライン	名詞,一般,*,*,*,*,オンライン,オンライン,オンライン
# ショップ	名詞,一般,*,*,*,*,ショップ,ショップ,ショップ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 購入	名詞,サ変接続,*,*,*,*,購入,コウニュウ,コーニュー
# 可能	名詞,形容動詞語幹,*,*,*,*,可能,カノウ,カノー
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 2019	名詞,数,*,*,*,*,2019,*,*
# 年	名詞,接尾,助数詞,*,*,*,年,ネン,ネン
# 4	名詞,数,*,*,*,*,4,*,*
# 月	名詞,一般,*,*,*,*,月,ツキ,ツキ
# 1	名詞,数,*,*,*,*,1,*,*
# 日	名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# 首都	名詞,一般,*,*,*,*,首都,シュト,シュト
# 圏	名詞,接尾,一般,*,*,*,圏,ケン,ケン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# コンビニ	名詞,一般,*,*,*,*,コンビニ,コンビニ,コンビニ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# たばこ	名詞,一般,*,*,*,*,たばこ,タバコ,タバコ
# カプセル	名詞,一般,*,*,*,*,カプセル,カプセル,カプセル
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 購入	名詞,サ変接続,*,*,*,*,購入,コウニュウ,コーニュー
# 可能	名詞,形容動詞語幹,*,*,*,*,可能,カノウ,カノー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# 、	記号,読点,*,*,*,*,、,、,、
# この	連体詞,*,*,*,*,*,この,コノ,コノ
# 機会	名詞,一般,*,*,*,*,機会,キカイ,キカイ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 旧型	名詞,一般,*,*,*,*,旧型,キュウガタ,キューガタ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 比べ	動詞,自立,*,*,一段,連用形,比べる,クラベ,クラベ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 味	名詞,一般,*,*,*,*,味,アジ,アジ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 満足	名詞,サ変接続,*,*,*,*,満足,マンゾク,マンゾク
# 度	名詞,接尾,一般,*,*,*,度,ド,ド
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 格段	名詞,形容動詞語幹,*,*,*,*,格段,カクダン,カクダン
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# あがっ	動詞,自立,*,*,五段・ラ行,連用タ接続,あがる,アガッ,アガッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 試し	動詞,自立,*,*,五段・サ行,連用形,試す,タメシ,タメシ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# どう	副詞,助詞類接続,*,*,*,*,どう,ドウ,ドー
# だろ	助動詞,*,*,*,特殊・ダ,未然形,だ,ダロ,ダロ
# う	助動詞,*,*,*,不変化型,基本形,う,ウ,ウ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
#
#
#  	記号,空白,*,*,*,*,
#
#
#
#  ,*,*
# 進化	名詞,サ変接続,*,*,*,*,進化,シンカ,シンカ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# レビュー	名詞,サ変接続,*,*,*,*,レビュー,レビュー,レビュー
# 記事	名詞,一般,*,*,*,*,記事,キジ,キジ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# よく	副詞,一般,*,*,*,*,よく,ヨク,ヨク
# 読ま	動詞,自立,*,*,五段・マ行,未然形,読む,ヨマ,ヨマ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# い	動詞,非自立,*,*,一段,連用形,いる,イ,イ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# iQOS	名詞,一般,*,*,*,*,iQOS,*,*
# 3	名詞,数,*,*,*,*,3,*,*
# ・	記号,一般,*,*,*,*,・,・,・
# glo	名詞,固有名詞,組織,*,*,*,glo,*,*
# 2	名詞,数,*,*,*,*,2,*,*
# ・	記号,一般,*,*,*,*,・,・,・
# PloomTECH	名詞,固有名詞,組織,*,*,*,PloomTECH,*,*
#  	記号,空白,*,*,*,*, ,*,*
# +	名詞,サ変接続,*,*,*,*,+,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 3	名詞,数,*,*,*,*,3,*,*
# つ	助動詞,*,*,*,下二・タ行,基本形,つ,ツ,ツ
# 使っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,使う,ツカッ,ツカッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 結果	名詞,副詞可能,*,*,*,*,結果,ケッカ,ケッカ
# 「	記号,括弧開,*,*,*,*,「,「,「
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 1	名詞,数,*,*,*,*,1,*,*
# 番	名詞,接尾,助数詞,*,*,*,番,バン,バン
# 満足	名詞,サ変接続,*,*,*,*,満足,マンゾク,マンゾク
# 度	名詞,接尾,一般,*,*,*,度,ド,ド
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 高かっ	形容詞,自立,*,*,形容詞・アウオ段,連用タ接続,高い,タカカッ,タカカッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 」	記号,括弧閉,*,*,*,*,」,」,」
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 関連	名詞,サ変接続,*,*,*,*,関連,カンレン,カンレン
# 記事	名詞,一般,*,*,*,*,記事,キジ,キジ
# 【	記号,括弧開,*,*,*,*,【,【,【
# レビュー	名詞,サ変接続,*,*,*,*,レビュー,レビュー,レビュー
# 】	記号,括弧閉,*,*,*,*,】,】,】
# プルームテックプラス	名詞,一般,*,*,*,*,プルームテックプラス,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 進化	名詞,サ変接続,*,*,*,*,進化,シンカ,シンカ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 驚き	動詞,自立,*,*,五段・カ行イ音便,連用形,驚く,オドロキ,オドロキ
# ！	記号,一般,*,*,*,*,！,！,！
# 新型	名詞,一般,*,*,*,*,新型,シンガタ,シンガタ
# 電子	名詞,一般,*,*,*,*,電子,デンシ,デンシ
# タバコ	名詞,一般,*,*,*,*,タバコ,タバコ,タバコ
# 全部	名詞,副詞可能,*,*,*,*,全部,ゼンブ,ゼンブ
# 試し	動詞,自立,*,*,五段・サ行,連用形,試す,タメシ,タメシ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 結果	名詞,副詞可能,*,*,*,*,結果,ケッカ,ケッカ
#
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
#
# ,*,*
# あわせ	動詞,自立,*,*,一段,連用形,あわせる,アワセ,アワセ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 読み	動詞,自立,*,*,五段・マ行,連用形,読む,ヨミ,ヨミ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
#
#
# ['プルームテックプラスのたばこカプセルの味【吸いごたえがアップしたフレーバー全4種類徹底レビュー】\n\n今話題の低温加熱型電子たばこプルームテックプラス専用のたばこカプセルの味が気になる。「たばこカプセルにはどんなフレーバーの味があるのか知りたい… どうせならタバコカプセル全種類の味を詳しく教えてほしい」\n\nそんな疑問に答えます。\n\nちなみに、プルームテックプラスにはレギュラーに2種の味、メンソールに2種の味、合計4種類のフレーバーの味があります。\n\n以前『【レビュー】プルームテックプラスの進化に驚き！新型電子タバコ全部試してみた結果』の記事で書いたように進化したプルームテックプラスは味（キック感）・デザイン・使い勝手の進化がたまらなくいい。\n\nこの記事では、プルームテックプラスのたばこカプセル全4種類の味の比較と旧型プルームテックと比べてどうなのか？を比較しています。\n\nプルームテックプラス買ってみたんだけど、カプセルコンビニ売ってなくて吸えない…なにこれ！笑#プルームテックプラス #新しい pic.twitter.com/qwtPYgpnec&mdash; ヨッシー / RESKY. (@reskysk8boarder) February 17, 2019 \n\nツイートのように、現在プルームテックプラスのたばこカプセルはコンビニでは購入できない… プルームテック直営店のみで買うことができる。\n\n2019年4月1日から首都圏のコンビニでプルームテックプラスのたばこカプセルが購入できるようになりました。\n\n低温加熱や高温加熱の電子タバコを全て試した僕が今1番だと感じている低温加熱プルームテックプラス（PloomTECH +）専用のたばこカプセルの味をレギュラー・メンソールの2タイプ全4種類を全部買って吸ってみたので徹底解説しながらレビューしたいと思う。\n\n【プルームテックプラスたばこカプセルの味】フレーバーは全4種類\n\n\n\nこれがプルームテックプラスに必要なたばこカプセル MEVIUS for Ploom TECH として販売されているプルームテックプラス専用たばこカプセル全4種類だ。\n\n左からプルームテックプラス専用たばこカプセルのフレーバーの銘柄を説明すると\n\n\n\n\n\t【レギュラー】メビウス ロースト・ブレンド フォー プルーム・テック・プラス\n\t【レギュラー】メビウス マイルド・ブレンド プルーム・テック・プラス\n\t【メンソール】メビウス コールド・ミント フォー プルーム・テック・プラス\n\t【メンソール】メビウス クリア・ミント フォー プルーム・テック・プラス\n\n\n\n\n左の2つがレギュラータイプのたばこカプセルで、右2つがメンソールタイプのたばこカプセルだ。\n\nメンソール好きなのか？レギュラー好きなのか？で選べば選択肢が狭まり好みの味を見つけやすいですね。\n\n以下に、プルームテックプラスのたばこカプセルは全4種類の一覧表と吸ってみた味の比較を参考に載せておきます。\n\n 味の比較表\n\n\n\n\nメビウス クリア・ミント\nメビウス コールド・ミント\nメビウス ロースト・ブレンド\nメビウス マイルド・ブレンド\n\n\n◎\n×\n○\n△\n\n\n\n\n上記のフレーバーの味比較表に書いてあるとおり、僕がプルームテックプラス専用たばこカプセルのメンソールフレーバーの味で、1番吸いごたえもあって美味しいと感じたのはメビウス クリア・ミントで、レギュラーフレーバーの味ではメビウス ロースト・ブレンドが、キック感もありプルームテックプラスらしい刺激も感じれた。\n\n新しくなったタバコカプセルは全4種類で、各たばこカプセル5個入、カートリッジ1個入りで500円（税込）だ。\n\n メビウス クリア・ミント フォー プルーム・テック・プラスを開封したところ\n\nちなみに、たばこカプセルを開封するとこんな感じ。\n\nカプセルの箱を開けると中には、たばこカプセル5つとカートリッジ1本が同梱されている。\n\nプルームテックプラスのバッテリーフル充電の状態で、たばこカプセル5つ分の吸引が可能だ。\n\n たばこカプセルを吸える回数\n\n\n\n\n\tカートリッジ1本で250パフ\n\tタバコカプセル1個で50パフ\n\n\n\n\n付属カートリッジにはリキッドと呼ばれる液体が充填されていて、カートリッジ1本につきたばこカプセル5つ分の蒸気を発生させることのできるリキッドが充填されていて、約50回吸引するとバッテリーの先端が40回青く点滅するので、その時がたばこカプセル交換の合図でカートリッジ1本でタバコカプセル5本が吸える。全部で250回吸うことができる。\n\nそれではプルームテックプラスのタバコカプセルの味（フレーバー）を詳しく解説します。\n\n1番目に美味しいと感じたフレーバーの味はメビウス クリア・ミント（メンソール）\n\n\n\nこれが低温加熱たばこのプルームテックプラス専用のタバコカプセルで、正規名称は「メビウス クリア・ミント フォー プルーム・テック・プラス」と言う。全ての PloomTECH ＋ のたばこカプセルにフォー プルーム・テック・プラスとつく。\n\nプルームテックプラス専用のたばこカプセルの中で、1番美味しいと感じた味だったメビウス クリア・ミントはスタンダードなメンソールといった感じ。メンソール感が控えめでとても吸いタバコ味のハッキリした味が特長的で、喉にもガツンとくるのでキック感も感じれて満足度の高いメンソールだ。\n\n\n\nプルームテックプラスが40℃加熱になったことでキック感が増したのでシンプルに旨い！というのが、クリアミントフレーバーの第一印象だった。\n\n僕の周りでプルームテックプラスを使っている女性にもメビウス クリア・ミントはメンソールらしいミントの爽やかな味が人気だ。\n\nプルームテックプラス専用フレーバーの味に迷ったらまずコレにしておけば間違いない！\n\n2番目に美味しいと感じたフレーバーの味はメビウス ロースト・ブレンド（レギュラー）\n\n\n\nこれがプルームテックプラス専用たばこカプセルの中で2番目に美味しいと感じたメビウス「ロースト・ブレンド」は、レギュラータイプで香ばしさと奥深いコクが味わいのたばこカプセルだ。\n\n\n\nメビウス ロースト・ブレンドはレギュラータイプの専用タバコカプセルで、メンソールとは違いタバコ本来のガツンとくる香ばしさと味わい深さが特長で、4種類の中で1番タバコの味が感じれた。\n\nローストというだけあって炙った（あぶった）ような味わいがブレンドされた専用タバコカプセルだ。\n\nメンソールが苦手な人に一番おすすめしたい味だ。\n\n3番目に美味しいと感じたフレーバーの味はメビウス マイルド・ブレンド（レギュラー）\n\n\n\n3番目に美味しいと感じたのは、メビウス マイルド・ブレンド フォー プルーム・テック・プラス（レギュラー）だった。\n\n\n\nメビウス マイルド・ブレンドの味をレビューすると、香ばしさに優しさをプラスしたような味わいで少しお茶系（緑茶）の味するのが特長でフルーティーなフレーバーだ。\n\n低温加熱 PloomTECH ＋専用たばこカプセルのメンソールとレギュラーの中間の味が味わえるというのが僕の感想です。\n\n例えるならレギュラー50 × メンソール50といった感じのたばこカプセルなので、ミントのメンソールとブレンドのレギュラーをいいとこ取りしたい人におすすめのプルームテックプラス専用のたばこカプセル。\n\nメンソールとレギュラー両方の感じが欲しい人には1番おすすめの味な気がする。\n\n4番目に美味しいと感じたフレーバーの味はメビウス コールド・ミント（メンソール）\n\n\n\n4番目に美味しいと感じたのは、メンソールタイプのメビウス コールド・ミントだった。清涼感たっぷりな味が特長だ。\n\n\n\nメビウス コールド・ミントはメンソールタイプのたばこカプセルで、名前から味がイメージできる冷たいメンソールの味わいを堪能できるプルームテックプラス専用のタバコカプセルだ。\n\n新しくなった PloomTECH + の特長でもあるキック感が苦手な人におすすめのメンソールフレーバーという感じで、プルームテックプラスのたばこカプセル4つの中で一番キック感が少なかった。\n\n今までのプルームテックに近い吸い心地を味わうならメビウス コールド・ミント フォー プルーム・テック・プラスがおすすめだ。\n\n【吸いごたえ】味とキック感の満足度をプラスする吸い方\n\n\n\nプルームテックプラスのたばこカプセルの味とキック感の満足度をプラスする吸い方を詳しく紹介します。\n\nどうするかと言うと、マウスピースを使うことでプルームテックプラスのたばこカプセルの味とキック感の満足度をプラスすることができるのでおすすめだ。\n\nマウスピースを本体の先端に装着するだけで吸いごたえアップ\n\nメビウス ロースト・ブレンド フォー プルーム・テック・プラスにマウスピースを使ったところ\n\nプルームテックプラスの吸いごたえをアップさせるマウスピースを使った「たばこカプセルの味」も気になるところですよね？\n\nマウスピースをプルームテックプラスの本体の先端に装着して吸うだけで驚くくらいにタバコカプセルの吸いごたえがアッ ...
# 味(77) カプセル(63) プルームテックプラス(57) たばこ(52) メビウス(34) 種類(26) タバコ(22) メンソール(22) ミント(21) 4(20) 感(19) プルームテック(19) プルーム・テック・プラス(18) フレーバー(17) レギュラー(17) 専用(15) 1(15) フォー(15) の(14) キック(13) ブレンド(12) ロースト(11) クリア(11) 感じ(11) マウス(11) ピース(11) おすすめ(10) ごたえ(9) 全(9) 加熱(9) 2(9) 記事(9) 人(9) 比較(8) こと(8) マイルド・ブレンド(8) コールド(8) 満足(8) 度(8) アップ(7) レビュー(7) 番目(7) 低温(6) よう(6) 旧型(6) これ(6) 僕(6) 番(6) タイプ(6) 個(6)
